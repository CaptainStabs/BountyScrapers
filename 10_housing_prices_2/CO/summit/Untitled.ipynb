# %%
import pandas as pd

# %%
df = pd.read_csv("combined.csv", dtype={"PropertySchedule": "object"})
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_22076\3009813310.py:1: DtypeWarning: Columns (17,26,64,65,68,96,99,100,101,102,103) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("combined.csv", dtype={"PropertySchedule": "object"})

# %%
df = df.rename(columns={"PropertySchedule": "property_id"})
df = df[["property_id", "ShortPropertyDescription"]]

# %%
df2 = pd.read_csv("extracted_sales_data.csv", dtype={"property_id": "object"})
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_22076\1675606467.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("extracted_sales_data.csv", dtype={"property_id": "object"})

# %%
df3 = pd.merge(df, df2, on="property_id", how="inner")

# %%
df3
# Out:
#          property_id              ShortPropertyDescription  \
# 0             100001                     LOT 244 ROYAL SUB
# 1             100001                     LOT 244 ROYAL SUB
# 2             100001                     LOT 244 ROYAL SUB
# 3             100001                     LOT 244 ROYAL SUB
# 4             100001                     LOT 244 ROYAL SUB
# ...              ...                                   ...
# 50096025     6519643       UNIT 8 GRANITE SQUARE TOWNHOMES
# 50096026     6519644       UNIT 9 GRANITE SQUARE TOWNHOMES
# 50096027     6519644       UNIT 9 GRANITE SQUARE TOWNHOMES
# 50096028     6519645  COMMON AREA GRANITE SQUARE TOWNHOMES
# 50096029     6519645  COMMON AREA GRANITE SQUARE TOWNHOMES
#
#               property_street_address property_township  land_area_acres  \
# 0         0225 Creek Side DR (CR 608)        Blue River           0.2700
# 1         0225 Creek Side DR (CR 608)        Blue River           0.2700
# ...

# %%
df3["property_street_address"] = df3["property_street_address"].fillna(df["ShortPropertyDescription"])

# %%
objs = df3.select_dtypes(['object'])
df3[objs.columns] = objs.apply(lambda x: x.str.strip())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22076\36439616.py in <module>
#       1 objs = df3.select_dtypes(['object'])
# ----> 2 df3[objs.columns] = objs.apply(lambda x: x.str.strip())
#
# c:\users\adria\miniconda3\envs\scraper\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8843             kwargs=kwargs,
#    8844         )
# -> 8845         return op.apply().__finalize__(self, method="apply")
#    8846
#    8847     def applymap(
#
# c:\users\adria\miniconda3\envs\scraper\lib\site-packages\pandas\core\apply.py in apply(self)
#     731             return self.apply_raw()
#     732
# --> 733         return self.apply_standard()
#     734
#     735     def agg(self):
#
# c:\users\adria\miniconda3\envs\scraper\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     855
# ...

# %%
df3 = df3.drop_duplicates(subset=["property_id", "sale_datetime", "sale_id"])

# %%
df4.to_csv("fixed_part_1.csv", index=False)

# %%
df2
# Out:
#         property_id      property_street_address property_township  \
# 0            100001  0225 Creek Side DR (CR 608)        Blue River
# 1            100001  0225 Creek Side DR (CR 608)        Blue River
# 2            100001  0225 Creek Side DR (CR 608)        Blue River
# 3            100001  0225 Creek Side DR (CR 608)        Blue River
# 4            100001  0225 Creek Side DR (CR 608)        Blue River
# ...             ...                          ...               ...
# 1314841     6519643        317 Granite ST UNIT 8            Frisco
# 1314842     6519644        317 Granite ST UNIT 9            Frisco
# 1314843     6519644        317 Granite ST UNIT 9            Frisco
# 1314844     6519645               317 Granite ST            Frisco
# 1314845     6519645               317 Granite ST            Frisco
#
#          land_area_acres  land_area_sqft         property_type  \
# 0                 0.2700           11761       SFR Improvement
# ...
