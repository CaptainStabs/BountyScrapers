# %%
import pandas as pd
import json

# %%
folder = '.\\input_files\\'
file = '37-0960170-northwestern-memorial-hospital-standard-charges.json'

# %%
with open(folder + file, 'r', encoding='utf-8-sig') as f:
    jd = json.load(f)
    jd = jd[list(jd.keys())[0]]

# %%
df = pd.DataFrame(jd, dtype=str)

# %%
df.rename(columns={
    'Billing_Code': 'code',
    'Service_Description': 'description',
    'Revenue_Code': 'rev_code',
}, inplace=True)

# %%
df.loc[~df['rev_code'].isna(),'rev_code'] = df['rev_code'].str.split('.').str[0].str.zfill(4)

# %%
cols = df.columns.tolist()
id_vars = cols[:3]
val_vars = cols[3:]

df = pd.melt(df, id_vars=id_vars, value_vars=val_vars, var_name='payer_name', value_name='standard_charge')

# %%
df.loc[df['code'].str.startswith('CPT®'), 'hcpcs_cpt'] = df['code'].str.split('CPT® ').str[1]
df.loc[df['code'].str.startswith('HCPCS'), 'hcpcs_cpt'] = df['code'].str.split('HCPCS ').str[1]
# df.loc[df['code'].str.startswith('MS-DRG V40 (FY 2023)'), 'ms_drg'] = df['code'].str.split('MS-DRG V40 (FY 2023)').str[1]

df['ms_drg'] = df['code'].str.extract(r'MS-DRG V40 \(FY 2023\) (.*)')

# %%
mask = df['code'].str.match(r'CPT® HB\d{5}')
df.loc[mask, 'hcpcs_cpt'] = df['code'].str.replace('CPT® HB', '')
df.loc[mask, 'modifiers'] = 'HB'

df.loc[mask]
# Out:
#                 code                   description rev_code
# 4464    CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300  \
# 11621   CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
# 18778   CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
# 25935   CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
# 33092   CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
# 40249   CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
# 47406   CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
# 54563   CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
# 61720   CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
# 68877   CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
# 76034   CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
# 83191   CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
# 90348   CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
# 97505   CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
# 104662  CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
# 111819  CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
# 118976  CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
# 126133  CPT® HB81479  UNLISTED MOLECULAR PATHOLOGY     0300
#
#                                     payer_name standard_charge hcpcs_cpt
# 4464                              Gross_Charge          6685.0     81479  \
# 11621   Deidentified_Minimum_Negotiated_Charge            55.0     81479
# 18778   Deidentified_Maximum_Negotiated_Charge          5214.3     81479
# 25935                    Discounted_Cash_Price          4679.5     81479
# 33092                         NMH AETNA [3004]         2246.16     81479
# 40249                       NMH AETNA BP [759]          2005.5     81479
# 47406                      NMH AETNA NAP [330]          5214.3     81479
# 54563        NMH BCBS BLUECHOICE OPTIONS [725]         1637.83     81479
# 61720      NMH BCBS BLUECHOICE PREFERRED [433]         1637.83     81479
# 68877         NMH BCBS PAR/INDEMNITY ADP [486]         3803.77     81479
# 76034                       NMH BCBS PPO [371]          2406.6     81479
# 83191              NMH CIGNA ALTERNATIVE [664]         1798.27     81479
# 90348                    NMH CIGNA BROAD [663]         4452.21     81479
# 97505                  NMH CIGNA PLUS NM [680]          1203.3     81479
# 104662               NMH HEALTH ALLIANCE [399]         2379.86     81479
# 111819                        NMH HUMANA [553]         2633.89     81479
# 118976                           NMH UHC [419]            59.0     81479
# 126133                      NMH UHC CORE [329]            55.0     81479
#
#        ms_drg modifiers
# 4464      NaN        HB
# 11621     NaN        HB
# 18778     NaN        HB
# 25935     NaN        HB
# 33092     NaN        HB
# 40249     NaN        HB
# 47406     NaN        HB
# 54563     NaN        HB
# 61720     NaN        HB
# 68877     NaN        HB
# 76034     NaN        HB
# 83191     NaN        HB
# 90348     NaN        HB
# 97505     NaN        HB
# 104662    NaN        HB
# 111819    NaN        HB
# 118976    NaN        HB
# 126133    NaN        HB

# %%
a = 'MS-DRG V40 (FY 2023) 999'
a.split('MS-DRG V40 (FY 2023) ')[1]
# Out:
# '999'

# %%
df['ms_drg'] = pd.NA

# %%
df.loc[~df['ms_drg'].isna()]
# Out:
# Empty DataFrame
# Columns: [code, description, rev_code, payer_name, standard_charge, hcpcs_cpt, ms_drg, modifiers]
# Index: []

# %%
df
# Out:
#                             code
# 0                   ADA 27204122  \
# 1                     CPT® 0001A
# 2                     CPT® 0001U
# 3                     CPT® 0002A
# 4                     CPT® 0003A
# ...                          ...
# 128821  MS-DRG V40 (FY 2023) 987
# 128822  MS-DRG V40 (FY 2023) 988
# 128823  MS-DRG V40 (FY 2023) 989
# 128824  MS-DRG V40 (FY 2023) 998
# 128825  MS-DRG V40 (FY 2023) 999
#
#                                               description rev_code
# 0       HB KNIFE JR ELECTROSURGICAL TISSUE CUT HIGH FR...     0272  \
# 1                            ADM SARSCOV2 30MCG/0.3ML 1ST     0771
# 2                                   RED BLOOD CELL TYPING     0302
# 3                            ADM SARSCOV2 30MCG/0.3ML 2ND     0771
# 4                            ADM SARSCOV2 30MCG/0.3ML 3RD     0771
# ...                                                   ...      ...
# 128821  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...      NaN
# 128822  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...      NaN
# 128823  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...      NaN
# 128824  PRINCIPAL DIAGNOSIS INVALID AS DISCHARGE DIAGN...      NaN
# 128825                                        UNGROUPABLE      NaN
#
#                 payer_name standard_charge hcpcs_cpt ms_drg modifiers
# 0             Gross_Charge          3083.0       NaN    NaN       NaN
# 1             Gross_Charge           200.0     0001A    NaN       NaN
# 2             Gross_Charge          954.67     0001U    NaN       NaN
# 3             Gross_Charge           200.0     0002A    NaN       NaN
# 4             Gross_Charge           200.0     0003A    NaN       NaN
# ...                    ...             ...       ...    ...       ...
# 128821  NMH UHC CORE [329]        49839.05       NaN    NaN       NaN
# 128822  NMH UHC CORE [329]        25478.23       NaN    NaN       NaN
# 128823  NMH UHC CORE [329]        16556.95       NaN    NaN       NaN
# 128824  NMH UHC CORE [329]          8905.0       NaN    NaN       NaN
# 128825  NMH UHC CORE [329]        29395.19       NaN    NaN       NaN
#
# [128826 rows x 8 columns]

# %%
payer_mapping = {
    'Gross_Charge': 'gross',
    'Deidentified_Minimum_Negotiated_Charge': 'min',
    'Deidentified_Maximum_Negotiated_Charge': 'max',
    'Discounted_Cash_Price': 'cash'
}

df['payer_category'] = df['payer_name'].map(payer_mapping).fillna('payer')

# %%
# Out:
# Empty DataFrame
# Columns: [code, description, rev_code, payer_name, standard_charge, hcpcs_cpt, ms_drg, modifiers, payer_category]
# Index: []

# %%
id_mapping = {
 '36-2513909-northwestern-medicine-central-dupage-hospital-standard-charges.json': '140242',
 '36-3484281-northwestern-medicine-delnor-hospital-standard-charges.json': '140211',
 '23-7087041-northwestern-medicine-kishwaukee-hospital-standard-charges.json': '140286',
 '36-2179779-northwestern-medicine-lake-forest-hospital-standard-charges.json': '140130',
 '36-2338884-northwestern-medicine-mchenry-hospital-standard-charges.json': '140116',
 '36-2169179-northwestern-medicine-palos-hospital-standard-charges.json': '140062',
 '36-4244337-northwestern-medicine-valley-west-hospital-standard-charges.json': '141340',
 '36-2338884-northwestern-medicine-woodstock-hospital-standard-charges.json': '140176',
 '37-0960170-northwestern-memorial-hospital-standard-charges.json': '140281',
 '36-2680776-marianjoy-rehabilitation-hospital-standard-charges.json': '143027'}

hosp_id = id_mapping[file]

output_folder = '.\\output_files\\'
output_file = file.split('-standard-charges')[0]
output_file = '-'.join(output_file.split('-')[2:])
output_file = hosp_id + '_' + output_file + '.csv'

df.to_csv(output_folder + output_file, index=False)

# %%
a = '36-2179779-northwestern-medicine-lake-forest-hospital-standard-charges.json'
a = a.split('-standard-charges')[0]
'-'.join(a.split('-')[2:])
# Out:
# 'northwestern-medicine-lake-forest-hospital'
