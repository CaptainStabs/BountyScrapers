# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
tqdm = tqdm.pandas()

# %%
def payer_category(payer_category):
    cats = {
        'Discounted Cash Price': 'cash', 
        'Gross Charge': 'gross',
        'Minimum Negotiateed Charge': 'min',
        'Maximum Negotiated Charge': 'max'
    }
    try:
        return cats[payer_category]
    except KeyError:
        return "payer"

def plan_name(x):
    plans = {
        'Aetna Managed Care': 'Managed Care',
        'BCBS\n(PPO,State Health, Federal Employees, Blue Select)': 'PPO,State Health, Federal Employees, Blue Select',
        'BCBS High Performance Network': 'High Performance Network',
        'Cigna Managed Care': 'Managed Care',
        'Healthgram Lexington Brands': 'Lexington Brands',
        'HealthTeam Advantage': pd.NA, # Not a plan
        'UHC Managed Care': 'Managed Care',
        'UHC Managed Care Individual Exchange': 'Managed Care Individual Exchange'
    }

    if x not in ('Gross Charge', 'Discounted Cash Price', 'Minimum Negotiateed Charge', 'Maximum Negotiated Charge'):
        try:
            return plans[x]
        except KeyError:
            if " " in x:
                return x.split(" ")[-1]
            else:
                return pd.NA
    else:
        return pd.NA

def code_type(code_type):
    codes = {
        'eap': 'eapg',
        'cpt': 'hcpcs_cpt',
        'drg': 'ms-drg'
    }
    return codes[code_type]

# %%
# def update_df(x):
#     if x in ('Gross Charge', 'Discounted Cash Price', 'Minimum Negotiateed Charge', 'Maximum Negotiated Charge'):
#         return pd.Series([payer_category(x), pd.NA], index=['payer_category', 'plan_name'])
#     else:
#         return pd.Series([pd.NA, plan_name(x)], index=['payer_category', 'plan_name'])

# %%
ccn_dict = {
    "Lexington": ['340096', '56-0543238'],
    
}

# %%
file = "./input_files/Lexington Transparency CY2022.csv"
df = pd.read_csv(file, encoding='ansi', dtype={'Revenue Code': str, 'DRG': str, 'CPT/HCPCS': str, 'CPT/HCPCS': str, 'EAP': str, 'NDC': str})#, nrows=100000)
file = file.split("/")[-1]
# Out:
# \Local\Temp\ipykernel_2992\3822224169.py:2: DtypeWarning: Columns (9,10,12,17,21,24,31,34,41,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, encoding='ansi', dtype={'Revenue Code': str, 'DRG': str, 'CPT/HCPCS': str, 'CPT/HCPCS': str, 'EAP': str, 'NDC': str})#, nrows=100000)

# %%
df = df.rename(columns={
    'Patient Type': 'patient_class',
    'Revenue Code': 'rev_code',
    'NDC': 'ndc',
    'EAP': 'procedure_code',
    'DRG': 'drg',
    'CPT/HCPCS': 'cpt',
    'HCPCS': 'hcpcs',
    'Procedure Description': 'description',
})

# %%
# melt codes
value_vars= ['drg', 'cpt']
id_vars = [x for x in df.columns if x not in value_vars]
df = pd.melt(df, id_vars=id_vars, value_vars=value_vars, var_name='code_meta', value_name='code')
df = df.drop(subset=['code_meta'])
df = df.dropna(subset=['code'])

df['code_orig'] = df['code']

# %%
df.columns
# Out:
# Index(['procedure_code', 'patient_class', 'rev_code', 'ndc', 'description',
#        'Gross Charge', 'Discounted Cash Price', 'Minimum Negotiateed Charge',
#        'Maximum Negotiated Charge', 'Aetna Managed Care', 'Aetna Medicare',
#        'Aetna Wholehealth', 'Ambetter', 'Amerihealth Medicaid', 'BeechStreet',
#        'BCBS\n(PPO,State Health, Federal Employees, Blue Select)',
#        'BCBS High Performance Network', 'Blue Local Group',
#        'Blue Local Individual', 'Blue Medicare', 'Blue Value',
#        'Carolina Complete Medicaid', 'Cigna HealthSprings',
#        'Cigna Managed Care', 'Coventry Wellpath', 'Coventry First Health',
#        'DirectNet', 'Healthgram', 'Healthgram Lexington Brands',
#        'HealthTeam Advantage', 'Healthy Blue Medicaid', 'Humana Choicecare',
#        'Humana Medicare', 'Medcost', 'Medcost Ultra', 'Multiplan-PCHS',
#        'National Provider Network', 'UHC Managed Care',
#        'UHC Managed Care Individual Exchange', 'UHC Medicare',
#        'United Community Medicaid', 'Wellcare Medicaid', 'Wellcare Medicare',
#        'code_meta', 'code', 'code_orig'],
#       dtype='object')

# %%
# Bring added columns to the beginning to make the next step easier
cols = df.columns.tolist()
cols = cols[-3:] + cols[:-3]
df = df[cols]

# %%
# melt payers
desc_index = cols.index("description")
id_vars = cols[:desc_index+1]
value_vars = cols[desc_index+1:]

df = pd.melt(df, id_vars=id_vars, value_vars=value_vars, var_name='payer_orig', value_name='rate')

# %%
# Schema conformance enforcement
df['rev_code'] = df['rev_code'].replace("#REF!", 'na') # excel mistake on their end

df['rev_code'].fillna('na', inplace=True)
df['ndc'].fillna('na', inplace=True)

# %%
# It is faster to just iterate over the df multiple times than to iterate over the whole df
# df[['payer_category', 'plan_name']] = df['payer_orig'].progress_apply(update_df).str.split(",", expand=True)
df['payer_category'] = df['payer_orig'].progress_apply(payer_category)
# df['plan_name'] = df['payer_orig'].progress_apply(plan_name) # Not allowed to extract the plan name
df['code_type'] = df['code_meta'].progress_apply(code_type)
# df['code'] = df[['code', 'code_type']].progress_apply(lambda x: x[0].zfill(3) if x[1] == 'ms-drg' else x[0], axis=1)
df['code'] = np.where(df['code_type'] == 'ms-drg', df['code'].str.zfill(3), df['code'])
# Out:
# 100%|██████████| 10881742/10881742 [00:11<00:00, 977563.14it/s]
# 100%|██████████| 10881742/10881742 [00:08<00:00, 1298072.03it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[94], line 6
#       4 # df['plan_name'] = df['payer_orig'].progress_apply(plan_name) # Not allowed to extract the plan name
#       5 df['code_type'] = df['code_meta'].progress_apply(code_type)
# ----> 6 df['code'] = df[['code', 'code_type']].apply(lambda x: x[0].zfill(3) if x[1] == 'ms-drg' else x[0], axis=1)
#
# File c:\Users\adria\miniconda3\envs\scraper2\lib\site-packages\pandas\core\frame.py:9565, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9554 from pandas.core.apply import frame_apply
#    9556 op = frame_apply(
#    9557     self,
#    9558     func=func,
#    (...)
#    9563     kwargs=kwargs,
#    9564 )
# -> 9565 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\adria\miniconda3\envs\scraper2\lib\site-packages\pandas\core\apply.py:746, in FrameApply.apply(self)
#     743 elif self.raw:
#     744     return self.apply_raw()
# --> 746 return self.apply_standard()
#
# File c:\Users\adria\miniconda3\envs\scraper2\lib\site-packages\pandas\core\apply.py:873, in FrameApply.apply_standard(self)
#     872 def apply_standard(self):
# --> 873     results, res_index = self.apply_series_generator()
#     875     # wrap results
#     876     return self.wrap_results(results, res_index)
#
# File c:\Users\adria\miniconda3\envs\scraper2\lib\site-packages\pandas\core\apply.py:889, in FrameApply.apply_series_generator(self)
#     886 with option_context("mode.chained_assignment", None):
#     887     for i, v in enumerate(series_gen):
#     888         # ignore SettingWithCopy here in case the user mutates
# --> 889         results[i] = self.f(v)
#     890         if isinstance(results[i], ABCSeries):
#     891             # If we have a view on v, we need to make a copy because
#     892             #  series_generator will swap out the underlying data
#     893             results[i] = results[i].copy(deep=False)
#
# Cell In[94], line 6, in <lambda>(x)
#       4 # df['plan_name'] = df['payer_orig'].progress_apply(plan_name) # Not allowed to extract the plan name
#       5 df['code_type'] = df['code_meta'].progress_apply(code_type)
# ----> 6 df['code'] = df[['code', 'code_type']].apply(lambda x: x[0].zfill(3) if x[1] == 'ms-drg' else x[0], axis=1)
#
# File c:\Users\adria\miniconda3\envs\scraper2\lib\site-packages\pandas\core\series.py:978, in Series.__getitem__(self, key)
#     975     key = unpack_1tuple(key)
#     977 if is_integer(key) and self.index._should_fallback_to_positional:
# --> 978     return self._values[key]
#     980 elif key_is_scalar:
#     981     return self._get_value(key)
#
# File c:\Users\adria\miniconda3\envs\scraper2\lib\site-packages\pandas\core\series.py:740, in Series._values(self)
#     708 @property
#     709 def _values(self):
#     710     """
#     711     Return the internal repr of this data (defined by Block.interval_values).
#     712     This are the values as stored in the Block (ndarray or ExtensionArray
#    (...)
#     738
#     739     """
# --> 740     return self._mgr.internal_values()
#
# KeyboardInterrupt:

# %%
# Add required hospital-specific file
ccn, tin = ccn_dict[file.split()[0]]
df['hospital_ccn'], df['hospital_tin'] = ccn, tin
df["filename"] = file
df['url'] = 'https://cdn.atriumhealth.org/-/media/wakeforest/clinical/files/patient-and-family-resources/transparency-files/2022/' + file

# %%
df['rate'] = df['rate'].str.replace(',', '')
df = df[(df['rate'] != '#VALUE!') & (df['rate'] != '#NUM!')]
df.dropna(subset=['rate'], inplace=True)
df['patient_class'] = df['patient_class'].str.lower()
# df['rev_code'] = df['rev_code'].str.zfill(4)

# %%
 # This has to be done like this to prevent 'na' from being zero padded
df['rev_code'] = df['rev_code'].progress_apply(lambda x: str(x).zfill(4) if x != 'na' else x)
# Out:
# 100%|██████████| 10881742/10881742 [00:07<00:00, 1548451.13it/s]

# %%
# df = df[df['code'].str.len() < 25]

# %%
df.to_csv('F:\\_Bounty\\transparency-in-pricing\\' + file.split()[0] + '.csv', index=False)

# %%
df
# Out:
#          code_meta   code code_orig procedure_code patient_class rev_code ndc  \
# 0              drg    571       571          MS571     inpatient       na  na
# 1              drg     54        54          MS054     inpatient       na  na
# 2              drg     56        56          MS056     inpatient       na  na
# 3              drg     57        57          MS057     inpatient       na  na
# 4              drg     60        60          MS060     inpatient       na  na
# ...            ...    ...       ...            ...           ...      ...  ..
# 11406341       cpt  C1760     C1760       70503402    outpatient       na  na
# 11406342       cpt  C1789     C1789         121464    outpatient       na  na
# 11406343       cpt  C1725     C1725       70504176    outpatient       na  na
# 11406344       cpt  C1725     C1725         212833    outpatient       na  na
# 11406345       cpt  C1729     C1729         100739    outpatient       na  na
#
#                                                 description  \
# 0                                  Skin Debridement With Cc
# 1                         Nervous System Neoplasms With McC
# 2            Degenerative Nervous System Disorders With McC
# 3         Degenerative Nervous System Disorders Without McC
# 4         Multiple Sclerosis And Cerebellar Ataxia Witho...
# ...                                                     ...
# 11406341  DEVICE CLOSURE CORDIS EXOSEAL OD7 FR FEMORAL A...
# 11406342  IMPLANT BREAST MENTOR MEMORYGEL COHESIVE I SIL...
# 11406343  COYOTE ES ODSEC2.5 MM L20 MM L143 CM OTW ULTRA...
# 11406344  COYOTE ES ODSEC4 MM L40 MM L145 CM OTW ULTRA L...
# 11406345  CATHETER DRAINAGE WORD L5 CM OD10 FR 5 CC BART...
#
#                  payer_orig   rate payer_category  code_type hospital_ccn  \
# 0              Gross Charge  20641          gross     ms-drg       340096
# 1              Gross Charge  10014          gross     ms-drg       340096
# 2              Gross Charge  45019          gross     ms-drg       340096
# 3              Gross Charge   8487          gross     ms-drg       340096
# 4              Gross Charge  37345          gross     ms-drg       340096
# ...                     ...    ...            ...        ...          ...
# 11406341  Wellcare Medicare      0          payer  hcpcs_cpt       340096
# 11406342  Wellcare Medicare      0          payer  hcpcs_cpt       340096
# 11406343  Wellcare Medicare      0          payer  hcpcs_cpt       340096
# 11406344  Wellcare Medicare      0          payer  hcpcs_cpt       340096
# 11406345  Wellcare Medicare      0          payer  hcpcs_cpt       340096
#
#          hospital_tin                           filename  \
# 0          56-0543238  Lexington Transparency CY2022.csv
# 1          56-0543238  Lexington Transparency CY2022.csv
# 2          56-0543238  Lexington Transparency CY2022.csv
# 3          56-0543238  Lexington Transparency CY2022.csv
# 4          56-0543238  Lexington Transparency CY2022.csv
# ...               ...                                ...
# 11406341   56-0543238  Lexington Transparency CY2022.csv
# 11406342   56-0543238  Lexington Transparency CY2022.csv
# 11406343   56-0543238  Lexington Transparency CY2022.csv
# 11406344   56-0543238  Lexington Transparency CY2022.csv
# 11406345   56-0543238  Lexington Transparency CY2022.csv
#
#                                                         url
# 0         https://cdn.atriumhealth.org/-/media/wakefores...
# 1         https://cdn.atriumhealth.org/-/media/wakefores...
# 2         https://cdn.atriumhealth.org/-/media/wakefores...
# 3         https://cdn.atriumhealth.org/-/media/wakefores...
# 4         https://cdn.atriumhealth.org/-/media/wakefores...
# ...                                                     ...
# 11406341  https://cdn.atriumhealth.org/-/media/wakefores...
# 11406342  https://cdn.atriumhealth.org/-/media/wakefores...
# 11406343  https://cdn.atriumhealth.org/-/media/wakefores...
# 11406344  https://cdn.atriumhealth.org/-/media/wakefores...
# 11406345  https://cdn.atriumhealth.org/-/media/wakefores...
#
# [10881742 rows x 16 columns]
