# %%
import pandas as pd

# %%
df = pd.read_csv("F:\\_Bounty\\transparency-in-pricing\\Lexington.csv", dtype={'rate': float})

pk_cols = ['hospital_tin','hospital_ccn','rev_code','procedure_code','code_type','code','modifier','ndc','apc','billing_class','patient_class','billed_quantity','payer_orig']
pk_cols = [x for x in pk_cols if x in df.columns]

dp_rows = df[df.duplicated(subset=pk_cols, keep=False)]

# %%
dp_rows
# Out:
#          code_meta   code code_orig                    procedure_code  \
# 7322           cpt  C1762     C1762                          65005492
# 7366           cpt  C1725     C1725                          70503900
# 7368           cpt  C1725     C1725                          70503902
# 7374           cpt  C1725     C1725                          70503909
# 7378           cpt  C1725     C1725                          70503915
# ...            ...    ...       ...                               ...
# 10856870       cpt  C1713     C1713                          69000949
# 10858610       cpt  C2617     C2617                          89030173
# 10859907       cpt  C1730     C1730  7475717300E523ABD959B081103B9E44
# 10877307       cpt  C1713     C1713                          69000949
# 10881739       cpt  C1725     C1725                          70504176
#
#          patient_class rev_code ndc  \
# 7322        outpatient       na  na
# 7366        outpatient       na  na
# ...
