# %%
import pandas as pd

# %%
df = pd.read_csv(".\\output_files\\reedley_.csv", dtype={'standard_charge': float}, low_memory=False)

pk_cols = ['hospital_id', 'rev_code', 'local_code', 'ms_drg', 'apr_drg', 'hcpcs_cpt', 'modifiers', 'ndc', 'billing_class', 'setting', 'payer', 'plan']
pk_cols = [x for x in pk_cols if x in df.columns]

# create a style object with background color yellow for pk columns
pk_cols_style = df.duplicated(subset=pk_cols, keep=False)
dp_rows = df[df.duplicated(subset=pk_cols, keep=False)]


# display the dataframe with highlighted pk columns
# dp_rows.style.apply(lambda x: pk_cols_style, axis=None)

# %%
dp_rows
# Out:
#        local_code                                        description setting
# 15228       77067                              Screening mammography       1  \
# 15229       77067                              Screening mammography       1
# 15352       97597   Removal of tissue from wound, 20.0 sq cm or less       1
# 15353       97597   Removal of tissue from wound, 20.0 sq cm or less       1
# 15357       99203  New patient office or other outpatient visit, ...       1
# ...           ...                                                ...     ...
# 180060       D649  VAGINAL DELIVERY WITHOUT STERILIZATION OR D&C ...       1
# 180061       E039                        Hypothyroidism, unspecified       1
# 180062       E039  VAGINAL DELIVERY WITHOUT STERILIZATION OR D&C ...       1
# 180064       E119  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...       1
# 180065       E119     Type 2 diabetes mellitus without complications       1
#
#         rev_code   code  ndc  drug_hcpcs_multiplier            payer
# 15228        NaN  77067  NaN                    NaN     Gross Charge  \
# 15229        NaN  77067  NaN                    NaN     Gross Charge
# 15352        NaN  97597  NaN                    NaN     Gross Charge
# 15353        NaN  97597  NaN                    NaN     Gross Charge
# 15357        NaN  99203  NaN                    NaN     Gross Charge
# ...          ...    ...  ...                    ...              ...
# 180060       NaN   D649  NaN                    NaN  WESTERN_GROWERS
# 180061       NaN   E039  NaN                    NaN  WESTERN_GROWERS
# 180062       NaN   E039  NaN                    NaN  WESTERN_GROWERS
# 180064       NaN   E119  NaN                    NaN  WESTERN_GROWERS
# 180065       NaN   E119  NaN                    NaN  WESTERN_GROWERS
#
#         standard_charge payer_category       plan  modifiers  ms_drg
# 15228            647.20          gross        NaN        NaN     NaN  \
# 15229            980.65          gross        NaN        NaN     NaN
# 15352            452.59          gross        NaN        NaN     NaN
# 15353            717.10          gross        NaN        NaN     NaN
# 15357            214.59          gross        NaN        NaN     NaN
# ...                 ...            ...        ...        ...     ...
# 180060         18611.76          payer  ALL PLANS        NaN     NaN
# 180061           219.42          payer  ALL PLANS        NaN     NaN
# 180062         55910.09          payer  ALL PLANS        NaN     NaN
# 180064         23383.93          payer  ALL PLANS        NaN     NaN
# 180065           481.31          payer  ALL PLANS        NaN     NaN
#
#        additional_payer_notes hcpcs_cpt   icd  hospital_id
# 15228                     NaN       NaN   NaN        50192
# 15229                     NaN       NaN   NaN        50192
# 15352                     NaN       NaN   NaN        50192
# 15353                     NaN       NaN   NaN        50192
# 15357                     NaN       NaN   NaN        50192
# ...                       ...       ...   ...          ...
# 180060                    NaN       NaN  D649        50192
# 180061                    NaN       NaN  E039        50192
# 180062                    NaN       NaN  E039        50192
# 180064                    NaN       NaN  E119        50192
# 180065                    NaN       NaN  E119        50192
#
# [222 rows x 17 columns]

# %%
pk_cols_style
# Out:
# 0        [background-color: yellow, background-color: y...
# 1        [background-color: yellow, background-color: y...
# 2        [background-color: yellow, background-color: y...
# 3        [background-color: yellow, background-color: y...
# 4        [background-color: yellow, background-color: y...
#                                ...
# 76150    [background-color: yellow, background-color: y...
# 76151    [background-color: yellow, background-color: y...
# 76152    [background-color: yellow, background-color: y...
# 76153    [background-color: yellow, background-color: y...
# 76154    [background-color: yellow, background-color: y...
# Length: 76155, dtype: object
