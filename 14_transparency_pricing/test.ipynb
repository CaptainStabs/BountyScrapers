# %%
import pandas as pd

# %%
file = 'C:\\Users\\adria\\Downloads\\370661238_ST-JOHN-S-HOSPITAL_STANDARDCHARGES.txt'


# df = pd.read_xml(file)
df = pd.read_csv(file, encoding='ansi', skiprows=1)
df
# Out:
#                       Site      Svc_Cd HCPC/Cpt_Cd
# 0      ST. JOHN'S HOSPITAL         NaN         216  \
# 1      ST. JOHN'S HOSPITAL         NaN         473
# 2      ST. JOHN'S HOSPITAL         NaN         470
# 3      ST. JOHN'S HOSPITAL         NaN         460
# 4      ST. JOHN'S HOSPITAL         NaN         743
# ...                    ...         ...         ...
# 33301  ST. JOHN'S HOSPITAL  98500008.0       93321
# 33302  ST. JOHN'S HOSPITAL  98500009.0       93272
# 33303  ST. JOHN'S HOSPITAL  98500010.0       93227
# 33304  ST. JOHN'S HOSPITAL  98500011.0       93228
# 33305  ST. JOHN'S HOSPITAL  98500012.0       93350
#
#                                            CDM_Svc_Descr  Rev_Cd
# 0      CARDIAC VALVE AND OTHER MAJOR CARDIOTHORACIC P...     120  \
# 1                  CERVICAL SPINAL FUSION WITHOUT CC/MCC     120
# 2      MAJOR HIP AND KNEE JOINT REPLACEMENT OR REATTA...     120
# 3              SPINAL FUSION EXCEPT CERVICAL WITHOUT MCC     120
# ...
