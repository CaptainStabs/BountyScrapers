# %%
import pandas as pd

# %%
file = 'F:\\_Bounty\\942854057_alta-view-hospital_standardcharges\\942854057_alta-view-hospital_standardcharges.xml'

df = pd.read_xml(file)
df
# Out:
#         Author        LastAuthor  TotalTime               Created
# 0   Ferah Syed  Patrick Mitchell        0.0  2023-03-24T14:40:44Z  \
# 1         None              None        NaN                  None
# 2         None              None        NaN                  None
# 3         None              None        NaN                  None
# 4         None              None        NaN                  None
# ..         ...               ...        ...                   ...
# 80        None              None        NaN                  None
# 81        None              None        NaN                  None
# 82        None              None        NaN                  None
# 83        None              None        NaN                  None
# 84        None              None        NaN                  None
#
#                LastSaved  Version  AllowPNG  Colors  WindowHeight
# 0   2023-03-27T14:32:57Z     16.0       NaN     NaN           NaN  \
# ...
