# %%
import pandas as pd

# %%
pd.set_option('display.min_rows', 20)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv(".\\output_files\\251778644_390067.csv", dtype=str, low_memory=False)

pk_cols = ['hospital_id', 'rev_code', 'local_code', 'ms_drg', 'apr_drg', 'hcpcs_cpt', 'modifiers', 'ndc', 'billing_class', 'setting', 'payer_name', 'plan', 'description', 'standard_charge']
pk_cols = [x for x in pk_cols if x in df.columns]

# create a style object with background color yellow for pk columns
dp_rows = df[df.duplicated(subset=pk_cols, keep=False)]

dp_rows.sort_values(pk_cols, inplace=True)
# Out:
# \Local\Temp\ipykernel_2531080\1995977074.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp_rows.sort_values(pk_cols, inplace=True)

# %%
df[df.duplicated]
# Out:
#                                                          description   code
# 14                                    HC Fine Ndl Asp W/O Imag Guide  10021  \
# 21                                             HC I&D Abscess Simple  10060
# 22                                             HC I&D Abscess Simple  10060
# 23                                             HC I&D Abscess Simple  10060
# 25                                          HC I&D Abscess Comp/Mult  10061
# 26                                          HC I&D Abscess Comp/Mult  10061
# 30                                        HC I&D Foreign Body Simple  10120
# 31                                        HC I&D Foreign Body Simple  10120
# 33                                          HC I&D Foreign Body Comp  10121
# 35                                               HC I&D Hematoma T/F  10140
# ...                                                              ...    ...
# 433741           IMMUNE GLOBULIN, OCTAGAM 10% SYRINGE (PEDS/NEONATE)  J1568
# 434494                               HC Locm 200-299mg/Ml Iodine,1ml  Q9966
# 434495                               HC Locm 200-299mg/Ml Iodine,1ml  Q9966
# 434496                               HC Locm 200-299mg/Ml Iodine,1ml  Q9966
# 434501                               HC Locm 300-399mg/Ml Iodine,1ml  Q9967
# 434502                               HC Locm 300-399mg/Ml Iodine,1ml  Q9967
# 434503                               HC Locm 300-399mg/Ml Iodine,1ml  Q9967
# 434504                               HC Locm 300-399mg/Ml Iodine,1ml  Q9967
# 434507  IOHEXOL 350 MG IODINE/ML INTRAVENOUS SOLUTION (RADIANT ONLY)  Q9967
# 434518                                      HC Sars Cov2 Rna, Rt Pcr  U0002
#
#         Gross Charges IP         payer_name standard_charge ms_drg hcpcs_cpt
# 14                $1,411   Gross Charges OP            1411    NaN     10021  \
# 21                  $683   Gross Charges OP             683    NaN     10060
# 22                  $683   Gross Charges OP             683    NaN     10060
# 23                  $683   Gross Charges OP             683    NaN     10060
# 25                $1,144   Gross Charges OP            1144    NaN     10061
# 26                $1,144   Gross Charges OP            1144    NaN     10061
# 30                  $696   Gross Charges OP             696    NaN     10120
# 31                  $696   Gross Charges OP             696    NaN     10120
# 33                $3,576   Gross Charges OP            3576    NaN     10121
# 35                $2,782   Gross Charges OP            2782    NaN     10140
# ...                   ...               ...             ...    ...       ...
# 433741            $4,938       UPMC For You             864    NaN     J1568
# 434494               $87       UPMC For You               0    NaN     Q9966
# 434495               $87       UPMC For You               0    NaN     Q9966
# 434496               $87       UPMC For You               0    NaN     Q9966
# 434501                $2       UPMC For You               0    NaN     Q9967
# 434502                $2       UPMC For You               0    NaN     Q9967
# 434503                $2       UPMC For You               0    NaN     Q9967
# 434504                $2       UPMC For You               0    NaN     Q9967
# 434507               $54       UPMC For You              13    NaN     Q9967
# 434518              $125       UPMC For You              36    NaN     U0002
#
#        setting payer_category contracting_method additional_generic_notes
# 14           1          gross                NaN                      NaN  \
# 21           1          gross                NaN                      NaN
# 22           1          gross                NaN                      NaN
# 23           1          gross                NaN                      NaN
# 25           1          gross                NaN                      NaN
# 26           1          gross                NaN                      NaN
# 30           1          gross                NaN                      NaN
# 31           1          gross                NaN                      NaN
# 33           1          gross                NaN                      NaN
# 35           1          gross                NaN                      NaN
# ...        ...            ...                ...                      ...
# 433741       1          payer                NaN                      NaN
# 434494       1          payer                NaN                      NaN
# 434495       1          payer                NaN                      NaN
# 434496       1          payer                NaN                      NaN
# 434501       1          payer                NaN                      NaN
# 434502       1          payer                NaN                      NaN
# 434503       1          payer                NaN                      NaN
# 434504       1          payer                NaN                      NaN
# 434507       1          payer                NaN                      NaN
# 434518       1          payer                NaN                      NaN
#
#        hospital_id
# 14          390067
# 21          390067
# 22          390067
# 23          390067
# 25          390067
# 26          390067
# 30          390067
# 31          390067
# 33          390067
# 35          390067
# ...            ...
# 433741      390067
# 434494      390067
# 434495      390067
# 434496      390067
# 434501      390067
# 434502      390067
# 434503      390067
# 434504      390067
# 434507      390067
# 434518      390067
#
# [10931 rows x 12 columns]
