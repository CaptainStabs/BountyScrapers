# %%
import pandas as pd

# %%
pd.set_option('display.min_rows', 50)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv(".\\output_files\\other_format\\521369749.csv", dtype=str, low_memory=False)

pk_cols = ['hospital_id', 'rev_code', 'local_code', 'ms_drg', 'apr_drg', 'hcpcs_cpt', 'modifiers', 'ndc', 'billing_class', 'setting', 'payer', 'plan']
pk_cols = [x for x in pk_cols if x in df.columns]

# create a style object with background color yellow for pk columns
dp_rows = df[df.duplicated(subset=pk_cols, keep=False)]

dp_rows.sort_values(pk_cols, inplace=True)
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_42332\2036464608.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp_rows.sort_values(pk_cols, inplace=True)

# %%
dp_rows
# Out:
#                           description rev_code code
# 3965                 2W REHAB PRIVATE     0118  NaN  \
# 4108                 2E REHAB PRIVATE     0118  NaN
# 2051                 2W REHAB PRIVATE     0118  NaN
# 2194                 2E REHAB PRIVATE     0118  NaN
# 5879                 2W REHAB PRIVATE     0118  NaN
# 6022                 2E REHAB PRIVATE     0118  NaN
# 7793                 2W REHAB PRIVATE     0118  NaN
# 7936                 2E REHAB PRIVATE     0118  NaN
# 9707                 2W REHAB PRIVATE     0118  NaN
# 9850                 2E REHAB PRIVATE     0118  NaN
# 11621                2W REHAB PRIVATE     0118  NaN
# 11764                2E REHAB PRIVATE     0118  NaN
# 15449                2W REHAB PRIVATE     0118  NaN
# 15592                2E REHAB PRIVATE     0118  NaN
# 13535                2W REHAB PRIVATE     0118  NaN
# 13678                2E REHAB PRIVATE     0118  NaN
# 47987                2W REHAB PRIVATE     0118  NaN
# 48130                2E REHAB PRIVATE     0118  NaN
# 46073                2W REHAB PRIVATE     0118  NaN
# 46216                2E REHAB PRIVATE     0118  NaN
# 137                  2W REHAB PRIVATE     0118  NaN
# 280                  2E REHAB PRIVATE     0118  NaN
# 17363                2W REHAB PRIVATE     0118  NaN
# 17506                2E REHAB PRIVATE     0118  NaN
# 19277                2W REHAB PRIVATE     0118  NaN
# ...                               ...      ...  ...
# 41070       EMG NDL GD W/CHEMODENERV+     0922  NaN
# 41074    NERVE CONDUCT STUDIES 3 TO 4     0922  NaN
# 41415    NERVE CONDUCT STUDIES 1 TO 2     0922  NaN
# 41417   NERVE CONDUCT STUDIES 13 PLUS     0922  NaN
# 41951        EMG ELEC STIM W/CHEMODEN     0922  NaN
# 42101  EMG 1 EXTREMTY W/WO PARASPINAL     0922  NaN
# 42102   EMG MUSCLE TEST HEMIDIAPHRAGM     0922  NaN
# 42106   NERVE CONDUCT STUDIES 13 PLUS     0922  NaN
# 42107    NERVE CONDUCT STUDIES 5 TO 6     0922  NaN
# 44152       EMG EXT W/NCS LTD+PRIM PX     0922  NaN
# 44153           EMG EXT W/NDC+PRIM PX     0922  NaN
# 44299  NERVE CONDUCT STUDIES 11 TO 12     0922  NaN
# 44575    NERVE CONDUCT STUDIES 7 TO 8     0922  NaN
# 44724  EMG 1 MUSCLE NONPARASPINAL LTD     0922  NaN
# 44725   NERVE CONDUCT STUDIES 9 TO 10     0922  NaN
# 44897  EMG 2 EXTREMTY W/WO PARASPINAL     0922  NaN
# 44898       EMG NDL GD W/CHEMODENERV+     0922  NaN
# 44902    NERVE CONDUCT STUDIES 3 TO 4     0922  NaN
# 45243    NERVE CONDUCT STUDIES 1 TO 2     0922  NaN
# 45245   NERVE CONDUCT STUDIES 13 PLUS     0922  NaN
# 45779        EMG ELEC STIM W/CHEMODEN     0922  NaN
# 45929  EMG 1 EXTREMTY W/WO PARASPINAL     0922  NaN
# 45930   EMG MUSCLE TEST HEMIDIAPHRAGM     0922  NaN
# 45934   NERVE CONDUCT STUDIES 13 PLUS     0922  NaN
# 45935    NERVE CONDUCT STUDIES 5 TO 6     0922  NaN
#
#                                          payer standard_charge modifiers
# 3965                                     Aetna             0.0       NaN  \
# 4108                                     Aetna             0.0       NaN
# 2051                  Aetna Medicare Advantage         1438.43       NaN
# 2194                  Aetna Medicare Advantage         1438.43       NaN
# 5879                               Amerihealth         1359.69       NaN
# 6022                               Amerihealth         1359.69       NaN
# 7793                                 CareFirst          1686.9       NaN
# 7936                                 CareFirst          1686.9       NaN
# 9707                       CareFirst Advantage         1396.52       NaN
# 9850                       CareFirst Advantage         1396.52       NaN
# 11621              CareFirst Community Plan DC         1359.69       NaN
# 11764              CareFirst Community Plan DC         1359.69       NaN
# 15449                                    Cigna         2522.75       NaN
# 15592                                    Cigna         2522.75       NaN
# 13535                       Cigna Healthspring         1466.37       NaN
# 13678                       Cigna Healthspring         1466.37       NaN
# 47987                    De-Identified Maximum         2522.75       NaN
# 48130                    De-Identified Maximum         2522.75       NaN
# 46073                    De-Identified Minimum             0.0       NaN
# 46216                    De-Identified Minimum             0.0       NaN
# 137                              Gross Charges         2540.05       NaN
# 280                              Gross Charges         2540.05       NaN
# 17363                                    HSCSN         1905.04       NaN
# 17506                                    HSCSN         1905.04       NaN
# 19277                 Johns Hopkins Healthcare          2500.0       NaN
# ...                                        ...             ...       ...
# 41070                United Medicare Advantage          122.02       NaN
# 41074                United Medicare Advantage          160.66       NaN
# 41415                United Medicare Advantage           94.74       NaN
# 41417                United Medicare Advantage           586.1       NaN
# 41951                United Medicare Advantage          128.48       NaN
# 42101                United Medicare Advantage          278.26       NaN
# 42102                United Medicare Advantage          179.08       NaN
# 42106                United Medicare Advantage           586.1       NaN
# 42107                United Medicare Advantage          160.66       NaN
# 44152  Veterans Affairs Community Care Network           91.98       NaN
# 44153  Veterans Affairs Community Care Network          103.12       NaN
# 44299  Veterans Affairs Community Care Network          282.32       NaN
# 44575  Veterans Affairs Community Care Network           172.8       NaN
# 44724  Veterans Affairs Community Care Network          137.94       NaN
# 44725  Veterans Affairs Community Care Network          282.32       NaN
# 44897  Veterans Affairs Community Care Network          425.16       NaN
# 44898  Veterans Affairs Community Care Network          118.46       NaN
# 44902  Veterans Affairs Community Care Network          155.98       NaN
# 45243  Veterans Affairs Community Care Network           91.98       NaN
# 45245  Veterans Affairs Community Care Network          569.03       NaN
# 45779  Veterans Affairs Community Care Network          124.73       NaN
# 45929  Veterans Affairs Community Care Network          270.15       NaN
# 45930  Veterans Affairs Community Care Network          173.86       NaN
# 45934  Veterans Affairs Community Care Network          569.03       NaN
# 45935  Veterans Affairs Community Care Network          155.98       NaN
#
#       hcpcs_cpt payer_category hospital_id
# 3965        NaN          payer      093025
# 4108        NaN          payer      093025
# 2051        NaN          payer      093025
# 2194        NaN          payer      093025
# 5879        NaN          payer      093025
# 6022        NaN          payer      093025
# 7793        NaN          payer      093025
# 7936        NaN          payer      093025
# 9707        NaN          payer      093025
# 9850        NaN          payer      093025
# 11621       NaN          payer      093025
# 11764       NaN          payer      093025
# 15449       NaN          payer      093025
# 15592       NaN          payer      093025
# 13535       NaN          payer      093025
# 13678       NaN          payer      093025
# 47987       NaN            max      093025
# 48130       NaN            max      093025
# 46073       NaN            min      093025
# 46216       NaN            min      093025
# 137         NaN          gross      093025
# 280         NaN          gross      093025
# 17363       NaN          payer      093025
# 17506       NaN          payer      093025
# 19277       NaN          payer      093025
# ...         ...            ...         ...
# 41070       NaN          payer      093025
# 41074       NaN          payer      093025
# 41415       NaN          payer      093025
# 41417       NaN          payer      093025
# 41951       NaN          payer      093025
# 42101       NaN          payer      093025
# 42102       NaN          payer      093025
# 42106       NaN          payer      093025
# 42107       NaN          payer      093025
# 44152       NaN          payer      093025
# 44153       NaN          payer      093025
# 44299       NaN          payer      093025
# 44575       NaN          payer      093025
# 44724       NaN          payer      093025
# 44725       NaN          payer      093025
# 44897       NaN          payer      093025
# 44898       NaN          payer      093025
# 44902       NaN          payer      093025
# 45243       NaN          payer      093025
# 45245       NaN          payer      093025
# 45779       NaN          payer      093025
# 45929       NaN          payer      093025
# 45930       NaN          payer      093025
# 45934       NaN          payer      093025
# 45935       NaN          payer      093025
#
# [47268 rows x 9 columns]
