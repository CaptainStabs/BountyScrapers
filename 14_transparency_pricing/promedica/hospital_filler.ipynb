# %%
import pandas as pd

# %%
df = pd.read_csv('hospital.csv', dtype=str)

# %%
df['ein'] = df['file_name'].str.split('_').str[0].str[:2] + '-' + df['file_name'].str.split('_').str[0].str[2:]

# %%
df
# Out:
#        id         ein                                          file_name
# 0  360259  34-1883132   341883132_bay-park-hospital_standardcharges.json  \
# 1  361328  34-4446484  344446484_defiance-regional-hospital_standardc...
# 2  360074  34-4428256     344428256_toledo-hospital_standardcharges.json
# 3  361318  34-0898745  340898745_fostoria-community-hospital_standard...
# 4  360156  34-4430849   344430849_memorial-hospital_standardcharges.json
# 5  230005  38-2796005  382796005_charles-and-virginia-hickman-hospita...
# 6  230022  38-6108110  386108110_coldwater-regional-hospital_standard...
# 7  230099  38-1984289  381984289_monroe-regional-hospital_standardcha...
# 8  360068  34-4428256     344428256_toledo-hospital_standardcharges.json
#
#                                              mrf_url
# 0  https://goldteamstorage.blob.core.windows.net/...  \
# 1  https://goldteamstorage.blob.core.windows.net/...
# 2  https://goldteamstorage.blob.core.windows.net/...
# 3  https://goldteamstorage.blob.core.windows.net/...
# 4  https://goldteamstorage.blob.core.windows.net/...
# 5  https://goldteamstorage.blob.core.windows.net/...
# 6  https://goldteamstorage.blob.core.windows.net/...
# 7  https://goldteamstorage.blob.core.windows.net/...
# 8  https://goldteamstorage.blob.core.windows.net/...
#
#                                               name
# 0                      BAY PARK COMMUNITY HOSPITAL  \
# 1                 DEFIANCE REGIONAL MEDICAL CENTER
# 2                                  FLOWER HOSPITAL
# 3                      FOSTORIA COMMUNITY HOSPITAL
# 4                                MEMORIAL HOSPITAL
# 5  PROMEDICA CHARLES AND VIRGINIA HICKMAN HOSPITAL
# 6            PROMEDICA COLDWATER REGIONAL HOSPITAL
# 7               PROMEDICA MONROE REGIONAL HOSPITAL
# 8                              TOLEDO HOSPITAL THE
#
#                                 alt_name              system_name
# 0            ProMedica Bay Park Hospital  ProMedica Health System  \
# 1   ProMedica Defiance Regional Hospital  ProMedica Health System
# 2              ProMedica Flower Hospital                      NaN
# 3  ProMedica Fostoria Community Hospital  ProMedica Health System
# 4            ProMedica Memorial Hospital  ProMedica Health System
# 5                                    NaN  ProMedica Health System
# 6  ProMedica Coldwater Regional Hospital  ProMedica Health System
# 7     ProMedica Monroe Regional Hospital  ProMedica Health System
# 8              ProMedica Toledo Hospital  ProMedica Health System
#
#                         addr       city state    zip       phone urban_rural
# 0        2801 BAY PARK DRIVE     OREGON    OH  43616  4196907700           U  \
# 1        1200 RALSTON AVENUE   DEFIANCE    OH  43512  4197834493           R
# 2          5200 HARROUN ROAD   SYLVANIA    OH  43560  4198241444           U
# 3       501 VAN BUREN STREET   FOSTORIA    OH  44830  4194357734           R
# 4      715 SOUTH TAFT AVENUE    FREMONT    OH  43420  4193346617           R
# 5      5640 N ADRIAN HIGHWAY     ADRIAN    MI  49221  5172650900           R
# 6           274 E CHICAGO ST  COLDWATER    MI  49036  5172795400           R
# 7            718 N MACOMB ST     MONROE    MI  48162  7342408400           U
# 8  2142 NORTH COVE BOULEVARD     TOLEDO    OH  43606  4192917482           U
#
#                     category              control_type
# 0                 Short Term  FOR PROFIT - CORPORATION  \
# 1  Critical Access Hospitals  FOR PROFIT - PARTNERSHIP
# 2                 Short Term  FOR PROFIT - PARTNERSHIP
# 3  Critical Access Hospitals  FOR PROFIT - PARTNERSHIP
# 4                 Short Term  FOR PROFIT - CORPORATION
# 5                 Short Term  FOR PROFIT - PARTNERSHIP
# 6                 Short Term        GOVERNMENT - STATE
# 7                 Short Term  FOR PROFIT - CORPORATION
# 8                 Short Term  FOR PROFIT - PARTNERSHIP
#
#   medicare_termination_status last_updated permalink
# 0             ACTIVE PROVIDER   2022-01-28       NaN  \
# 1             ACTIVE PROVIDER   2022-01-28       NaN
# 2   VOLUNTARY-MERGER, CLOSURE   2022-01-28       NaN
# 3             ACTIVE PROVIDER   2022-01-28       NaN
# 4             ACTIVE PROVIDER   2022-01-28       NaN
# 5             ACTIVE PROVIDER   2022-01-28       NaN
# 6             ACTIVE PROVIDER   2022-01-28       NaN
# 7             ACTIVE PROVIDER   2022-01-28       NaN
# 8             ACTIVE PROVIDER   2022-01-28       NaN
#
#                                    transparency_page additional_notes
# 0  https://www.promedica.org/pay-my-bill/price-tr...              NaN
# 1  https://www.promedica.org/pay-my-bill/price-tr...              NaN
# 2  https://www.promedica.org/pay-my-bill/price-tr...              NaN
# 3  https://www.promedica.org/pay-my-bill/price-tr...              NaN
# 4  https://www.promedica.org/pay-my-bill/price-tr...              NaN
# 5  https://www.promedica.org/pay-my-bill/price-tr...              NaN
# 6  https://www.promedica.org/pay-my-bill/price-tr...              NaN
# 7  https://www.promedica.org/pay-my-bill/price-tr...              NaN
# 8  https://www.promedica.org/pay-my-bill/price-tr...              NaN

# %%
df.to_csv('hospitals.csv', index=False)

# %%
ein_ccn_dict = dict(zip(df['file_name'], df['id']))
ein_ccn_dict
# Out:
# {'341883132_bay-park-hospital_standardcharges.json': '360259',
#  '344446484_defiance-regional-hospital_standardcharges.json': '361328',
#  '344428256_toledo-hospital_standardcharges.json': '360068',
#  '340898745_fostoria-community-hospital_standardcharges.json': '361318',
#  '344430849_memorial-hospital_standardcharges.json': '360156',
#  '382796005_charles-and-virginia-hickman-hospital_standardcharges.json': '230005',
#  '386108110_coldwater-regional-hospital_standardcharges.json': '230022',
#  '381984289_monroe-regional-hospital_standardcharges.json': '230099'}
