# %%
import pandas as pd
import json

# %%
folder = '.\\input_files\\'
file = '344430849_memorial-hospital_standardcharges.json'

# %%
with open(folder + file, 'r') as f:
    jd = json.load(f)
    jd = jd[0]['item']

# %%
df = pd.DataFrame(jd)

# %%
df.rename(columns={
    'payer': 'payer_name',
    'Associated_Codes': 'code',
    'iobSelection': 'setting',
    'Payer_Allowed_Amount': 'standard_charge',
}, inplace=True)

# %%
df['code'] = df['code'].str.strip()

# %%
# Extract revenue codes from `code`
df['rev_code'] = df['code'].str.extract(r'.*,(0\d{3})')
# Remove the revenue code from `code`
df['code'] = df['code'].str.replace(r',0\d{3}', '', regex=True)

# %%
df = df.assign(code=df['code'].str.split(',')).explode('code')

# %%
df['code'] = df['code'].str.strip()

# %%
df.reset_index(drop=True, inplace=True)

# %%
df[['ms_drg', 'thru']] = df.loc[df['code'].str.contains('-'), 'code'].str.split('-', expand=True)

# %%
df_payer = df.copy()
df_payer = df_payer[['payer_name', 'description', 'code', 'standard_charge', 'setting', 'rev_code', 'ms_drg', 'thru']]
df_payer['payer_category'] = 'payer'

# %%
df_rates = df.copy()
df_rates = df_rates[['description', 'code', 'setting', 'Gross_Charge', 'Cash_Discount', 'Deidentified_Min_Allowed', 'DeIdentified_Max_Allowed', 'rev_code', 'ms_drg', 'thru']]

# %%
cols = df_rates.columns.tolist()
id_vars = ['description', 'code', 'setting', 'rev_code', 'ms_drg', 'thru']
value_vars = [x for x in cols if x not in id_vars]

df_rates = pd.melt(df_rates, id_vars=id_vars, value_vars=value_vars, var_name='payer_name', value_name='standard_charge')

# %%
mapping = {
    'Gross_Charge': 'gross',
    'Cash_Discount': 'cash',
    'Deidentified_Min_Allowed': 'min',
    'DeIdentified_Max_Allowed':'max',
    }

df_rates['payer_category'] = df_rates['payer_name'].map(mapping)

# %%
df = pd.concat([df_payer, df_rates])

# %%
df.reset_index(drop=True, inplace=True)

# %%
df['setting'] = df['setting'].str.lower()

# %%
df.loc[df['code'].str.match(r'^[A-Z][0-9]{4}$|^[0-9]{5}$|^[0-9]{4}[A-Z]$'), 'hcpcs_cpt'] = df['code']
df.loc[df['code'].str.match(r'^[0-9]{3}$'), 'ms_drg'] = df['code']
df.loc[df['code'].str.len() == 4, 'rev_code'] = df['code']

# %%
df.loc[~df['hcpcs_cpt'].isna() & ~df['rev_code'].isna()]
# Out:
#                      payer_name
# 11833                       NaN  \
# 11834                       NaN
# 11835                       NaN
# 11836                       NaN
# 11837                       NaN
# ...                         ...
# 60886  DeIdentified_Max_Allowed
# 60896  DeIdentified_Max_Allowed
# 60897  DeIdentified_Max_Allowed
# 60898  DeIdentified_Max_Allowed
# 60899  DeIdentified_Max_Allowed
#
#                                              description   code
# 11833               STERILE SUPPLIES - INFUSION CATHETER  C1751  \
# 11834               STERILE SUPPLIES - INFUSION CATHETER  C1751
# 11835               STERILE SUPPLIES - INFUSION CATHETER  C1751
# 11836               STERILE SUPPLIES - INFUSION CATHETER  C1751
# 11837               STERILE SUPPLIES - INFUSION CATHETER  C1751
# ...                                                  ...    ...
# 60886  LAB - High Throughput Detection Of COVID-19 Vi...  U0003
# 60896  LAB - High Throughput COVID-19 Testing By Non-...  U0004
# 60897  LAB - High Throughput Detection Of COVID-19 Vi...  U0005
# 60898  STERILE SUPPLIES - INTRAOCULAR LENS - POSTERIO...  V2632
# 60899                                   PHYSICAL THERAPY  W0710
#
#       standard_charge setting rev_code ms_drg thru payer_category hcpcs_cpt
# 11833             N/A     NaN     0272    NaN  NaN          payer     C1751
# 11834             N/A     NaN     0272    NaN  NaN          payer     C1751
# 11835             N/A     NaN     0272    NaN  NaN          payer     C1751
# 11836             N/A     NaN     0272    NaN  NaN          payer     C1751
# 11837             N/A     NaN     0272    NaN  NaN          payer     C1751
# ...               ...     ...      ...    ...  ...            ...       ...
# 60886             N/A     NaN     0300    NaN  NaN            max     U0003
# 60896             N/A     NaN     0300    NaN  NaN            max     U0004
# 60897             N/A     NaN     0300    NaN  NaN            max     U0005
# 60898             N/A     NaN     0276    NaN  NaN            max     V2632
# 60899             N/A     NaN     0421    NaN  NaN            max     W0710
#
# [475 rows x 10 columns]

# %%
df.loc[df['standard_charge'] == 'N/A', 'standard_charge'] = pd.NA

# %%
df.dropna(subset='standard_charge', inplace=True)

# %%
# Out:
# Empty DataFrame
# Columns: [payer_name, description, code, standard_charge, setting, payer_category, hcpcs_cpt, ms_drg, rev_code, hospital_id]
# Index: []

# %%
id_mapping = {
 '344428256_toledo-hospital_standardcharges copy.json': '360074',
 '341883132_bay-park-hospital_standardcharges.json': '360259',
 '344446484_defiance-regional-hospital_standardcharges.json': '361328',
 '344428256_toledo-hospital_standardcharges.json': '360068',
 '340898745_fostoria-community-hospital_standardcharges.json': '361318',
 '344430849_memorial-hospital_standardcharges.json': '360156',
 '382796005_charles-and-virginia-hickman-hospital_standardcharges.json': '230005',
 '386108110_coldwater-regional-hospital_standardcharges.json': '230022',
 '381984289_monroe-regional-hospital_standardcharges.json': '230099'}

hosp_id = id_mapping[file]

df['hospital_id'] = hosp_id

out_file = hosp_id + file.split('_')[1] + '.csv'

out_folder = '.\\output_files\\'

# df.to_csv(out_folder + out_file, index=False)

# %%
df[df.duplicated(subset=['payer_name','description','code','setting','payer_category','hcpcs_cpt','ms_drg','rev_code'], keep=False)]
# Out:
#                          payer_name
# 3063   UNITED HEALTHCARE Commercial  \
# 3064   UNITED HEALTHCARE Commercial
# 3099   UNITED HEALTHCARE Commercial
# 3100   UNITED HEALTHCARE Commercial
# 12261                  Gross_Charge
# ...                             ...
# 60891      DeIdentified_Max_Allowed
# 60892      DeIdentified_Max_Allowed
# 60893      DeIdentified_Max_Allowed
# 60894      DeIdentified_Max_Allowed
# 60895      DeIdentified_Max_Allowed
#
#                                              description   code
# 3063                           Replacement Of Knee Joint    469  \
# 3064                           Replacement Of Knee Joint    470
# 3099                           Replacement Of Knee Joint    469
# 3100                           Replacement Of Knee Joint    470
# 12261  Lab Test - Identification of DNA from 22 Patho...  0097U
# ...                                                  ...    ...
# 60891  Lab Test - COVID-19 Test Panel By Non-CDC Lab ...  U0004
# 60892  Lab Test - COVID-19 Test Panel By Non-CDC Lab ...  U0004
# 60893  Lab Test - COVID-19 Test Panel By Non-CDC Lab ...  U0004
# 60894  Lab Test - COVID-19 Test Panel By Non-CDC Lab ...  U0004
# 60895  Lab Test - COVID-19 Test Panel By Non-CDC Lab ...  U0004
#
#       standard_charge     setting payer_category hcpcs_cpt ms_drg rev_code
# 3063        2125.4000   inpatient          payer       NaN    469      NaN  \
# 3064        2125.4000   inpatient          payer       NaN    470      NaN
# 3099        1625.2000   inpatient          payer       NaN    469      NaN
# 3100        1625.2000   inpatient          payer       NaN    470      NaN
# 12261        800.0000  outpatient          gross     0097U    NaN      NaN
# ...               ...         ...            ...       ...    ...      ...
# 60891        305.5500  outpatient            max     U0004    NaN      NaN
# 60892        305.5500  outpatient            max     U0004    NaN      NaN
# 60893        305.5500  outpatient            max     U0004    NaN      NaN
# 60894        305.5500  outpatient            max     U0004    NaN      NaN
# 60895        305.5500  outpatient            max     U0004    NaN      NaN
#
#       hospital_id
# 3063       360156
# 3064       360156
# 3099       360156
# 3100       360156
# 12261      360156
# ...           ...
# 60891      360156
# 60892      360156
# 60893      360156
# 60894      360156
# 60895      360156
#
# [37751 rows x 10 columns]

# %%
file.split('_')
# Out:
# ['344430849', 'memorial-hospital', 'standardcharges.json']
