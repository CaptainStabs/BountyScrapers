# %%
import pandas as pd

# %%
df = pd.read_csv(".\\output_files\\lawrencecountyhospital.csv", dtype={'rate': float})
# Out:
# \Local\Temp\ipykernel_168404\1018587341.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(".\\output_files\\lawrencecountyhospital.csv", dtype={'rate': float})

# %%
pk_cols = ['hospital_ein','hospital_ccn','rev_code','internal_code','code_type','code','modifier','ndc','apc','billing_class','patient_class','billed_quantity','payer_orig','plan_orig']
pk_cols = [x for x in pk_cols if x in df.columns]

dp_rows = df[df.duplicated(subset=pk_cols, keep=False)]

# %%
dp_rows.sample(20)
# Out:
#       code_prefix                              description   code modifier  \
# 93830   hcpcs_cpt                                MEROPENEM  J2185       na
# 2013    hcpcs_cpt                         GTT, 3 SPECIMENS  82951       na
# 97416   hcpcs_cpt             OPEN TX DPRSD FRONT SINUS FX  21343       na
# 79693   hcpcs_cpt                     ECHO EXAM OF ABDOMEN  76705       na
# 17319   hcpcs_cpt        CULTURE, FUNGUS(NOT BLD,SK,HAIR/N  87102       na
# 9776    hcpcs_cpt              REMOVE IMPACTED EAR WAX UNI  69209       na
# 26142   hcpcs_cpt                   URINE BACTERIA CULTURE  87088       na
# 22554   hcpcs_cpt                     PROGESTERONE (MPGSN)  84144       na
# 30831   hcpcs_cpt           MRI ANY JOIN UP EXT WO/W BILAT  73223       na
# 32080   hcpcs_cpt          DEV OF COG SKILLS EA ADD 15 MIN  97130       na
# 70776   hcpcs_cpt            CARDIOLIPIN AB,EACH-CHRG ONLY  86147       na
# ...
