# %%
import pandas as pd

# %%
pd.set_option('display.min_rows', 20)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv(".\\output_files\\264827222_360359.csv", dtype=str, low_memory=False)

pk_cols = ['hospital_id', 'rev_code', 'local_code', 'ms_drg', 'apr_drg', 'hcpcs_cpt', 'modifiers', 'ndc', 'billing_class', 'setting', 'payer_name', 'plan', 'description', 'standard_charge']
pk_cols = [x for x in pk_cols if x in df.columns]

# create a style object with background color yellow for pk columns
dp_rows = df[df.duplicated(subset=pk_cols, keep=False)]

dp_rows.sort_values(pk_cols, inplace=True)
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_4486984\2545700747.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp_rows.sort_values(pk_cols, inplace=True)

# %%
df[df.duplicated]
# Out:
#                      payer_name
# 15919          Avg_Gross_Charge  \
# 15920          Avg_Gross_Charge
# 15922          Avg_Gross_Charge
# 15923          Avg_Gross_Charge
# 15925          Avg_Gross_Charge
# 15926          Avg_Gross_Charge
# 15951          Avg_Gross_Charge
# 15952          Avg_Gross_Charge
# 15953          Avg_Gross_Charge
# 15954          Avg_Gross_Charge
# ...                         ...
# 54985  DeIdentified_Max_Allowed
# 54986  DeIdentified_Max_Allowed
# 54987  DeIdentified_Max_Allowed
# 54988  DeIdentified_Max_Allowed
# 54989  DeIdentified_Max_Allowed
# 54990  DeIdentified_Max_Allowed
# 54991  DeIdentified_Max_Allowed
# 54992  DeIdentified_Max_Allowed
# 54993  DeIdentified_Max_Allowed
# 54994  DeIdentified_Max_Allowed
#
#                                                 description   code
# 15919          CAT Scan Of Abdomen And Pelvis With Contrast  74178  \
# 15920          CAT Scan Of Abdomen And Pelvis With Contrast  74177
# ...
