# %%
import pandas as pd
import datetime as dt

df = pd.read_json('F:\\_Bounty\\581954432_northsidehospitalatlanta_standardcharges.json', encoding='UTF-16')

# %%
df.rename(columns={
    "prices posted and effective": "file_last_updated",
    "code description": "code_desc",
    "payer": "plan_name",
}, inplace=True)

# %%
df["file_last_updated"] = pd.to_datetime(df["file_last_updated"])

# %%
df
# Out:
#                              name file_last_updated   code  \
# 0      Northside Hospital Atlanta        2022-07-05  0001A
# 1      Northside Hospital Atlanta        2022-07-05  0002A
# 2      Northside Hospital Atlanta        2022-07-05  0202U
# 3      Northside Hospital Atlanta        2022-07-05  10030
# 4      Northside Hospital Atlanta        2022-07-05  19000
# ...                           ...               ...    ...
# 37006  Northside Hospital Atlanta        2022-07-05    172
# 37007  Northside Hospital Atlanta        2022-07-05    173
# 37008  Northside Hospital Atlanta        2022-07-05    174
# 37009  Northside Hospital Atlanta        2022-07-05    200
# 37010  Northside Hospital Atlanta        2022-07-05    206
#
#                                    code_desc      payer gross charge  \
# 0               ADM SARSCOV2 30MCG/0.3ML 1ST  AETNA HMO           48
# 1               ADM SARSCOV2 30MCG/0.3ML 2ND  AETNA HMO  0.008713137
# ...
