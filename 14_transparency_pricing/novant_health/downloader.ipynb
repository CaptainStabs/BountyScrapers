# %%
import pandas as pd
import requests
from tqdm import tqdm

tqdm = tqdm.pandas()

# %%
df = pd.read_csv('hospitals.csv', dtype=str)

# %%
def download_file(url):
    filename = url.split('/')[-1]
    r = requests.get(url, stream=True).content
    
    with open('.\\input_files\\' + filename, 'wb') as f:
        f.write(r)

# %%
df['mrf_url'].progress_apply(download_file)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# 100%|██████████| 12/12 [00:07<00:00,  1.52it/s]
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# Name: mrf_url, dtype: object

# %%
ein_ccn_dict = dict(zip(df['file_name'], df['id']))
ein_ccn_dict
# Out:
# {'20-4278130_novanthealthbrunswickmedicalcenter_standardcharges.csv': '340158',
#  '56-0554230_novanthealthcharlotteorthopedichospital_standardcharges.csv': '340153',
#  '56-0928089_novanthealthforsythmedicalcenter_standardcharges.csv': '340014',
#  '56-0554230_novanthealthhuntersvillemedicalcenter_standardcharges.csv': '340183',
#  '56-1376368_novanthealthmatthewsmedicalcenter_standardcharges.csv': '340171',
#  '56-1340424_novanthealthmedicalparkhospital_standardcharges.csv': '340148',
#  '26-0599536_novanthealthminthillmedicalcenter_standardcharges.csv': '340190',
#  '56-0887181_novanthealthnewhanorverregionalmedicalcenter_standardcharges.csv': '340141',
#  '56-0653348_novanthealthpendermemorialhospital_standardcharges.csv': '341307',
#  '56-0554230_novanthealthpresbyterianmedicalcenter_standardcharges.csv': '340053',
#  '56-0547479_novanthealthrowanmedicalcenter_standardcharges.csv': '340015',
#  '56-0636250_novanthealththomasvillemedicalcenter_standardcharges.csv': '340085'}

# %%
df
# Out:
#         id         ein                                            mrf_url
# 0   340158  20-4278130  https://www.novanthealth.org/globalassets/butt...  \
# 1   340153  56-0554230  https://www.novanthealth.org/globalassets/butt...
# 2   340014  56-0928089  https://www.novanthealth.org/globalassets/butt...
# 3   340183  56-0554230  https://www.novanthealth.org/globalassets/butt...
# 4   340171  56-1376368  https://www.novanthealth.org/globalassets/butt...
# 5   340148  56-1340424  https://www.novanthealth.org/globalassets/butt...
# 6   340190  26-0599536  https://www.novanthealth.org/globalassets/butt...
# 7   340141  56-0887181  https://www.novanthealth.org/globalassets/butt...
# 8   341307  56-0653348  https://www.novanthealth.org/globalassets/butt...
# 9   340053  56-0554230  https://www.novanthealth.org/globalassets/butt...
# 10  340015  56-0547479  https://www.novanthealth.org/globalassets/butt...
# 11  340085  56-0636250  https://www.novanthealth.org/globalassets/butt...
#
#                                                  name
# 0              NOVANT HEALTH BRUNSWICK MEDICAL CENTER  \
# 1         NOVANT HEALTH CHARLOTTE ORTHOPEDIC HOSPITAL
# 2                NOVANT HEALTH FORSYTH MEDICAL CENTER
# 3           NOVANT HEALTH HUNTERSVILLE MEDICAL CENTER
# 4               NOVANT HEALTH MATTHEWS MEDICAL CENTER
# 5                 NOVANT HEALTH MEDICAL PARK HOSPITAL
# 6              NOVANT HEALTH MINT HILL MEDICAL CENTER
# 7   NOVANT HEALTH NEW HANOVER REGIONAL MEDICAL CENTER
# 8                            PENDER MEMORIAL HOSPITAL
# 9           NOVANT HEALTH PRESBYTERIAN MEDICAL CENTER
# 10                 NOVANT HEALTH ROWAN MEDICAL CENTER
# 11           NOVANT HEALTH THOMASVILLE MEDICAL CENTER
#
#                                              alt_name    system_name
# 0              Novant Health Brunswick Medical Center  Novant Health  \
# 1        Novant Health Charlotte Orthopaedic Hospital            NaN
# 2   Novant Health Forsyth Medical Center - Winston...  Novant Health
# 3           Novant Health Huntersville Medical Center  Novant Health
# 4               Novant Health Matthews Medical Center  Novant Health
# 5   Novant Health Medical Park Hospital - Winston-...            NaN
# 6              Novant Health Mint Hill Medical Center            NaN
# 7   Novant Health New Hanover Regional Medical Center  Novant Health
# 8                 Novant Health Pender Medical Center            NaN
# 9           Novant Health Presbyterian Medical Center  Novant Health
# 10                 Novant Health Rowan Medical Center  Novant Health
# 11           Novant Health Thomasville Medical Center  Novant Health
#
#                                    addr           city state    zip
# 0       1 MEDICAL CENTER DR  PO BOX 139         SUPPLY    NC  28462  \
# 1                      1901 RANDOLPH RD      CHARLOTTE    NC  28207
# 2              3333 SILAS CREEK PARKWAY  WINSTON-SALEM    NC  27103
# 3                     10030 GILEAD ROAD   HUNTERSVILLE    NC  28078
# 4   1500 MATTHEWS TWNSHP PRKWY BOX 3310       MATTHEWS    NC  28106
# 5                   1950 S HAWTHORNE RD  WINSTON-SALEM    NC  27103
# 6                  8201 HEALTHCARE LOOP      CHARLOTTE    NC  28215
# 7               2131 S 17TH ST BOX 9000     WILMINGTON    NC  28402
# 8                      507 E FREMONT ST         BURGAW    NC  28425
# 9          200 HAWTHORNE LANE BOX 33549      CHARLOTTE    NC  28233
# 10                   612 MOCKSVILLE AVE      SALISBURY    NC  28144
# 11         207 OLD LEXINGTON RD BOX 789    THOMASVILLE    NC  27360
#
#          phone urban_rural                   category
# 0   9107558121           U                 Short Term  \
# 1   7043162000           U                 Short Term
# 2   3367185000           U                 Short Term
# 3   7043164000           U                 Short Term
# 4   7043846500           U                 Short Term
# 5   3367180600           U                 Short Term
# 6   7043844089           U                 Short Term
# 7   9103437000           U                 Short Term
# 8   9103004004           U  Critical Access Hospitals
# 9   7043844000           U                 Short Term
# 10  7042105000           U                 Short Term
# 11  3364722000           U                 Short Term
#
#                 control_type medicare_termination_status last_updated
# 0   FOR PROFIT - CORPORATION             ACTIVE PROVIDER   2022-12-31  \
# 1   FOR PROFIT - CORPORATION   VOLUNTARY-MERGER, CLOSURE   2022-12-31
# 2   FOR PROFIT - PARTNERSHIP             ACTIVE PROVIDER   2022-12-31
# 3   FOR PROFIT - PARTNERSHIP             ACTIVE PROVIDER   2022-12-31
# 4   FOR PROFIT - CORPORATION             ACTIVE PROVIDER   2022-12-31
# 5   FOR PROFIT - CORPORATION             ACTIVE PROVIDER   2022-12-31
# 6   FOR PROFIT - PARTNERSHIP             ACTIVE PROVIDER   2022-12-31
# 7         GOVERNMENT - STATE             ACTIVE PROVIDER   2022-12-31
# 8         GOVERNMENT - STATE             ACTIVE PROVIDER   2022-12-31
# 9   FOR PROFIT - PARTNERSHIP             ACTIVE PROVIDER   2022-12-31
# 10  FOR PROFIT - PARTNERSHIP             ACTIVE PROVIDER   2022-12-31
# 11  FOR PROFIT - PARTNERSHIP             ACTIVE PROVIDER   2022-12-31
#
#                                             file_name permalink
# 0   20-4278130_novanthealthbrunswickmedicalcenter_...       NaN  \
# 1   56-0554230_novanthealthcharlotteorthopedichosp...       NaN
# 2   56-0928089_novanthealthforsythmedicalcenter_st...       NaN
# 3   56-0554230_novanthealthhuntersvillemedicalcent...       NaN
# 4   56-1376368_novanthealthmatthewsmedicalcenter_s...       NaN
# 5   56-1340424_novanthealthmedicalparkhospital_sta...       NaN
# 6   26-0599536_novanthealthminthillmedicalcenter_s...       NaN
# 7   56-0887181_novanthealthnewhanorverregionalmedi...       NaN
# 8   56-0653348_novanthealthpendermemorialhospital_...       NaN
# 9   56-0554230_novanthealthpresbyterianmedicalcent...       NaN
# 10  56-0547479_novanthealthrowanmedicalcenter_stan...       NaN
# 11  56-0636250_novanthealththomasvillemedicalcente...       NaN
#
#                                     transparency_page additional_notes
# 0   https://www.novanthealth.org/for-patients/bill...              NaN
# 1   https://www.novanthealth.org/for-patients/bill...              NaN
# 2   https://www.novanthealth.org/for-patients/bill...              NaN
# 3   https://www.novanthealth.org/for-patients/bill...              NaN
# 4   https://www.novanthealth.org/for-patients/bill...              NaN
# 5   https://www.novanthealth.org/for-patients/bill...              NaN
# 6   https://www.novanthealth.org/for-patients/bill...              NaN
# 7   https://www.novanthealth.org/for-patients/bill...              NaN
# 8   https://www.novanthealth.org/for-patients/bill...              NaN
# 9   https://www.novanthealth.org/for-patients/bill...              NaN
# 10  https://www.novanthealth.org/for-patients/bill...              NaN
# 11  https://www.novanthealth.org/for-patients/bill...              NaN
