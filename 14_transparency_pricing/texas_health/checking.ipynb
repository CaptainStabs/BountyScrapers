# %%
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
folder = 'G:\\transparency-in-pricing\\output_files\\'

file = '450743_presbyterian-hospital-denton.csv'

# %%
df = pd.read_csv(folder + file, dtype=str)

# %%
len(df)
# Out:
# 6513719

# %%
df.loc[~df['apr_drg'].isna()]
# Out:
#                                                description contracting_method
# 265497   TRACHEOSTOMY WITH MV >96 HOURS WITH EXTENSIVE ...          case rate  \
# 265498   TRACHEOSTOMY WITH MV >96 HOURS WITH EXTENSIVE ...          case rate
# 265499   TRACHEOSTOMY WITH MV >96 HOURS WITH EXTENSIVE ...          case rate
# 265500   TRACHEOSTOMY WITH MV >96 HOURS WITH EXTENSIVE ...          case rate
# 265501   TRACHEOSTOMY WITH MV >96 HOURS WITHOUT EXTENSI...          case rate
# ...                                                    ...                ...
# 6363829  MODERATELY EXTENSIVE O.R. PROCEDURE UNRELATED ...          case rate
# 6363830  NON-EXTENSIVE O.R. PROCEDURE UNRELATED TO PRIN...          case rate
# 6363831  NON-EXTENSIVE O.R. PROCEDURE UNRELATED TO PRIN...          case rate
# 6363832  NON-EXTENSIVE O.R. PROCEDURE UNRELATED TO PRIN...          case rate
# 6363833  NON-EXTENSIVE O.R. PROCEDURE UNRELATED TO PRIN...          case rate
#
# ...
