# %%
import pandas as pd
import numpy as np

# %%
folder = '.\\input_files\\'
file = '930223960_AsanteRogueRegionalMedicalCenter_Standardcharges.csv'

# %%
df = pd.read_csv(folder + file, dtype=str, encoding='ansi')

# %%
df.drop(columns='Location', inplace=True)

# %%
df.rename(columns={
    'Procedure': 'local_code',
    'Code Type': 'line_type', 
    'Code': 'code',
    'NDC': 'ndc',
    'Rev Code': 'rev_code',
    'Procedure Description': 'description',
    'Quantity': 'quantity',
    'Payer': 'payer_name', 
    'Plan(s)': 'plan_name'
}, inplace=True)

# %%
df['rev_code'] = df['rev_code'].str.split(' -').str[0]

# %%
df.loc[df['quantity'] == "1", 'quantity'] = pd.NA

# %%
cols = df.columns.tolist()
id_vars = cols[:9]
value_vars = ['IP Expected Reimbursement', 'OP Expected Reimbursement']

payer_df = pd.melt(df, id_vars=id_vars, value_vars=value_vars, var_name='payer_temp', value_name='standard_charge')

# %%
df.drop(columns=['payer_name', 'plan_name', 'IP Expected Reimbursement', 'OP Expected Reimbursement'], inplace=True)

# %%
cols = df.columns.tolist()
id_vars = cols[:7]
value_vars = cols[7:]

df = pd.melt(df, id_vars=id_vars, value_vars=value_vars, var_name='payer_name', value_name='standard_charge')

# %%
df = pd.concat([df, payer_df])

# %%
df['setting'] = np.where(df['payer_name'].str.startswith('IP'), 'inpatient', np.where(df['payer_name'].str.startswith('OP'), 'outpatient', 1))
df['setting'] = np.where(df['payer_temp'].str.startswith('IP'), 'inpatient', np.where(df['payer_temp'].str.startswith('OP'), 'outpatient', 1))

# %%
df
# Out:
#        local_code line_type           code            ndc rev_code
# 0           MS783       DRG          MS783            NaN      NaN  \
# 1           MS784       DRG          MS784            NaN      NaN
# 2           MS785       DRG          MS785            NaN      NaN
# 3           MS786       DRG          MS786            NaN      NaN
# 4           MS787       DRG          MS787            NaN      NaN
# ...           ...       ...            ...            ...      ...
# 334399       9974       ERX    HCPCS J7512  00046-1102-81     0250
# 334400      99754       ERX  HCPCS 2500003  00456-2405-11     0250
# 334401       9977       ERX  HCPCS 2500003  00046-0872-21     0250
# 334402       9982       ERX  HCPCS 2500003  54879-0001-01     0250
# 334403       9983       ERX  HCPCS 2500003  54879-0002-01     0250
#
#                                               description          quantity
# 0            Cesarean Section With Sterilization With McC               NaN  \
# 1             Cesarean Section With Sterilization With Cc               NaN
# 2       Cesarean Section With Sterilization Without Cc...               NaN
# 3         Cesarean Section Without Sterilization With McC               NaN
# 4          Cesarean Section Without Sterilization With Cc               NaN
# ...                                                   ...               ...
# 334399               CONJUGATED ESTROGENS 0.625 MG TABLET        0.5 tablet
# 334400                   ASENAPINE 5 MG SUBLINGUAL TABLET          1 tablet
# 334401   CONJUGATED ESTROGENS 0.625 MG/GRAM VAGINAL CREAM  60 Applicatorful
# 334402                           ETHAMBUTOL 100 MG TABLET          8 tablet
# 334403                           ETHAMBUTOL 400 MG TABLET          2 tablet
#
#         payer_name standard_charge   plan_name                 payer_temp
# 0         IP Price       32,996.83         NaN                        NaN  \
# 1         IP Price       40,323.75         NaN                        NaN
# 2         IP Price       27,123.45         NaN                        NaN
# 3         IP Price       40,926.46         NaN                        NaN
# 4         IP Price       36,724.63         NaN                        NaN
# ...            ...             ...         ...                        ...
# 334399  <Self-pay>          16.315  <Self-pay>  OP Expected Reimbursement
# 334400  <Self-pay>         102.232  <Self-pay>  OP Expected Reimbursement
# 334401  <Self-pay>         873.665  <Self-pay>  OP Expected Reimbursement
# 334402  <Self-pay>          36.816  <Self-pay>  OP Expected Reimbursement
# 334403  <Self-pay>            9.49  <Self-pay>  OP Expected Reimbursement
#
#            setting
# 0        inpatient
# 1        inpatient
# 2        inpatient
# 3        inpatient
# 4        inpatient
# ...            ...
# 334399  outpatient
# 334400  outpatient
# 334401  outpatient
# 334402  outpatient
# 334403  outpatient
#
# [1337616 rows x 12 columns]

# %%
payer_mapping = {
    'IP Price': 'gross',
    'IP De-Identified MIN': 'min',
    'IP De-Identified MAX': 'max',
    'OP Price': 'gross',   
    'OP De-Identified MIN': 'min',
    'OP De-Identified MAX': 'max',
    '<Self-pay>': 'cash',
    'De-Identified IP MIN': 'min',
    'De-Identified IP MAX': 'max',
    'De-Identified OP MIN': 'min',
    'De-Identified OP MAX': 'max'   
    
}

df['payer_category'] = df['payer_name'].map(payer_mapping)

# %%
df.loc[df['payer_name'] == '<Self-pay>', 'payer_category'] = 'cash'

# %%
df.loc[~df['payer_temp'].isna(), 'payer_category'] = 'payer'

# %%
# df.drop(columns='payer_temp', inplace=True)

# %%
df['code'] = df['code'].str.strip()

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.loc[~df['code'].isna() & df['code'].str.match(r"MS\d{3}"), 'ms_drg'] = df['code'].str.replace('MS', '')

# %%
df['ms_drg'] = df['ms_drg'].astype(str)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.loc[~df['code'].isna() & df['code'].str.startswith('HCPCS '), 'hcpcs_cpt'] = df['code'].str.replace('HCPCS ', '')
df.loc[~df['code'].isna() & df['code'].str.startswith('CPT® '), 'hcpcs_cpt'] = df['code'].str.replace('CPT® ', '')

# %%
df.loc[df['hcpcs_cpt'].str.len() == 7, 'hcpcs_cpt'] = pd.NA

# %%
df.loc[df['hcpcs_cpt'] == 'SART', ['hcpcs_cpt', 'alt_hcpcs_cpt']] = [pd.NA, 'SART']

mask = ~df['hcpcs_cpt'].fillna('').isna() & ~(df['hcpcs_cpt'].fillna('').str.match(r'^[A-Z][0-9]{4}$|^[0-9]{5}$|^[0-9]{4}[A-Z]$'))
df.loc[mask, 'alt_hcpcs_cpt'] = df['hcpcs_cpt']
df.loc[mask, 'hcpcs_cpt'] = pd.NA

# %%
df.loc[df['hcpcs_cpt'] == 'SART']
# Out:
# Empty DataFrame
# Columns: [local_code, line_type, code, ndc, rev_code, description, quantity, payer_name, standard_charge, plan_name, payer_temp, setting, payer_category, ms_drg, hcpcs_cpt, alt_hcpcs_cpt]
# Index: []

# %%
df.loc[~df['plan_name'].isna() & df['plan_name'].str.contains(',')]
# Out:
#         local_code line_type           code            ndc rev_code
# 1086811      MS783       DRG          MS783            NaN      NaN  \
# 1086816      MS784       DRG          MS784            NaN      NaN
# 1086821      MS785       DRG          MS785            NaN      NaN
# 1086826      MS786       DRG          MS786            NaN      NaN
# 1086831      MS787       DRG          MS787            NaN      NaN
# ...            ...       ...            ...            ...      ...
# 1312532       9974       ERX    HCPCS J7512  00046-1102-81     0250
# 1312533      99754       ERX  HCPCS 2500003  00456-2405-11     0250
# 1312534       9977       ERX  HCPCS 2500003  00046-0872-21     0250
# 1312535       9982       ERX  HCPCS 2500003  54879-0001-01     0250
# 1312536       9983       ERX  HCPCS 2500003  54879-0002-01     0250
#
#                                                description          quantity
# 1086811       Cesarean Section With Sterilization With McC               NaN  \
# 1086816        Cesarean Section With Sterilization With Cc               NaN
# 1086821  Cesarean Section With Sterilization Without Cc...               NaN
# 1086826    Cesarean Section Without Sterilization With McC               NaN
# 1086831     Cesarean Section Without Sterilization With Cc               NaN
# ...                                                    ...               ...
# 1312532               CONJUGATED ESTROGENS 0.625 MG TABLET        0.5 tablet
# 1312533                   ASENAPINE 5 MG SUBLINGUAL TABLET          1 tablet
# 1312534   CONJUGATED ESTROGENS 0.625 MG/GRAM VAGINAL CREAM  60 Applicatorful
# 1312535                           ETHAMBUTOL 100 MG TABLET          8 tablet
# 1312536                           ETHAMBUTOL 400 MG TABLET          2 tablet
#
#                                           payer_name standard_charge
# 1086811                PROVIDENCE HEALTH PLAN [1078]       31,913.86  \
# 1086816                PROVIDENCE HEALTH PLAN [1078]       18,728.48
# 1086821                PROVIDENCE HEALTH PLAN [1078]       15,790.66
# 1086826                PROVIDENCE HEALTH PLAN [1078]       26,895.56
# 1086831                PROVIDENCE HEALTH PLAN [1078]       18,208.82
# ...                                              ...             ...
# 1312532  LIBERTY HEALTHSHARE MEDSOLUTIONS LLC [1159]           20.08
# 1312533  LIBERTY HEALTHSHARE MEDSOLUTIONS LLC [1159]          125.82
# 1312534  LIBERTY HEALTHSHARE MEDSOLUTIONS LLC [1159]        1,075.28
# 1312535  LIBERTY HEALTHSHARE MEDSOLUTIONS LLC [1159]           45.31
# 1312536  LIBERTY HEALTHSHARE MEDSOLUTIONS LLC [1159]           11.68
#
#                                                  plan_name
# 1086811  PEBB [100100], PEBB PROVIDENCE CHOICE MEDICAL ...  \
# 1086816  PEBB [100100], PEBB PROVIDENCE CHOICE MEDICAL ...
# 1086821  PEBB [100100], PEBB PROVIDENCE CHOICE MEDICAL ...
# 1086826  PEBB [100100], PEBB PROVIDENCE CHOICE MEDICAL ...
# 1086831  PEBB [100100], PEBB PROVIDENCE CHOICE MEDICAL ...
# ...                                                    ...
# 1312532         LIBERTY HEALTHSHARE MEDSOLUTIONS, LLC [29]
# 1312533         LIBERTY HEALTHSHARE MEDSOLUTIONS, LLC [29]
# 1312534         LIBERTY HEALTHSHARE MEDSOLUTIONS, LLC [29]
# 1312535         LIBERTY HEALTHSHARE MEDSOLUTIONS, LLC [29]
# 1312536         LIBERTY HEALTHSHARE MEDSOLUTIONS, LLC [29]
#
#                         payer_temp     setting payer_category ms_drg
# 1086811  IP Expected Reimbursement   inpatient          payer    783  \
# 1086816  IP Expected Reimbursement   inpatient          payer    784
# 1086821  IP Expected Reimbursement   inpatient          payer    785
# 1086826  IP Expected Reimbursement   inpatient          payer    786
# 1086831  IP Expected Reimbursement   inpatient          payer    787
# ...                            ...         ...            ...    ...
# 1312532  OP Expected Reimbursement  outpatient          payer    nan
# 1312533  OP Expected Reimbursement  outpatient          payer    nan
# 1312534  OP Expected Reimbursement  outpatient          payer    nan
# 1312535  OP Expected Reimbursement  outpatient          payer    nan
# 1312536  OP Expected Reimbursement  outpatient          payer    nan
#
#         hcpcs_cpt alt_hcpcs_cpt
# 1086811       NaN           NaN
# 1086816       NaN           NaN
# 1086821       NaN           NaN
# 1086826       NaN           NaN
# 1086831       NaN           NaN
# ...           ...           ...
# 1312532     J7512           NaN
# 1312533      <NA>           NaN
# 1312534      <NA>           NaN
# 1312535      <NA>           NaN
# 1312536      <NA>           NaN
#
# [50162 rows x 16 columns]

# %%
df = df.assign(plan_name=df['plan_name'].str.split(', ')).explode('plan_name')

# %%
df['payer_category'] = df['payer_name'].map(payer_mapping).fillna('payer')

# %%
if file == '930223960_AsanteRogueRegionalMedicalCenter_Standardcharges.csv':
    df['setting'] = np.where(df['payer_name'].str.contains('IP'), 'inpatient', np.where(df['payer_name'].str.contains('OP'), 'outpatient', 1))
    df['setting'] = np.where(df['payer_temp'].notnull() & df['payer_temp'].str.contains('IP'), 'inpatient', np.where(df['payer_temp'].notnull() & df['payer_temp'].str.contains('OP'), 'outpatient', df['setting']))
else:
    df['setting'] = np.where(df['payer_name'].str.startswith('IP'), 'inpatient', np.where(df['payer_name'].str.startswith('OP'), 'outpatient', 1))
    df['setting'] = np.where(df['payer_temp'].notnull() & df['payer_temp'].str.startswith('IP'), 'inpatient', np.where(df['payer_temp'].notnull() & df['payer_temp'].str.startswith('OP'), 'outpatient', df['setting']))

# %%
df.drop_duplicates(subset=['payer_name', 'payer_temp'])
# Out:
#         local_code line_type   code  ndc rev_code
# 0            MS783       DRG  MS783  NaN      NaN  \
# 167202       MS783       DRG  MS783  NaN      NaN
# 334404       MS783       DRG  MS783  NaN      NaN
# 501606       MS783       DRG  MS783  NaN      NaN
# 668808       MS783       DRG  MS783  NaN      NaN
# 836010       MS783       DRG  MS783  NaN      NaN
# 1003212      MS783       DRG  MS783  NaN      NaN
# 1011571      MS783       DRG  MS783  NaN      NaN
# 1019930      MS783       DRG  MS783  NaN      NaN
# 1028289      MS783       DRG  MS783  NaN      NaN
# 1036648      MS783       DRG  MS783  NaN      NaN
# 1045007      MS783       DRG  MS783  NaN      NaN
# 1078451      MS783       DRG  MS783  NaN      NaN
# 1086810      MS783       DRG  MS783  NaN      NaN
# 1128615      MS783       DRG  MS783  NaN      NaN
# 1136976      MS783       DRG  MS783  NaN      NaN
# 1145335      MS783       DRG  MS783  NaN      NaN
# 1153694      MS783       DRG  MS783  NaN      NaN
# 1162053      MS783       DRG  MS783  NaN      NaN
# 1170414      MS783       DRG  MS783  NaN      NaN
# 1178773      MS783       DRG  MS783  NaN      NaN
# 1187132      MS783       DRG  MS783  NaN      NaN
# 1195491      MS783       DRG  MS783  NaN      NaN
# 1203850      MS783       DRG  MS783  NaN      NaN
# 1212209      MS783       DRG  MS783  NaN      NaN
# 1245653      MS783       DRG  MS783  NaN      NaN
# 1254012      MS783       DRG  MS783  NaN      NaN
# 1295817      MS783       DRG  MS783  NaN      NaN
# 1304178      MS783       DRG  MS783  NaN      NaN
# 1312537      MS783       DRG  MS783  NaN      NaN
# 1320896      MS783       DRG  MS783  NaN      NaN
# 1329255      MS783       DRG  MS783  NaN      NaN
#
#                                           description quantity
# 0        Cesarean Section With Sterilization With McC     <NA>  \
# 167202   Cesarean Section With Sterilization With McC     <NA>
# 334404   Cesarean Section With Sterilization With McC     <NA>
# 501606   Cesarean Section With Sterilization With McC     <NA>
# 668808   Cesarean Section With Sterilization With McC     <NA>
# 836010   Cesarean Section With Sterilization With McC     <NA>
# 1003212  Cesarean Section With Sterilization With McC     <NA>
# 1011571  Cesarean Section With Sterilization With McC     <NA>
# 1019930  Cesarean Section With Sterilization With McC     <NA>
# 1028289  Cesarean Section With Sterilization With McC     <NA>
# 1036648  Cesarean Section With Sterilization With McC     <NA>
# 1045007  Cesarean Section With Sterilization With McC     <NA>
# 1078451  Cesarean Section With Sterilization With McC     <NA>
# 1086810  Cesarean Section With Sterilization With McC     <NA>
# 1128615  Cesarean Section With Sterilization With McC     <NA>
# 1136976  Cesarean Section With Sterilization With McC     <NA>
# 1145335  Cesarean Section With Sterilization With McC     <NA>
# 1153694  Cesarean Section With Sterilization With McC     <NA>
# 1162053  Cesarean Section With Sterilization With McC     <NA>
# 1170414  Cesarean Section With Sterilization With McC     <NA>
# 1178773  Cesarean Section With Sterilization With McC     <NA>
# 1187132  Cesarean Section With Sterilization With McC     <NA>
# 1195491  Cesarean Section With Sterilization With McC     <NA>
# 1203850  Cesarean Section With Sterilization With McC     <NA>
# 1212209  Cesarean Section With Sterilization With McC     <NA>
# 1245653  Cesarean Section With Sterilization With McC     <NA>
# 1254012  Cesarean Section With Sterilization With McC     <NA>
# 1295817  Cesarean Section With Sterilization With McC     <NA>
# 1304178  Cesarean Section With Sterilization With McC     <NA>
# 1312537  Cesarean Section With Sterilization With McC     <NA>
# 1320896  Cesarean Section With Sterilization With McC     <NA>
# 1329255  Cesarean Section With Sterilization With McC     <NA>
#
#                                           payer_name standard_charge
# 0                                           IP Price       32,996.83  \
# 167202                          De-Identified IP MIN        13198.73
# 334404                          De-Identified IP MAX        52122.22
# 501606                                      OP Price             NaN
# 668808                          De-Identified OP MIN             NaN
# 836010                          De-Identified OP MAX             NaN
# 1003212                                 AETNA [1002]       28,047.31
# 1011571                    ASANTE HEALTH PLAN [1014]       13,198.73
# 1019930                                 CIGNA [1025]       28,047.31
# 1028289                             HEALTHNET [1047]       28,047.31
# 1036648                                HUMANA [1051]       29,697.15
# 1045007                           MODA HEALTH [1070]       32,996.83
# 1078451                         PACIFICSOURCE [1072]       27,387.37
# 1086810                PROVIDENCE HEALTH PLAN [1078]       52,122.22
# 1128615                    REGENCE BLUE CROSS [1114]       32,996.83
# 1136976  LIBERTY HEALTHSHARE MEDSOLUTIONS LLC [1159]       26,397.46
# 1145335                     UNITED HEALTH ONE [1181]       29,697.15
# 1153694                         PACIFICSOURCE [1195]       25,902.51
# 1162053                                   <Self-pay>       21,447.94
# 1170414                                 AETNA [1002]             NaN
# 1178773                    ASANTE HEALTH PLAN [1014]             NaN
# 1187132                                 CIGNA [1025]             NaN
# 1195491                             HEALTHNET [1047]             NaN
# 1203850                                HUMANA [1051]             NaN
# 1212209                           MODA HEALTH [1070]             NaN
# 1245653                         PACIFICSOURCE [1072]             NaN
# 1254012                PROVIDENCE HEALTH PLAN [1078]             NaN
# 1295817                    REGENCE BLUE CROSS [1114]             NaN
# 1304178  LIBERTY HEALTHSHARE MEDSOLUTIONS LLC [1159]             NaN
# 1312537                     UNITED HEALTH ONE [1181]             NaN
# 1320896                         PACIFICSOURCE [1195]             NaN
# 1329255                                   <Self-pay>             NaN
#
#                                              plan_name
# 0                                                  NaN  \
# 167202                                             NaN
# 334404                                             NaN
# 501606                                             NaN
# 668808                                             NaN
# 836010                                             NaN
# 1003212                                 AETNA [100003]
# 1011571               ASANTE PPO HEALTH PLAN  [100389]
# 1019930                                 CIGNA [100344]
# 1028289           HEALTHNET COMMERCIAL CLAIMS [100662]
# 1036648                                HUMANA [100062]
# 1045007                        BEACON NETWORK [100426]
# 1078451             PACIFICSOURCE HEALTH PLAN [100092]
# 1086810          PROVIDENCE SIGNATURE NETWORK [100554]
# 1128615  PREFERRED PPO OR BLUECARD W SUITCASE [100272]
# 1136976               LIBERTY HEALTHSHARE MEDSOLUTIONS
# 1145335                     UNITED HEALTH ONE [100694]
# 1153694                SMARTHEATH/SMARTCHOICE [100753]
# 1162053                                     <Self-pay>
# 1170414                                 AETNA [100003]
# 1178773               ASANTE PPO HEALTH PLAN  [100389]
# 1187132                                 CIGNA [100344]
# 1195491           HEALTHNET COMMERCIAL CLAIMS [100662]
# 1203850                                HUMANA [100062]
# 1212209                        BEACON NETWORK [100426]
# 1245653             PACIFICSOURCE HEALTH PLAN [100092]
# 1254012          PROVIDENCE SIGNATURE NETWORK [100554]
# 1295817  PREFERRED PPO OR BLUECARD W SUITCASE [100272]
# 1304178               LIBERTY HEALTHSHARE MEDSOLUTIONS
# 1312537                     UNITED HEALTH ONE [100694]
# 1320896                SMARTHEATH/SMARTCHOICE [100753]
# 1329255                                     <Self-pay>
#
#                         payer_temp     setting payer_category ms_drg
# 0                              NaN   inpatient          gross    783  \
# 167202                         NaN   inpatient            min    783
# 334404                         NaN   inpatient            max    783
# 501606                         NaN  outpatient          gross    783
# 668808                         NaN  outpatient            min    783
# 836010                         NaN  outpatient            max    783
# 1003212  IP Expected Reimbursement   inpatient          payer    783
# 1011571  IP Expected Reimbursement   inpatient          payer    783
# 1019930  IP Expected Reimbursement   inpatient          payer    783
# 1028289  IP Expected Reimbursement   inpatient          payer    783
# 1036648  IP Expected Reimbursement   inpatient          payer    783
# 1045007  IP Expected Reimbursement   inpatient          payer    783
# 1078451  IP Expected Reimbursement   inpatient          payer    783
# 1086810  IP Expected Reimbursement   inpatient          payer    783
# 1128615  IP Expected Reimbursement   inpatient          payer    783
# 1136976  IP Expected Reimbursement   inpatient          payer    783
# 1145335  IP Expected Reimbursement   inpatient          payer    783
# 1153694  IP Expected Reimbursement   inpatient          payer    783
# 1162053  IP Expected Reimbursement   inpatient           cash    783
# 1170414  OP Expected Reimbursement  outpatient          payer    783
# 1178773  OP Expected Reimbursement  outpatient          payer    783
# 1187132  OP Expected Reimbursement  outpatient          payer    783
# 1195491  OP Expected Reimbursement  outpatient          payer    783
# 1203850  OP Expected Reimbursement  outpatient          payer    783
# 1212209  OP Expected Reimbursement  outpatient          payer    783
# 1245653  OP Expected Reimbursement  outpatient          payer    783
# 1254012  OP Expected Reimbursement  outpatient          payer    783
# 1295817  OP Expected Reimbursement  outpatient          payer    783
# 1304178  OP Expected Reimbursement  outpatient          payer    783
# 1312537  OP Expected Reimbursement  outpatient          payer    783
# 1320896  OP Expected Reimbursement  outpatient          payer    783
# 1329255  OP Expected Reimbursement  outpatient           cash    783
#
#         hcpcs_cpt alt_hcpcs_cpt
# 0            <NA>           NaN
# 167202       <NA>           NaN
# 334404       <NA>           NaN
# 501606       <NA>           NaN
# 668808       <NA>           NaN
# 836010       <NA>           NaN
# 1003212      <NA>           NaN
# 1011571      <NA>           NaN
# 1019930      <NA>           NaN
# 1028289      <NA>           NaN
# 1036648      <NA>           NaN
# 1045007      <NA>           NaN
# 1078451      <NA>           NaN
# 1086810      <NA>           NaN
# 1128615      <NA>           NaN
# 1136976      <NA>           NaN
# 1145335      <NA>           NaN
# 1153694      <NA>           NaN
# 1162053      <NA>           NaN
# 1170414      <NA>           NaN
# 1178773      <NA>           NaN
# 1187132      <NA>           NaN
# 1195491      <NA>           NaN
# 1203850      <NA>           NaN
# 1212209      <NA>           NaN
# 1245653      <NA>           NaN
# 1254012      <NA>           NaN
# 1295817      <NA>           NaN
# 1304178      <NA>           NaN
# 1312537      <NA>           NaN
# 1320896      <NA>           NaN
# 1329255      <NA>           NaN

# %%
df.loc[df['payer_category'].isna()]
# Out:
# Empty DataFrame
# Columns: [local_code, line_type, code, ndc, rev_code, description, quantity, payer_name, standard_charge, plan_name, payer_temp, setting, payer_category, ms_drg, hcpcs_cpt, alt_hcpcs_cpt]
# Index: []

# %%
df['standard_charge'] = df['standard_charge'].str.replace(',', '')

# %%
df.dropna(subset='standard_charge', inplace=True)

# %%
df.drop_duplicates(subset=['payer_category', 'payer_name'])
# Out:
#         local_code line_type        code  ndc rev_code
# 0            MS783       DRG       MS783  NaN      NaN  \
# 167202       MS783       DRG       MS783  NaN      NaN
# 334404       MS783       DRG       MS783  NaN      NaN
# 502318     3002160       EAP  CPT® 82523  NaN     0300
# 669520     3002160       EAP  CPT® 82523  NaN     0300
# 836722     3002160       EAP  CPT® 82523  NaN     0300
# 1003212      MS783       DRG       MS783  NaN      NaN
# 1011571      MS783       DRG       MS783  NaN      NaN
# 1019930      MS783       DRG       MS783  NaN      NaN
# 1028289      MS783       DRG       MS783  NaN      NaN
# 1036648      MS783       DRG       MS783  NaN      NaN
# 1045007      MS783       DRG       MS783  NaN      NaN
# 1078451      MS783       DRG       MS783  NaN      NaN
# 1086810      MS783       DRG       MS783  NaN      NaN
# 1128615      MS783       DRG       MS783  NaN      NaN
# 1136976      MS783       DRG       MS783  NaN      NaN
# 1145335      MS783       DRG       MS783  NaN      NaN
# 1153694      MS783       DRG       MS783  NaN      NaN
# 1162053      MS783       DRG       MS783  NaN      NaN
#
#                                           description quantity
# 0        Cesarean Section With Sterilization With McC     <NA>  \
# 167202   Cesarean Section With Sterilization With McC     <NA>
# 334404   Cesarean Section With Sterilization With McC     <NA>
# 502318                     HC C-Telopeptide,Serum S/O     <NA>
# 669520                     HC C-Telopeptide,Serum S/O     <NA>
# 836722                     HC C-Telopeptide,Serum S/O     <NA>
# 1003212  Cesarean Section With Sterilization With McC     <NA>
# 1011571  Cesarean Section With Sterilization With McC     <NA>
# 1019930  Cesarean Section With Sterilization With McC     <NA>
# 1028289  Cesarean Section With Sterilization With McC     <NA>
# 1036648  Cesarean Section With Sterilization With McC     <NA>
# 1045007  Cesarean Section With Sterilization With McC     <NA>
# 1078451  Cesarean Section With Sterilization With McC     <NA>
# 1086810  Cesarean Section With Sterilization With McC     <NA>
# 1128615  Cesarean Section With Sterilization With McC     <NA>
# 1136976  Cesarean Section With Sterilization With McC     <NA>
# 1145335  Cesarean Section With Sterilization With McC     <NA>
# 1153694  Cesarean Section With Sterilization With McC     <NA>
# 1162053  Cesarean Section With Sterilization With McC     <NA>
#
#                                           payer_name standard_charge
# 0                                           IP Price        32996.83  \
# 167202                          De-Identified IP MIN        13198.73
# 334404                          De-Identified IP MAX        52122.22
# 502318                                      OP Price            86.9
# 669520                          De-Identified OP MIN           22.42
# 836722                          De-Identified OP MAX            86.9
# 1003212                                 AETNA [1002]        28047.31
# 1011571                    ASANTE HEALTH PLAN [1014]        13198.73
# 1019930                                 CIGNA [1025]        28047.31
# 1028289                             HEALTHNET [1047]        28047.31
# 1036648                                HUMANA [1051]        29697.15
# 1045007                           MODA HEALTH [1070]        32996.83
# 1078451                         PACIFICSOURCE [1072]        27387.37
# 1086810                PROVIDENCE HEALTH PLAN [1078]        52122.22
# 1128615                    REGENCE BLUE CROSS [1114]        32996.83
# 1136976  LIBERTY HEALTHSHARE MEDSOLUTIONS LLC [1159]        26397.46
# 1145335                     UNITED HEALTH ONE [1181]        29697.15
# 1153694                         PACIFICSOURCE [1195]        25902.51
# 1162053                                   <Self-pay>        21447.94
#
#                                              plan_name
# 0                                                  NaN  \
# 167202                                             NaN
# 334404                                             NaN
# 502318                                             NaN
# 669520                                             NaN
# 836722                                             NaN
# 1003212                                 AETNA [100003]
# 1011571               ASANTE PPO HEALTH PLAN  [100389]
# 1019930                                 CIGNA [100344]
# 1028289           HEALTHNET COMMERCIAL CLAIMS [100662]
# 1036648                                HUMANA [100062]
# 1045007                        BEACON NETWORK [100426]
# 1078451             PACIFICSOURCE HEALTH PLAN [100092]
# 1086810          PROVIDENCE SIGNATURE NETWORK [100554]
# 1128615  PREFERRED PPO OR BLUECARD W SUITCASE [100272]
# 1136976               LIBERTY HEALTHSHARE MEDSOLUTIONS
# 1145335                     UNITED HEALTH ONE [100694]
# 1153694                SMARTHEATH/SMARTCHOICE [100753]
# 1162053                                     <Self-pay>
#
#                         payer_temp     setting payer_category ms_drg
# 0                              NaN   inpatient          gross    783  \
# 167202                         NaN   inpatient            min    783
# 334404                         NaN   inpatient            max    783
# 502318                         NaN  outpatient          gross    nan
# 669520                         NaN  outpatient            min    nan
# 836722                         NaN  outpatient            max    nan
# 1003212  IP Expected Reimbursement   inpatient          payer    783
# 1011571  IP Expected Reimbursement   inpatient          payer    783
# 1019930  IP Expected Reimbursement   inpatient          payer    783
# 1028289  IP Expected Reimbursement   inpatient          payer    783
# 1036648  IP Expected Reimbursement   inpatient          payer    783
# 1045007  IP Expected Reimbursement   inpatient          payer    783
# 1078451  IP Expected Reimbursement   inpatient          payer    783
# 1086810  IP Expected Reimbursement   inpatient          payer    783
# 1128615  IP Expected Reimbursement   inpatient          payer    783
# 1136976  IP Expected Reimbursement   inpatient          payer    783
# 1145335  IP Expected Reimbursement   inpatient          payer    783
# 1153694  IP Expected Reimbursement   inpatient          payer    783
# 1162053  IP Expected Reimbursement   inpatient           cash    783
#
#         hcpcs_cpt alt_hcpcs_cpt
# 0            <NA>           NaN
# 167202       <NA>           NaN
# 334404       <NA>           NaN
# 502318      82523           NaN
# 669520      82523           NaN
# 836722      82523           NaN
# 1003212      <NA>           NaN
# 1011571      <NA>           NaN
# 1019930      <NA>           NaN
# 1028289      <NA>           NaN
# 1036648      <NA>           NaN
# 1045007      <NA>           NaN
# 1078451      <NA>           NaN
# 1086810      <NA>           NaN
# 1128615      <NA>           NaN
# 1136976      <NA>           NaN
# 1145335      <NA>           NaN
# 1153694      <NA>           NaN
# 1162053      <NA>           NaN

# %%
id_mapping = {
 '571181758_AsanteThreeRiversMedicalCenter_Standardcharges.csv': '380002',
 '815427847_AsanteAshlandCommunityHospital_Standardcharges.csv': '380005',
 '930223960_AsanteRogueRegionalMedicalCenter_Standardcharges.csv': '380018'}

hosp_id = id_mapping[file]

df['hospital_id'] = hosp_id

output_folder = '.\\output_files\\'

filename = hosp_id + file.split('_')[1] + '.csv'

df.to_csv(output_folder + filename, index=False)
