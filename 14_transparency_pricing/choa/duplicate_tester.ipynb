# %%
import pandas as pd

# %%
df = pd.read_csv('.\\output_files\\58-0572412.csv', dtype={'rate': float})

pk_cols = ['hospital_ein','hospital_ccn','rev_code','internal_code','code_type','code','modifier','ndc','apc','billing_class','patient_class','billed_quantity','payer_orig']
pk_cols = [x for x in pk_cols if x in df.columns]

dp_rows = df[df.duplicated(subset=pk_cols, keep=False)]
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_158508\1825115185.py:1: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('.\\output_files\\58-0572412.csv', dtype={'rate': float})

# %%
dp_rows
# Out:
#         internal_code code_type code_orig ndc rev_desc  \
# 15826           66559       sup       NaN  na      NaN
# 22283           66559       sup       NaN  na      NaN
# 51834           66559       sup       NaN  na      NaN
# 58291           66559       sup       NaN  na      NaN
# 88668           66559       sup       NaN  na      NaN
# ...               ...       ...       ...  ..      ...
# 1218807         66559       sup       NaN  na      NaN
# 1248358         66559       sup       NaN  na      NaN
# 1254815         66559       sup       NaN  na      NaN
# 1284366         66559       sup       NaN  na      NaN
# 1290823         66559       sup       NaN  na      NaN
#
#                         description Quantity  \
# 15826    RING SPAT FRAME FULL 180MM        1
# 22283      RING FULL ILIZAROV 180MM      NaN
# 51834    RING SPAT FRAME FULL 180MM        1
# 58291      RING FULL ILIZAROV 180MM      NaN
# 88668    RING SPAT FRAME FULL 180MM        1
# ...
