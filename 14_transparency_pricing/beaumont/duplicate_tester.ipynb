# %%
import pandas as pd

# %%
def highlight_cols(x):
      
    # copy df to new - original data is not changed
    df = x.copy()
      
    # select all values to green color
    df.loc[:, :] = 'background-color: green'
      
    # overwrite values grey color
    df[['B', 'C', 'E']] = 'background-color: grey'
      
    # return color df
    return df

# %%
df = pd.read_csv("./output_files/dearborn.csv", dtype={'rate': float})
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_36632\4067396972.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./output_files/dearborn.csv", dtype={'rate': float})

# %%
pk_cols = ['hospital_tin','hospital_ccn','rev_code','procedure_code','code_type','code','modifier','ndc','apc','billing_class','patient_class','billed_quantity','payer_orig','plan_orig']
pk_cols = [x for x in pk_cols if x in df.columns]

dp_rows = df[df.duplicated(subset=pk_cols, keep=False)]

# %%
dp_rows
# Out:
#         code_meta procedure_code   code ndc rev_code  \
# 1680          sup         611045  C1713  na     0278
# 1681          sup         611045  C1713  na     0278
# 1926          sup      M00534320  C2625  na     0278
# 1927          sup      M00534320  C2625  na     0278
# 2393          sup         407645  C1898  na     0275
# ...           ...            ...    ...  ..      ...
# 1241327       sup         SRM140  C1789  na      278
# 1241525       sup       TEM1509G  C1781  na      278
# 1241526       sup       TEM1509G  C1781  na      278
# 1241527       sup       TEM1515G  C1781  na      278
# 1241528       sup       TEM1515G  C1781  na      278
#
#                                                description       payer_orig  \
# 1680              SCREW, 8.0 X 45MM TI CANNULATED (611045)     GROSS CHARGE
# 1681                 SCREW, CANNULATED 8.0 X 45MM (611045)     GROSS CHARGE
# 1926     STENT, BILIARY, 10F X 5CM, NAVIFLEX DEL SYSTEM...     GROSS CHARGE
# ...
