# %%
import pandas as pd
import numpy as np
import polars as pl
import pyarrow

# %%
def payer_category(x):
    x = x.lower()
    if 'min' in x:
        return 'min'
    elif 'max' in x:
        return'max'
    elif 'cash_price' in x:
        return 'cash'
    elif 'gross' in x:
        return 'gross'

# %%
df = pd.read_csv('58-1645396_BMH_Restorative_Care_STANDARDCHARGES.csv', delimiter="|", encoding='ansi')

# %%
date = df['FDATE'][0]
df = df.drop(['FDATE', 'FAC'], axis=1)

# %%
df.rename(columns=lambda x: x.strip().strip(), inplace=True)

# %%
df.rename(columns={
    'Code_Type': 'line_type',
    'Code': 'code',
    'Procedure': 'local_code',
    'Procedure_Description': 'description',
    'NDC': 'ndc',
    'Rev_Code':'rev_code',
    'Plan': 'plan'
}, inplace=True)

# %%
df.loc[df['CODE_DESC'].str.contains('MS-LTC'), 'code'] = df['CODE_DESC']

df.loc[df['code'].str.contains('MS-LTC'), 'ms_drg'] = df['code'].str.replace('MS-LTC', '')
df.loc[df['CODE_DESC'] == 'HCPCS', 'hcpcs_cpt'] = df['code'].str.replace('HCPCS ', '')
df.loc[df['CODE_DESC'] == 'CPT®', 'hcpcs_cpt'] = df['code'].str.replace('CPT® ', '')

# %%
df['rev_code'] = df['rev_code'].str.split(' - ').str[0]

# %%
# Bring added columns to the beginning to make the next step easier
cols = df.columns.tolist()
cols = cols[-2:] + cols[:-2]
df = df[cols]

df = df.drop('CODE_DESC', axis=1)

# %%
df
# Out:
#       ms_drg hcpcs_cpt   line_type         code  local_code  \
# 0        166       NaN  MS-LTC-DRG    MS-LTC166         166
# 1        166       NaN  MS-LTC-DRG    MS-LTC166         166
# 2        166       NaN  MS-LTC-DRG    MS-LTC166         166
# 3        166       NaN  MS-LTC-DRG    MS-LTC166         166
# 4        166       NaN  MS-LTC-DRG    MS-LTC166         166
# ...      ...       ...         ...          ...         ...
# 75520    NaN     Q9967         ERX  HCPCS Q9967       10322
# 75521    NaN     Q9967         ERX  HCPCS Q9967       10322
# 75522    NaN     Q9967         ERX  HCPCS Q9967       10322
# 75523    NaN     Q9967         ERX  HCPCS Q9967       10322
# 75524    NaN     Q9967         ERX  HCPCS Q9967       10322
#
#                                              description            ndc  \
# 0      Other respiratory system O.R. procedures with MCC            NaN
# 1      Other respiratory system O.R. procedures with MCC            NaN
# 2      Other respiratory system O.R. procedures with MCC            NaN
# 3      Other respiratory system O.R. procedures with MCC            NaN
# 4      Other respiratory system O.R. procedures with MCC            NaN
# ...                                                  ...            ...
# 75520      IOHEXOL 300 MG IODINE/ML INTRAVENOUS SOLUTION  00407-1413-58
# 75521      IOHEXOL 300 MG IODINE/ML INTRAVENOUS SOLUTION  00407-1413-58
# 75522      IOHEXOL 300 MG IODINE/ML INTRAVENOUS SOLUTION  00407-1413-58
# 75523      IOHEXOL 300 MG IODINE/ML INTRAVENOUS SOLUTION  00407-1413-58
# 75524      IOHEXOL 300 MG IODINE/ML INTRAVENOUS SOLUTION  00407-1413-58
#
#       rev_code                                         plan  \
# 0          NaN             1100313001-BLUE CROSS NETWORK S
# 1          NaN      1100313002-BLUE CROSS BAPTIST EMPLOYEE
# 2          NaN     1100315001-BLUE CROSS ARKANSAS EXCHANGE
# 3          NaN   1100316001-BLUE CROSS TENNESSEE NETWORK P
# 4          NaN        1100330002-BLUE CROSS MISSISSIPPI PPO
# ...        ...                                          ...
# 75520     0636    1100316001-BLUE CROSS TENNESSEE NETWORK P
# 75521     0636      1100315001-BLUE CROSS ARKANSAS EXCHANGE
# 75522     0636       1100313002-BLUE CROSS BAPTIST EMPLOYEE
# 75523     0636              1100313001-BLUE CROSS NETWORK S
# 75524     0636                           1001583001-TRICARE
#
#        IP_Expected_Reimbursement IP_Expected_Reimbursement_MIN  \
# 0                       52950.00                      52950.00
# 1                       52950.00                      52950.00
# 2                       52950.00                      52950.00
# 3                       52950.00                      52950.00
# 4                       52950.00                      52950.00
# ...                          ...                           ...
# 75520  Not reimbursed separately     Not reimbursed separately
# 75521  Not reimbursed separately     Not reimbursed separately
# 75522  Not reimbursed separately     Not reimbursed separately
# 75523  Not reimbursed separately     Not reimbursed separately
# 75524  Not reimbursed separately     Not reimbursed separately
#
#       IP_Expected_Reimbursement_MAX  IP_cash_price Gross_ip_chg  \
# 0                         135291.32      103723.34    450971.05
# 1                         135291.32      103723.34    450971.05
# 2                         135291.32      103723.34    450971.05
# 3                         135291.32      103723.34    450971.05
# 4                         135291.32      103723.34    450971.05
# ...                             ...            ...          ...
# 75520     Not reimbursed separately          66.34       288.45
# 75521     Not reimbursed separately          66.34       288.45
# 75522     Not reimbursed separately          66.34       288.45
# 75523     Not reimbursed separately          66.34       288.45
# 75524     Not reimbursed separately          66.34       288.45
#
#        OP_Expected_Reimbursement  OP_Expected_Reimbursement_MIN  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
# ...                          ...                            ...
# 75520                        NaN                            NaN
# 75521                        NaN                            NaN
# 75522                        NaN                            NaN
# 75523                        NaN                            NaN
# 75524                        NaN                            NaN
#
#        OP_Expected_Reimbursement_MAX  OP_cash_price  Gross_op_chg
# 0                                NaN            NaN           NaN
# 1                                NaN            NaN           NaN
# 2                                NaN            NaN           NaN
# 3                                NaN            NaN           NaN
# 4                                NaN            NaN           NaN
# ...                              ...            ...           ...
# 75520                            NaN            NaN           NaN
# 75521                            NaN            NaN           NaN
# 75522                            NaN            NaN           NaN
# 75523                            NaN            NaN           NaN
# 75524                            NaN            NaN           NaN
#
# [75525 rows x 19 columns]

# %%
cols = df.columns.tolist()

id_vars = cols[:9]
value_vars = ['IP_Expected_Reimbursement', 'OP_Expected_Reimbursement']

df_plan = pd.melt(df, id_vars=id_vars, value_vars=value_vars, var_name='payer', value_name='standard_charge')

# %%
# Set column `setting` to either `inpatient` if col `payer` starts with  'IP' or `outpatient` if col `payer` starts with  'OP'
df_plan['setting'] = np.where(df_plan['payer'].str.startswith('IP'), 'inpatient', np.where(df_plan['payer'].str.startswith('OP'), 'outpatient', 1))
df_plan['payer_category'] = 'payer'

# %%
df_plan
# Out:
#        ms_drg hcpcs_cpt   line_type         code  local_code  \
# 0         166       NaN  MS-LTC-DRG    MS-LTC166         166
# 1         166       NaN  MS-LTC-DRG    MS-LTC166         166
# 2         166       NaN  MS-LTC-DRG    MS-LTC166         166
# 3         166       NaN  MS-LTC-DRG    MS-LTC166         166
# 4         166       NaN  MS-LTC-DRG    MS-LTC166         166
# ...       ...       ...         ...          ...         ...
# 151045    NaN     Q9967         ERX  HCPCS Q9967       10322
# 151046    NaN     Q9967         ERX  HCPCS Q9967       10322
# 151047    NaN     Q9967         ERX  HCPCS Q9967       10322
# 151048    NaN     Q9967         ERX  HCPCS Q9967       10322
# 151049    NaN     Q9967         ERX  HCPCS Q9967       10322
#
#                                               description            ndc  \
# 0       Other respiratory system O.R. procedures with MCC            NaN
# 1       Other respiratory system O.R. procedures with MCC            NaN
# 2       Other respiratory system O.R. procedures with MCC            NaN
# 3       Other respiratory system O.R. procedures with MCC            NaN
# 4       Other respiratory system O.R. procedures with MCC            NaN
# ...                                                   ...            ...
# 151045      IOHEXOL 300 MG IODINE/ML INTRAVENOUS SOLUTION  00407-1413-58
# 151046      IOHEXOL 300 MG IODINE/ML INTRAVENOUS SOLUTION  00407-1413-58
# 151047      IOHEXOL 300 MG IODINE/ML INTRAVENOUS SOLUTION  00407-1413-58
# 151048      IOHEXOL 300 MG IODINE/ML INTRAVENOUS SOLUTION  00407-1413-58
# 151049      IOHEXOL 300 MG IODINE/ML INTRAVENOUS SOLUTION  00407-1413-58
#
#        rev_code                                         plan  \
# 0           NaN             1100313001-BLUE CROSS NETWORK S
# 1           NaN      1100313002-BLUE CROSS BAPTIST EMPLOYEE
# 2           NaN     1100315001-BLUE CROSS ARKANSAS EXCHANGE
# 3           NaN   1100316001-BLUE CROSS TENNESSEE NETWORK P
# 4           NaN        1100330002-BLUE CROSS MISSISSIPPI PPO
# ...         ...                                          ...
# 151045     0636    1100316001-BLUE CROSS TENNESSEE NETWORK P
# 151046     0636      1100315001-BLUE CROSS ARKANSAS EXCHANGE
# 151047     0636       1100313002-BLUE CROSS BAPTIST EMPLOYEE
# 151048     0636              1100313001-BLUE CROSS NETWORK S
# 151049     0636                           1001583001-TRICARE
#
#                             payer standard_charge     setting payer_category
# 0       IP_Expected_Reimbursement        52950.00   inpatient          payer
# 1       IP_Expected_Reimbursement        52950.00   inpatient          payer
# 2       IP_Expected_Reimbursement        52950.00   inpatient          payer
# 3       IP_Expected_Reimbursement        52950.00   inpatient          payer
# 4       IP_Expected_Reimbursement        52950.00   inpatient          payer
# ...                           ...             ...         ...            ...
# 151045  OP_Expected_Reimbursement             NaN  outpatient          payer
# 151046  OP_Expected_Reimbursement             NaN  outpatient          payer
# 151047  OP_Expected_Reimbursement             NaN  outpatient          payer
# 151048  OP_Expected_Reimbursement             NaN  outpatient          payer
# 151049  OP_Expected_Reimbursement             NaN  outpatient          payer
#
# [151050 rows x 13 columns]

# %%
# Move on to creating df with only rates and no plans
df = df.drop(['plan', 'IP_Expected_Reimbursement', 'OP_Expected_Reimbursement'], axis=1)

# %%
cols = df.columns.tolist()
id_vars = cols[:8]
value_vars = cols[8:]

df = pd.melt(df, id_vars=id_vars, value_vars=value_vars, var_name='payer', value_name='standard_charge')

# %%
df['setting'] = np.where(df['payer'].str.startswith('IP'), 'inpatient', np.where(df['payer'].str.startswith('OP'), 'outpatient', 1))
df['setting'] = np.where(df['payer'].str.contains('_ip_'), 'inpatient', np.where(df['payer'].str.contains('_op_'), 'outpatient', df['setting']))
df['payer_category'] = df['payer'].apply(payer_category)
df['plan'] = ''

# %%
df_concat = pd.concat([df, df_plan])

# %%
df_concat.dropna(subset=['standard_charge'], inplace=True)

# %%
df = df_concat
df = df[df['standard_charge'] != 'Not reimbursed separately']

# %%
df.loc[df['hcpcs_cpt'].str.len() > 5, 'hcpcs_cpt'] = pd.NA

# %%
df['hospital_id'] = '442010'
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_20596\1234934751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hospital_id'] = '442010'

# %%
df['hcpcs_cpt'].fillna('""', inplace=True)
df['code'].fillna('""', inplace=True)
df['rev_code'].fillna('""', inplace=True)
df['ndc'].fillna('""', inplace=True)
df['plan'].fillna('""', inplace=True)
df['ms_drg'].fillna('""', inplace=True)
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_20596\3110744954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hcpcs_cpt'].fillna('""', inplace=True)
# C:\Users\adria\AppData\Local\Temp\ipykernel_20596\3110744954.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['code'].fillna('""', inplace=True)
# C:\Users\adria\AppData\Local\Temp\ipykernel_20596\3110744954.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rev_code'].fillna('""', inplace=True)
# C:\Users\adria\AppData\Local\Temp\ipykernel_20596\3110744954.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ndc'].fillna('""', inplace=True)
# C:\Users\adria\AppData\Local\Temp\ipykernel_20596\3110744954.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['plan'].fillna('""', inplace=True)
# C:\Users\adria\AppData\Local\Temp\ipykernel_20596\3110744954.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ms_drg'].fillna('""', inplace=True)

# %%
df['standard_charge'] = df['standard_charge'].str.replace(',', '')
df.dropna(subset=['standard_charge'], inplace=True)

df['payer'] = df['payer'].str.strip()
df['plan'] = df['plan'].str.strip()
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_20596\53813817.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['standard_charge'] = df['standard_charge'].str.replace(',', '')
# C:\Users\adria\AppData\Local\Temp\ipykernel_20596\53813817.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['standard_charge'], inplace=True)
# C:\Users\adria\AppData\Local\Temp\ipykernel_20596\53813817.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['payer'] = df['payer'].str.strip()
# C:\Users\adria\AppData\Local\Temp\ipykernel_20596\53813817.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['plan'] = df['plan'].str.strip()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\adria\github\BountyScrapers\14_transparency_pricing\bmh\extractor.ipynb Cell 23 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/adria/github/BountyScrapers/14_transparency_pricing/bmh/extractor.ipynb#X62sZmlsZQ%3D%3D?line=3'>4</a> df['payer'] = df['payer'].str.strip()
#       <a href='vscode-notebook-cell:/c%3A/Users/adria/github/BountyScrapers/14_transparency_pricing/bmh/extractor.ipynb#X62sZmlsZQ%3D%3D?line=4'>5</a> df['plan'] = df['plan'].str.strip()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/adria/github/BountyScrapers/14_transparency_pricing/bmh/extractor.ipynb#X62sZmlsZQ%3D%3D?line=6'>7</a> df.columns()
#
# TypeError: 'Index' object is not callable

# %%
df.drop_duplicates(subset=['ms_drg', 'hcpcs_cpt', 'code', 'local_code', 'ndc', 'rev_code', 'payer', 'setting', 'payer_category', 'plan'], inplace=True)

# %%
df.columns
# Out:
# Index(['ms_drg', 'hcpcs_cpt', 'line_type', 'code', 'local_code', 'description',
#        'ndc', 'rev_code', 'payer', 'standard_charge', 'setting',
#        'payer_category', 'plan', 'hospital_id'],
#       dtype='object')

# %%
df.to_csv('data.csv', index=False)
