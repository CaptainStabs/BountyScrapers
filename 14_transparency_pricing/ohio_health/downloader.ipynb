# %%
import pandas as pd
import requests
from tqdm import tqdm

tqdm = tqdm.pandas()

# %%
df = pd.read_csv('hospitals.csv', dtype=str)

# %%
def download_file(url):
    filename = url.split('/')[-1]
    r = requests.get(url, stream=True).content
    
    with open('.\\input_files\\' + filename, 'wb') as f:
        f.write(r)

# %%
df['mrf_url'].progress_apply(download_file)
# Out:
# 100%|██████████| 12/12 [00:07<00:00,  1.59it/s]
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# Name: mrf_url, dtype: object

# %%
ein_ccn_dict = dict(zip(df['file_name'], df['id']))
ein_ccn_dict
# Out:
# {'38-4105653_berger_standardcharges.xlsx': '360170',
#  '31-4394942_doctors_standardcharges.xlsx': '360152',
#  '31-4394942_dublin_standardcharges.xlsx': '360348',
#  '31-4379436_grady_standardcharges.xlsx': '360210',
#  '31-4394942_grant_standardcharges.xlsx': '360017',
#  '31-4440479_hardin_standardcharges.xlsx': '361315',
#  '31-1070877_marion_standardcharges.xlsx': '360011',
#  '31-4394942_grove-city_standardcharges.xlsx': '360372',
#  '34-0714456_mansfield_standardcharges.xlsx': '360118',
#  '31-4446959_obleness_standardcharges.xlsx': '360014',
#  '34-0714456_shelby_standardcharges.xlsx': '361324',
#  '31-4394942_riverside_standardcharges.xlsx': '360006'}

# %%
df
# Out:
#         id         ein                                   name
# 0   360170  38-4105653                        BERGER HOSPITAL  \
# 1   360152  31-4394942                       DOCTORS HOSPITAL
# 2   360348  31-4394942              DUBLIN METHODIST HOSPITAL
# 3   360210  31-4379436                GRADY MEMORIAL HOSPITAL
# 4   360017  31-4394942                   GRANT MEDICAL CENTER
# 5   361315  31-4440479               HARDIN MEMORIAL HOSPITAL
# 6   360011  31-1070877                MARION GENERAL HOSPITAL
# 7   360372  31-4394942  OHIO ORTHOPEDIC SURGERY INSTITUTE LLC
# 8   360118  34-0714456          OHIOHEALTH MANSFIELD HOSPITAL
# 9   360014  31-4446959          OHIOHEALTH O'BLENESS HOSPITAL
# 10  361324  34-0714456             OHIOHEALTH SHELBY HOSPITAL
# 11  360006  34-0714456           RIVERSIDE METHODIST HOSPITAL
#
#                                      file_name
# 0       38-4105653_berger_standardcharges.xlsx  \
# 1      31-4394942_doctors_standardcharges.xlsx
# 2       31-4394942_dublin_standardcharges.xlsx
# 3        31-4379436_grady_standardcharges.xlsx
# 4        31-4394942_grant_standardcharges.xlsx
# 5       31-4440479_hardin_standardcharges.xlsx
# 6       31-1070877_marion_standardcharges.xlsx
# 7   31-4394942_grove-city_standardcharges.xlsx
# 8    34-0714456_mansfield_standardcharges.xlsx
# 9     31-4446959_obleness_standardcharges.xlsx
# 10      34-0714456_shelby_standardcharges.xlsx
# 11      34-0714456_shelby_standardcharges.xlsx
#
#                                               mrf_url
# 0   https://www.ohiohealth.com/siteassets/patients...  \
# 1   https://www.ohiohealth.com/siteassets/patients...
# 2   https://www.ohiohealth.com/siteassets/patients...
# 3   https://www.ohiohealth.com/siteassets/patients...
# 4   https://www.ohiohealth.com/siteassets/patients...
# 5   https://www.ohiohealth.com/siteassets/patients...
# 6   https://www.ohiohealth.com/siteassets/patients...
# 7   https://www.ohiohealth.com/siteassets/patients...
# 8   https://www.ohiohealth.com/siteassets/patients...
# 9   https://www.ohiohealth.com/siteassets/patients...
# 10  https://www.ohiohealth.com/siteassets/patients...
# 11  https://www.ohiohealth.com/siteassets/patients...
#
#                                    alt_name system_name
# 0                OhioHealth Berger Hospital  OhioHealth  \
# 1               OhioHealth Doctors Hospital  OhioHealth
# 2      OhioHealth Dublin Methodist Hospital  OhioHealth
# 3        OhioHealth Grady Memorial Hospital  OhioHealth
# 4           OhioHealth Grant Medical Center  OhioHealth
# 5       OhioHealth Hardin Memorial Hospital  OhioHealth
# 6        OhioHealth Marion General Hospital  OhioHealth
# 7             Grove City Methodist Hospital         NaN
# 8             OhioHealth Mansfield Hospital  OhioHealth
# 9             OhioHealth O'Bleness Hospital  OhioHealth
# 10               OhioHealth Shelby Hospital  OhioHealth
# 11  OhioHealth Riverside Methodist Hospital  OhioHealth
#
#                                addr         city state    zip       phone
# 0         600 NORTH PICKAWAY STREET  CIRCLEVILLE    OH  43113  7404742126  \
# 1           5100 WEST  BROAD STREET     COLUMBUS    OH  43228  6145441000
# 2              7500 HOSPITAL AVENUE       DUBLIN    OH  43016  6145448694
# 3           561 WEST CENTRAL AVENUE     DELAWARE    OH  43015  7403685145
# 4            111 SOUTH GRANT AVENUE     COLUMBUS    OH  43215  6145668952
# 5          921 EAST FRANKLIN STREET       KENTON    OH  43326  4196730761
# 6          1000 MCKINLEY PARK DRIVE       MARION    OH  43302  7403838400
# 7   1325 STRINGTOWN ROAD, SUITE 100   GROVE CITY    OH  43123  6149916900
# 8               335 GLESSNER AVENUE    MANSFIELD    OH  44903  4195268000
# 9                 55 HOSPITAL DRIVE       ATHENS    OH  45701  7405935551
# 10             199 WEST MAIN STREET       SHELBY    OH  44875  4193425015
# 11          3535 OLENTANGY RIVER RD     COLUMBUS    OH  43214  6147888251
#
#    urban_rural                   category                control_type
# 0            U                 Short Term          GOVERNMENT - STATE  \
# 1            U                 Short Term     FOR PROFIT - INDIVIDUAL
# 2            U                 Short Term    FOR PROFIT - PARTNERSHIP
# 3            U                 Short Term    FOR PROFIT - PARTNERSHIP
# 4            U                 Short Term     FOR PROFIT - INDIVIDUAL
# 5            R  Critical Access Hospitals    FOR PROFIT - PARTNERSHIP
# 6            R                 Short Term    FOR PROFIT - PARTNERSHIP
# 7            U                 Short Term  NONPROFIT - CHURCH RELATED
# 8            U                 Short Term    FOR PROFIT - PARTNERSHIP
# 9            R                 Short Term    FOR PROFIT - CORPORATION
# 10           U  Critical Access Hospitals    FOR PROFIT - PARTNERSHIP
# 11           U                 Short Term    FOR PROFIT - PARTNERSHIP
#
#    medicare_termination_status last_updated permalink
# 0              ACTIVE PROVIDER          NaN       NaN  \
# 1              ACTIVE PROVIDER          NaN       NaN
# 2              ACTIVE PROVIDER          NaN       NaN
# 3              ACTIVE PROVIDER          NaN       NaN
# 4              ACTIVE PROVIDER          NaN       NaN
# 5              ACTIVE PROVIDER          NaN       NaN
# 6              ACTIVE PROVIDER          NaN       NaN
# 7              ACTIVE PROVIDER          NaN       NaN
# 8              ACTIVE PROVIDER          NaN       NaN
# 9              ACTIVE PROVIDER          NaN       NaN
# 10             ACTIVE PROVIDER          NaN       NaN
# 11             ACTIVE PROVIDER          NaN       NaN
#
#                                     transparency_page additional_notes
# 0   https://www.ohiohealth.com/patients-and-visito...              NaN
# 1   https://www.ohiohealth.com/patients-and-visito...              NaN
# 2   https://www.ohiohealth.com/patients-and-visito...              NaN
# 3   https://www.ohiohealth.com/patients-and-visito...              NaN
# 4   https://www.ohiohealth.com/patients-and-visito...              NaN
# 5   https://www.ohiohealth.com/patients-and-visito...              NaN
# 6   https://www.ohiohealth.com/patients-and-visito...              NaN
# 7   https://www.ohiohealth.com/patients-and-visito...              NaN
# 8   https://www.ohiohealth.com/patients-and-visito...              NaN
# 9   https://www.ohiohealth.com/patients-and-visito...              NaN
# 10  https://www.ohiohealth.com/patients-and-visito...              NaN
# 11  https://www.ohiohealth.com/patients-and-visito...              NaN
