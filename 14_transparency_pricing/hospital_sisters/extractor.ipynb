# %%
import pandas as pd

# %%
folder = './input_files/'

file = '370512290_GOOD-SHEPHERD-HOSPITAL_STANDARDCHAGES.txt'

# %%
df = pd.read_csv(folder + file, dtype=str, skiprows=1, encoding='ansi')

# %%
df.drop('Site', axis=1, inplace=True)

# %%
df.rename(columns=lambda x: x.strip(), inplace=True)

# %%
df.rename(columns={
    'Svc_Cd': 'local_code',
    'HCPC/Cpt_Cd': 'code',
    'CDM_Svc_Descr': 'description',
    'Rev_Cd': 'rev_code',
    'Quantity/Units': 'drug_quantity', 
}, inplace=True)

# %%
df['drug_quantity'] = df['drug_quantity'].str.strip()
df.loc[df['drug_quantity'] == '1', 'drug_quantity'] = pd.NA

# %%
cols = df.columns.tolist()
id_vars = cols[:5]
val_vars = cols[5:]

df = pd.melt(df, id_vars=id_vars, value_vars=val_vars, var_name='payer_name', value_name='standard_charge')

# %%
df['code'] = df['code'].str.strip()

# %%
mask = ~df['code'].isna()

# %%
df.loc[mask & df['code'].str.match(r'^\d{3}$'), 'ms_drg'] = df['code']

# %%
df['temp_code'] = df['code'].str.upper()
df.loc[mask & df['temp_code'].str.match(r'^[A-Z][0-9]{4}$|^[0-9]{5}$|^[0-9]{4}[A-Z]$'), 'hcpcs_cpt'] = df['code']

# %%
payer_map = {
    'Hospital_Cdm_Chg': 'gross',
    'Self_Pay_Chg': 'cash',
    'Minimum_Negotiated_Chg': 'min',
    'Maximum_Negotiated_Chg': 'max',
}

df['rate_category'] = df['payer_name'].map(payer_map).fillna('negotiated')

# %%
df['standard_charge'] = df['standard_charge'].str.replace('$', '').str.replace(',', '')

# %%
df.loc[df['code'] == '1967', 'hcpcs_cpt'] = '01967'

# %%
df.loc[df['code'].str.len() == 4, 'hcpcs_cpt'] = df['code'].str.zfill(5)
df.loc[~df['rev_code'].isna(), 'rev_code'] = df['rev_code'].str.zfill(4)

# %%
df.drop('temp_code', axis=1, inplace=True)

# %% [markdown]
# ## NEW STUFF

# %%
df['standard_charge'] = df['standard_charge'].str.strip()

# %%
# Remove rows where standard_charge has no value
df.loc[df['standard_charge'].str.match('^Inpatient Medicare$|^Inpatient Medicaid$'), 'standard_charge'] = pd.NA
df.loc[df['standard_charge'] == 'N/A', 'standard_charge'] = pd.NA
df.dropna(subset='standard_charge', inplace=True)

df.loc[df['standard_charge'].str.lower().str.contains('inpatient'), 'setting'] = 'inpatient'
df.loc[df['standard_charge'].str.lower().str.contains('outpatient'), 'setting'] = 'outpatient'

# %%
df.loc[df['standard_charge'].str.contains(r'Medicare|Medicaid'), 'standard_charge_percent'] = df['standard_charge'].str.extract(r'\+(\d{1,3})\%', expand=False)

# %%
df['standard_charge_percent'] = df['standard_charge_percent'].astype(float)

# %%
df.loc[~df['standard_charge_percent'].isna(), 'standard_charge_percent'] = df['standard_charge_percent'] + 100

# %%
mask = df['standard_charge'].str.contains('Medicare|Medicaid')

df.loc[mask, 'additional_generic_notes'] = df['standard_charge']
df.loc[mask, 'standard_charge'] = pd.NA

# %%
df.loc[~df['additional_generic_notes'].isna()]
# Out:
#        local_code code                    description rev_code drug_quantity
# 39489    12000001  NaN       HC DAILY SERVICE GENERAL      120          <NA>  \
# 39490    12000006  NaN   HC DAILY SERVICE W/TELEMETRY      120          <NA>
# 39491    12200001  NaN    HC DAILY SERVICE OBSTETRICS      122          <NA>
# 39492    12500001  NaN    HC DAILY HOSPICE ACUTE CARE      125          <NA>
# 39493    17100001  NaN  HC DAILY INFANT SERVICE LEV 1      171          <NA>
# ...           ...  ...                            ...      ...           ...
# 463944   12200001  NaN    HC DAILY SERVICE OBSTETRICS      122          <NA>
# 463945   12500001  NaN    HC DAILY HOSPICE ACUTE CARE      125          <NA>
# 463946   17100001  NaN  HC DAILY INFANT SERVICE LEV 1      171          <NA>
# 463947   17200002  NaN  HC DAILY INFANT SERVICE LEV 2      172          <NA>
# 463948   20000001  NaN           HC DAILY SERVICE ICU      200          <NA>
#
#                    payer_name standard_charge ms_drg hcpcs_cpt rate_category
# 39489   6 DEGREES HEALTH, INC             NaN    NaN       NaN    negotiated  \
# 39490   6 DEGREES HEALTH, INC             NaN    NaN       NaN    negotiated
# 39491   6 DEGREES HEALTH, INC             NaN    NaN       NaN    negotiated
# 39492   6 DEGREES HEALTH, INC             NaN    NaN       NaN    negotiated
# 39493   6 DEGREES HEALTH, INC             NaN    NaN       NaN    negotiated
# ...                       ...             ...    ...       ...           ...
# 463944               NAPHCARE             NaN    NaN       NaN    negotiated
# 463945               NAPHCARE             NaN    NaN       NaN    negotiated
# 463946               NAPHCARE             NaN    NaN       NaN    negotiated
# 463947               NAPHCARE             NaN    NaN       NaN    negotiated
# 463948               NAPHCARE             NaN    NaN       NaN    negotiated
#
#         standard_charge_percent  additional_generic_notes
# 39489                     250.0  Inpatient Medicare +150%
# 39490                     250.0  Inpatient Medicare +150%
# 39491                     250.0  Inpatient Medicare +150%
# 39492                     250.0  Inpatient Medicare +150%
# 39493                     250.0  Inpatient Medicare +150%
# ...                         ...                       ...
# 463944                    200.0  Inpatient Medicare +100%
# 463945                    200.0  Inpatient Medicare +100%
# 463946                    200.0  Inpatient Medicare +100%
# 463947                    200.0  Inpatient Medicare +100%
# 463948                    200.0  Inpatient Medicare +100%
#
# [70 rows x 12 columns]

# %%
df.loc[df['standard_charge'] == 'N/A']
# Out:
#        local_code   code                                        description
# 39496    25000003    NaN                           ACETYLCYSTEINE 20 % SOLN  \
# 39497    25000003    NaN         ALBUTEROL (5 MG/ML) 0.5% NEBU 20 ML BOTTLE
# 39498    25000003    NaN                      ATROPINE 1 % SOLN 5 ML BOTTLE
# 39499    25000003    NaN                     AZTREONAM 1 G SOLR 1 EACH VIAL
# 39500    25000003    NaN                     AZTREONAM 2 G SOLR 1 EACH VIAL
# ...           ...    ...                                                ...
# 542900   98800015  99222  PC INITIAL HOSPITAL INP/OBSERV CARE LVL 2 MODE...
# 542901   98800016  99223  PC INITIAL HOSPITAL INP/OBSERV CARE LVL 3 HIGH...
# 542902   98800017  99231  PC SUBSQ HOSPITAL INP/OBSERV CARE LVL 1 LOW 25...
# 542903   98800018  99232  PC SUBSQ HOSPITAL INP/OBSERV CARE LVL 2 MODERA...
# 542904   98800019  99233  PC SUBSQ HOSPITAL INP/OBSERV CARE LVL 3 HIGH 5...
#
#        rev_code drug_quantity                   payer_name standard_charge
# 39496       250          <NA>        6 DEGREES HEALTH, INC             N/A  \
# 39497       250          <NA>        6 DEGREES HEALTH, INC             N/A
# 39498       250          <NA>        6 DEGREES HEALTH, INC             N/A
# 39499       250          <NA>        6 DEGREES HEALTH, INC             N/A
# 39500       250          <NA>        6 DEGREES HEALTH, INC             N/A
# ...         ...           ...                          ...             ...
# 542900      987          <NA>  UNITED HEALTH CARE MEDICARE             N/A
# 542901      987          <NA>  UNITED HEALTH CARE MEDICARE             N/A
# 542902      987          <NA>  UNITED HEALTH CARE MEDICARE             N/A
# 542903      987          <NA>  UNITED HEALTH CARE MEDICARE             N/A
# 542904      987          <NA>  UNITED HEALTH CARE MEDICARE             N/A
#
#        ms_drg hcpcs_cpt rate_category  standard_charge_percent
# 39496     NaN       NaN    negotiated                      NaN  \
# 39497     NaN       NaN    negotiated                      NaN
# 39498     NaN       NaN    negotiated                      NaN
# 39499     NaN       NaN    negotiated                      NaN
# 39500     NaN       NaN    negotiated                      NaN
# ...       ...       ...           ...                      ...
# 542900    NaN     99222    negotiated                      NaN
# 542901    NaN     99223    negotiated                      NaN
# 542902    NaN     99231    negotiated                      NaN
# 542903    NaN     99232    negotiated                      NaN
# 542904    NaN     99233    negotiated                      NaN
#
#        additional_generic_notes
# 39496                       NaN
# 39497                       NaN
# 39498                       NaN
# 39499                       NaN
# 39500                       NaN
# ...                         ...
# 542900                      NaN
# 542901                      NaN
# 542902                      NaN
# 542903                      NaN
# 542904                      NaN
#
# [153367 rows x 12 columns]

# %%
hosp_map = {
    '370512290_GOOD-SHEPHERD-HOSPITAL_STANDARDCHAGES.txt': '140019',
    '370661233_ST-ANTHONY-S-MEMORIAL-HOSPITAL_STANDARDCHARGES.txt': '140032',
    '370661238_ST-JOHN-S-HOSPITAL_STANDARDCHARGES.txt': '140053',
    '370792770_HOLY-FAMILY-HOSPITAL_STANDARDCHARGES.txt': '140137',
    '371208459_ST-JOSEPH-S-HOSPITAL-BREESE_STANDARDCHARGES.txt': '140145',
    '370661244_ST-MARY-S-HOSPITAL-DECATUR_STANDARDCHARGES.txt': '140166',
    '370663567_ST-ELIZABETH-S-HOSPITAL_STANDARDCHARGES.txt': '140187',
    '370663568_ST-JOSEPH-S-HOSPITAL-HIGHLAND_STANDARDCHARGES.txt': '141336',
    '370661236_ST-FRANCIS-HOSPITAL_STANDARDCHARGES.txt': '141350',
    '390807060_SACRED-HEART-HOSPITAL_STANDARDCHARGES.txt': '520013',
    '390810545_ST-JOSEPH-S-CHIPPEWA-FALLS_STANDARDCHARGES.txt': '520017',
    '390808480_ST-NICHOLAS-HOSPITAL_STANDARDCHARGES.txt': '520044',
    '390817529_ST-VINCENT-HOSPITAL_STANDARDCHARGES.txt': '520075',
    '390818682_ST-MARY-S-HOSPITAL_STANDARDCHARGES.txt': '520097',
    '390848401_ST-CLARE-MEMORIAL-HOSPITAL_STANDARDCHARGES.txt': '521310'
}

hosp_id = hosp_map[file]

df['hospital_id'] = hosp_id

output_folder = './output_files/'

# df.to_csv(output_folder + hosp_id + '_' + file.split('_')[1] + '.csv', index=False)
