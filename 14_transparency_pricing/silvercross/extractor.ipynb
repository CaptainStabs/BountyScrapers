# %%
import pandas as pd
import numpy as np

# %%
folder = '.\\input_files\\'

file = '362174832_silvercrosshospital_standardcharges_033123.csv'

# %%
df = pd.read_csv(folder + file, dtype=str, skiprows=2)

# %%
df.drop(columns='hospital_id', inplace=True)

# %%
df.rename(columns={
    'DRG': 'ms_drg',
    'APR-DRG': 'apr_drg',
    'APC': 'apc',
    'EAPG': 'eapg',
    'item_description': 'description',
    'item_setting': 'setting'
}, inplace=True)

# %%
df.rename(columns=lambda x: x.strip(), inplace=True)

# %%
cols = df.columns.tolist()
id_vars = cols[:11]
value_vars = cols[11:]

df = pd.melt(df, id_vars=id_vars, value_vars=value_vars, var_name='payer_name', value_name='standard_charge')

# %%
df.loc[~df['ms_drg'].isna(), 'ms_drg'] = df['ms_drg'].str.zfill(3)

# %%
df.loc[~df['cpt'].isna(), 'hcpcs_cpt'] = df['cpt']
df.loc[~df['hcpcs'].isna(), 'hcpcs_cpt'] = df['hcpcs']

# %%
df['setting'] = np.where(df['setting'] == 'O', 'outpatient', np.where(df['setting'] == 'I', 'inpatient', 1))

# %%
df.drop(columns=['cpt_modifier', 'hcpcs_modifier', 'cpt', 'hcpcs'], inplace=True)

# %%
payer_mapping = {
    'gross_charge': 'gross',
    'cash_price': 'cash',
    'de_identified_min': 'min',
    'de_identified_max': 'max',
}

df['payer_category'] = df['payer_name'].map(payer_mapping).fillna('payer')

# %%
df.dropna(subset=['standard_charge'], inplace=True)

# %%
df['hospital_id'] = '140213'

# %%
df.loc[~df['rev_code'].isna(), 'rev_code'] = df['rev_code'].str.zfill(4)
df.loc[~df['apc'].isna(), 'apc'] = df['apc'].str.zfill(4)

# %%
df.loc[df['standard_charge'].str.contains('%')].drop_duplicates(subset='standard_charge')
# Out:
#        ms_drg apr_drg  apc eapg rev_code
# 72125     003     NaN  NaN  NaN      NaN  \
# 230922    003     NaN  NaN  NaN      NaN
# 240263    003     NaN  NaN  NaN      NaN
#
#                                               description    setting
# 72125   ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...  inpatient  \
# 230922  ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...  inpatient
# 240263  ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...  inpatient
#
#                payer_name      standard_charge hcpcs_cpt payer_category
# 72125      BCBS Indemnity  38% of Gross Charge       NaN          payer  \
# 230922  MPI Complementary  90% of Gross Charge       NaN          payer
# 240263        MPI Primary  80% of Gross Charge       NaN          payer
#
#        hospital_id
# 72125       140213
# 230922      140213
# 240263      140213

# %%
mask = df['standard_charge'].str.contains('%')
df.loc[mask, 'standard_charge_percent'] = df['standard_charge'].str.extract(r'(\d{2})%', expand=False)
df.loc[mask, 'contracting_method'] = 'percent of total billed charge'
df.loc[mask, 'additional_payer_specific_notes'] = df['standard_charge']
df.loc[mask, 'standard_charge'] = pd.NA

# %%
df.loc[mask]
# Out:
#        ms_drg apr_drg  apc eapg rev_code
# 72125     003     NaN  NaN  NaN      NaN  \
# 72126     004     NaN  NaN  NaN      NaN
# 72127     011     NaN  NaN  NaN      NaN
# 72128     012     NaN  NaN  NaN      NaN
# 72129     013     NaN  NaN  NaN      NaN
# ...       ...     ...  ...  ...      ...
# 242861    NaN   952-2  NaN  NaN      NaN
# 242862    NaN   952-3  NaN  NaN      NaN
# 242863    NaN   952-4  NaN  NaN      NaN
# 242864    NaN   955-0  NaN  NaN      NaN
# 242865    NaN   956-0  NaN  NaN      NaN
#
#                                               description    setting
# 72125   ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...  inpatient  \
# 72126   TRACHEOSTOMY WITH MV >96 HOURS OR PRINCIPAL DI...  inpatient
# 72127   TRACHEOSTOMY FOR FACE, MOUTH AND NECK DIAGNOSE...  inpatient
# 72128   TRACHEOSTOMY FOR FACE, MOUTH AND NECK DIAGNOSE...  inpatient
# 72129   TRACHEOSTOMY FOR FACE, MOUTH AND NECK DIAGNOSE...  inpatient
# ...                                                   ...        ...
# 242861  NONEXTENSIVE PROCEDURE UNRELATED TO PRINCIPAL ...  inpatient
# 242862  NONEXTENSIVE PROCEDURE UNRELATED TO PRINCIPAL ...  inpatient
# 242863  NONEXTENSIVE PROCEDURE UNRELATED TO PRINCIPAL ...  inpatient
# 242864                             Principal Diag Invalid  inpatient
# 242865                                        Ungroupable  inpatient
#
#             payer_name standard_charge hcpcs_cpt payer_category hospital_id
# 72125   BCBS Indemnity            <NA>       NaN          payer      140213  \
# 72126   BCBS Indemnity            <NA>       NaN          payer      140213
# 72127   BCBS Indemnity            <NA>       NaN          payer      140213
# 72128   BCBS Indemnity            <NA>       NaN          payer      140213
# 72129   BCBS Indemnity            <NA>       NaN          payer      140213
# ...                ...             ...       ...            ...         ...
# 242861     MPI Primary            <NA>       NaN          payer      140213
# 242862     MPI Primary            <NA>       NaN          payer      140213
# 242863     MPI Primary            <NA>       NaN          payer      140213
# 242864     MPI Primary            <NA>       NaN          payer      140213
# 242865     MPI Primary            <NA>       NaN          payer      140213
#
#        standard_charge_percent              contracting_method
# 72125                       38  percent of total billed charge  \
# 72126                       38  percent of total billed charge
# 72127                       38  percent of total billed charge
# 72128                       38  percent of total billed charge
# 72129                       38  percent of total billed charge
# ...                        ...                             ...
# 242861                      80  percent of total billed charge
# 242862                      80  percent of total billed charge
# 242863                      80  percent of total billed charge
# 242864                      80  percent of total billed charge
# 242865                      80  percent of total billed charge
#
#        additional_payer_specific_notes
# 72125              38% of Gross Charge
# 72126              38% of Gross Charge
# 72127              38% of Gross Charge
# 72128              38% of Gross Charge
# 72129              38% of Gross Charge
# ...                                ...
# 242861             80% of Gross Charge
# 242862             80% of Gross Charge
# 242863             80% of Gross Charge
# 242864             80% of Gross Charge
# 242865             80% of Gross Charge
#
# [6099 rows x 15 columns]

# %%
df.loc[df['standard_charge'].isna() & df['standard_charge_percent'].isna()]
# Out:
# Empty DataFrame
# Columns: [ms_drg, apr_drg, apc, eapg, rev_code, description, setting, payer_name, standard_charge, hcpcs_cpt, payer_category, hospital_id, standard_charge_percent, contracting_method, additional_payer_specific_notes]
# Index: []

# %%
df.to_csv('.\\output_files\\output.csv', index=False)
