# %%
import pandas as pd
import numpy as np

# %%
folder = '.\\input_files\\'

file = '362174832_silvercrosshospital_standardcharges_033123.csv'

# %%
df = pd.read_csv(folder + file, dtype=str, skiprows=2)

# %%
df.drop(columns='hospital_id', inplace=True)

# %%
df.rename(columns={
    'DRG': 'ms_drg',
    'APR-DRG': 'apr_drg',
    'APC': 'apc',
    'EAPG': 'eapg',
    'item_description': 'description',
    'item_setting': 'setting'
}, inplace=True)

# %%
df.rename(columns=lambda x: x.strip(), inplace=True)

# %%
cols = df.columns.tolist()
id_vars = cols[:11]
value_vars = cols[11:]

df = pd.melt(df, id_vars=id_vars, value_vars=value_vars, var_name='payer_name', value_name='standard_charge')

# %%
df.loc[~df['ms_drg'].isna(), 'ms_drg'] = df['ms_drg'].str.zfill(3)

# %%
df.loc[~df['cpt'].isna(), 'hcpcs_cpt'] = df['cpt']
df.loc[~df['hcpcs'].isna(), 'hcpcs_cpt'] = df['hcpcs']

# %%
df['setting'] = np.where(df['setting'] == 'O', 'outpatient', np.where(df['setting'] == 'I', 'inpatient', 1))

# %%
df.drop(columns=['cpt_modifier', 'hcpcs_modifier', 'cpt', 'hcpcs'], inplace=True)

# %%
payer_mapping = {
    'gross_charge': 'gross',
    'cash_price': 'cash',
    'de_identified_min': 'min',
    'de_identified_max': 'max',
}

df['payer_category'] = df['payer_name'].map(payer_mapping).fillna('payer')

# %%
df.dropna(subset=['standard_charge'], inplace=True)

# %%
df['hospital_id'] = '140213'
# Out:
#        ms_drg apr_drg   apc eapg rev_code
# 0         NaN     NaN   NaN  NaN      110  \
# 9341      NaN     NaN   NaN  NaN      110
# 18763     NaN     NaN   NaN  NaN      260
# 28105     NaN     NaN  5693  NaN      260
# 37415     NaN     NaN   NaN  NaN      250
# 46756     NaN     NaN   NaN  NaN      250
# 56097     NaN     NaN   NaN  NaN      250
# 65387     NaN     NaN   NaN  NaN      110
# 74810     NaN     NaN  5693  NaN      260
# 91558     NaN     NaN   NaN    1      NaN
# 93492     NaN     NaN  5693  NaN      260
# 109489    003     NaN   NaN  NaN      NaN
# 112143    NaN     NaN   NaN  NaN      250
# 121484    NaN     NaN   NaN  NaN      250
# 130825    NaN     NaN   NaN  NaN      250
# 140166    NaN     NaN   NaN  NaN      250
# 149538    NaN     NaN  5693  NaN      260
# 158879    NaN     NaN  5693  NaN      260
# 168189    NaN     NaN   NaN  NaN      250
# 177561    NaN     NaN  5693  NaN      260
# 186871    NaN     NaN   NaN  NaN      250
# 196212    NaN     NaN   NaN  NaN      250
# 205584    NaN     NaN  5693  NaN      260
# 214843    NaN     NaN   NaN  NaN      110
# 224235    NaN     NaN   NaN  NaN      250
# 233547    NaN     NaN   NaN  NaN      171
# 242936    NaN     NaN   NaN  NaN      255
# 252258    NaN     NaN   NaN  NaN      250
# 261566    NaN     NaN   NaN  NaN      118
# 270907    NaN     NaN   NaN  NaN      118
# 280248    NaN     NaN   NaN  NaN      118
# 289653    NaN     NaN  5693  NaN      260
# 305650    003     NaN   NaN  NaN      NaN
# 308271    NaN     NaN   NaN  NaN      118
# 317594    NaN     NaN   NaN  NaN      110
# 326935    NaN     NaN   NaN  NaN      110
#
#                                               description     setting
# 0                                1-7 MED SURG ROOM CHARGE   inpatient  \
# 9341                             1-7 MED SURG ROOM CHARGE   inpatient
# 18763                          INJ IVP ADDL SEQ SAME DRUG  outpatient
# 28105                                INJ IVP SNGL/INITIAL  outpatient
# 37415                                           IV D5W IL  outpatient
# 46756                                           IV D5W IL  outpatient
# 56097                                           IV D5W IL  outpatient
# 65387                            1-7 MED SURG ROOM CHARGE   inpatient
# 74810                                INJ IVP SNGL/INITIAL  outpatient
# 91558                                   PHOTOCHEMOTHERAPY  outpatient
# 93492                                INJ IVP SNGL/INITIAL  outpatient
# 109489  ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...   inpatient
# 112143                                          IV D5W IL  outpatient
# 121484                                          IV D5W IL  outpatient
# 130825                                          IV D5W IL  outpatient
# 140166                                          IV D5W IL  outpatient
# 149538                               INJ IVP SNGL/INITIAL  outpatient
# 158879                               INJ IVP SNGL/INITIAL  outpatient
# 168189                                          IV D5W IL  outpatient
# 177561                               INJ IVP SNGL/INITIAL  outpatient
# 186871                                          IV D5W IL  outpatient
# 196212                                          IV D5W IL  outpatient
# 205584                               INJ IVP SNGL/INITIAL  outpatient
# 214843                           1-7 MED SURG ROOM CHARGE   inpatient
# 224235                                          IV D5W IL  outpatient
# 233547                            NURSERY BOARDER LEVEL I   inpatient
# 242936                       SP LOCM 350-399MG IODINE 1ML  outpatient
# 252258                                          IV D5W IL  outpatient
# 261566                                  REHAB ROOM CHARGE   inpatient
# 270907                                  REHAB ROOM CHARGE   inpatient
# 280248                                  REHAB ROOM CHARGE   inpatient
# 289653                               INJ IVP SNGL/INITIAL  outpatient
# 305650  ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...   inpatient
# 308271                                  REHAB ROOM CHARGE   inpatient
# 317594                           1-7 MED SURG ROOM CHARGE   inpatient
# 326935                           1-7 MED SURG ROOM CHARGE   inpatient
#
#                                                payer_name standard_charge
# 0                                            gross_charge            1166  \
# 9341                                           cash_price             583
# 18763   Aetna Commercial: HMO,PPO, POS, Coventry (HMO,...           76.72
# 28105                                      Aetna Medicare     213.0166708
# 37415                                    BCBS Blue Choice         21.8484
# 46756                             BCBS Blue Precision HMO         42.9114
# 56097                                   BCBS HMO Illinois         42.9828
# 65387                                      BCBS Indemnity          443.08
# 74810                                           BCBS MMAI     185.3245036
# 91558                                       BCBS Medicaid     68.63727804
# 93492         BCBS Medicare Advantage: Medicare (HMO,PPO)     213.0166708
# 109489                               BCBS Medicare Select     129682.6757
# 112143                                           BCBS PPO         26.1324
# 121484                                BCBS Workers Choice           49.98
# 130825                                  Cigna HMO,PPO,POS           46.41
# 140166                                   Cigna Local Plus         31.5588
# 149538   Essential Health Partner Commercial HMO Site 502     234.3183379
# 158879        Essential Health Partner Medicare Advantage     213.0166708
# 168189                                      FHP/Principal           53.55
# 177561                                       HSTechnology             363
# 186871                            Health Alliance Medical           49.98
# 196212                     Humana Commercial: HMO,PPO,POS            35.7
# 205584  Humana Medicare Advantage: Humana Gold Medicar...     213.0166708
# 214843                                         Local 1546           466.4
# 224235                                  MPI Complementary           64.26
# 233547                                        MPI Primary             985
# 242936                                   MPI Workers Comp        1.146992
# 252258                           Premier Suburban Medical           42.84
# 261566                              United Healthcare ACO             782
# 270907                        United Healthcare All Payer             920
# 280248                          United Healthcare Charter             782
# 289653               United Healthcare Medicare Advantage     213.0166708
# 305650                  United Healthcare Medicare Select     129682.6757
# 308271                    United Healthcare Navigate/Core             782
# 317594                                  de_identified_min          443.08
# 326935                                  de_identified_max           466.4
#
#        hcpcs_cpt payer_category
# 0            NaN          gross
# 9341         NaN           cash
# 18763      96376          payer
# 28105      96374          payer
# 37415        NaN          payer
# 46756        NaN          payer
# 56097        NaN          payer
# 65387        NaN          payer
# 74810      96374          payer
# 91558        NaN          payer
# 93492      96374          payer
# 109489       NaN          payer
# 112143       NaN          payer
# 121484       NaN          payer
# 130825       NaN          payer
# 140166       NaN          payer
# 149538     96374          payer
# 158879     96374          payer
# 168189       NaN          payer
# 177561     96374          payer
# 186871       NaN          payer
# 196212       NaN          payer
# 205584     96374          payer
# 214843       NaN          payer
# 224235       NaN          payer
# 233547       NaN          payer
# 242936     Q9951          payer
# 252258       NaN          payer
# 261566       NaN          payer
# 270907       NaN          payer
# 280248       NaN          payer
# 289653     96374          payer
# 305650       NaN          payer
# 308271       NaN          payer
# 317594       NaN            min
# 326935       NaN            max

# %%
df.to_csv('.\\output_files\\output.csv', index=False)
