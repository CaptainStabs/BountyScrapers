# %%
import pandas as pd
import numpy as np

# %%
folder = '.\\input_files\\'
file = '150539039_AURELIA-OSBORN-FOX-MEMORIAL-HOSPITAL_STANDARDCHARGES_0.csv'

# %%
df = pd.read_csv(folder + file, skiprows=3, dtype=str)

# %%
df.rename(columns={
    'Payer': 'payer_name',
    'Internal Code': 'local_code',
    'Code': 'code',
    'NDC': 'ndc',
    'Rev Code': 'rev_code',
    'Procedure Description': 'description',
    'Quantity': 'quantity',
    'Plan(s)': 'plan_name',
    'Contract': 'additional_payer_notes',
    'Code Type': 'line_type'

}, inplace=True)

# %%
df = df.assign(plan_name=df['plan_name'].str.split(',')).explode('plan_name')

# %%
df
# Out:
#                          payer_name
# 0                      AETNA [1001]  \
# 0                      AETNA [1001]
# 0                      AETNA [1001]
# 0                      AETNA [1001]
# 0                      AETNA [1001]
# ...                             ...
# 313468  MVP MANAGED MEDICAID [3509]
# 313469  MVP MANAGED MEDICAID [3509]
# 313469  MVP MANAGED MEDICAID [3509]
# 313469  MVP MANAGED MEDICAID [3509]
# 313469  MVP MANAGED MEDICAID [3509]
#
#                            additional_payer_notes
# 0                        FOX AETNA CONTRACT [162]  \
# 0                        FOX AETNA CONTRACT [162]
# 0                        FOX AETNA CONTRACT [162]
# 0                        FOX AETNA CONTRACT [162]
# 0                        FOX AETNA CONTRACT [162]
# ...                                           ...
# 313468  FOX MVP ESSENTIALS 1,2,5,6 CONTRACT [294]
# 313469  FOX MVP ESSENTIALS 1,2,5,6 CONTRACT [294]
# 313469  FOX MVP ESSENTIALS 1,2,5,6 CONTRACT [294]
# 313469  FOX MVP ESSENTIALS 1,2,5,6 CONTRACT [294]
# 313469  FOX MVP ESSENTIALS 1,2,5,6 CONTRACT [294]
#
#                                                plan_name local_code line_type
# 0                   AETNA ALLIED BENEFIT SYSTEM [100101]    H128220       EAP  \
# 0                      AETNA MANAGED CARE PLANS [100102]    H128220       EAP
# 0        AETNA SIGNATURE ADMINISTRATORS GENERIC [100103]    H128220       EAP
# 0                        AETNATRADITIONAL PLANS [100104]    H128220       EAP
# 0               1199 NATIONAL BENEFIT FUND(BAR) [100105]    H128220       EAP
# ...                                                  ...        ...       ...
# 313468                                        6 [350901]    H847021       EAP
# 313469                            MVP ESSENTIALS PLANS 1    H850140       EAP
# 313469                                                 2    H850140       EAP
# 313469                                                 5    H850140       EAP
# 313469                                        6 [350901]    H850140       EAP
#
#               code  ndc                                           rev_code
# 0              NaN  NaN  0270 - MEDICAL/SURGICAL SUPPLIES AND DEVICES -...  \
# 0              NaN  NaN  0270 - MEDICAL/SURGICAL SUPPLIES AND DEVICES -...
# 0              NaN  NaN  0270 - MEDICAL/SURGICAL SUPPLIES AND DEVICES -...
# 0              NaN  NaN  0270 - MEDICAL/SURGICAL SUPPLIES AND DEVICES -...
# 0              NaN  NaN  0270 - MEDICAL/SURGICAL SUPPLIES AND DEVICES -...
# ...            ...  ...                                                ...
# 313468  CPT« 84702  NaN                      0301 - LABORATORY - CHEMISTRY
# 313469  CPT« 85014  NaN                     0305 - LABORATORY - HEMATOLOGY
# 313469  CPT« 85014  NaN                     0305 - LABORATORY - HEMATOLOGY
# 313469  CPT« 85014  NaN                     0305 - LABORATORY - HEMATOLOGY
# 313469  CPT« 85014  NaN                     0305 - LABORATORY - HEMATOLOGY
#
#                       description quantity IP Price IP Expected Reimbursement
# 0       HC Restraints Limb Holder        1    10.44                       NaN  \
# 0       HC Restraints Limb Holder        1    10.44                       NaN
# 0       HC Restraints Limb Holder        1    10.44                       NaN
# 0       HC Restraints Limb Holder        1    10.44                       NaN
# 0       HC Restraints Limb Holder        1    10.44                       NaN
# ...                           ...      ...      ...                       ...
# 313468       HC Hcg, Tumor Marker        1    38.31                       NaN
# 313469  HC Blood Count Hematocrit        1    53.45                       NaN
# 313469  HC Blood Count Hematocrit        1    53.45                       NaN
# 313469  HC Blood Count Hematocrit        1    53.45                       NaN
# 313469  HC Blood Count Hematocrit        1    53.45                       NaN
#
#                      IP XR Detail OP Price OP Expected Reimbursement
# 0       Not reimbursed separately    10.44                      8.87  \
# 0       Not reimbursed separately    10.44                      8.87
# 0       Not reimbursed separately    10.44                      8.87
# 0       Not reimbursed separately    10.44                      8.87
# 0       Not reimbursed separately    10.44                      8.87
# ...                           ...      ...                       ...
# 313468  Not reimbursed separately    38.31                     14.84
# 313469  Not reimbursed separately    53.45                       2.4
# 313469  Not reimbursed separately    53.45                       2.4
# 313469  Not reimbursed separately    53.45                       2.4
# 313469  Not reimbursed separately    53.45                       2.4
#
#        Cash Price
# 0           10.44
# 0           10.44
# 0           10.44
# 0           10.44
# 0           10.44
# ...           ...
# 313468      38.31
# 313469      53.45
# 313469      53.45
# 313469      53.45
# 313469      53.45
#
# [1258917 rows x 16 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.loc[(~df['rev_code'].isna()), 'rev_code'] = df['rev_code'].str.extract(r'(\d{4})', expand=False)

# %%
df.drop(columns=['IP XR Detail'], inplace=True)

# %%
df
# Out:
#                           payer_name
# 0                       AETNA [1001]  \
# 1                       AETNA [1001]
# 2                       AETNA [1001]
# 3                       AETNA [1001]
# 4                       AETNA [1001]
# ...                              ...
# 1258912  MVP MANAGED MEDICAID [3509]
# 1258913  MVP MANAGED MEDICAID [3509]
# 1258914  MVP MANAGED MEDICAID [3509]
# 1258915  MVP MANAGED MEDICAID [3509]
# 1258916  MVP MANAGED MEDICAID [3509]
#
#                             additional_payer_notes
# 0                         FOX AETNA CONTRACT [162]  \
# 1                         FOX AETNA CONTRACT [162]
# 2                         FOX AETNA CONTRACT [162]
# 3                         FOX AETNA CONTRACT [162]
# 4                         FOX AETNA CONTRACT [162]
# ...                                            ...
# 1258912  FOX MVP ESSENTIALS 1,2,5,6 CONTRACT [294]
# 1258913  FOX MVP ESSENTIALS 1,2,5,6 CONTRACT [294]
# 1258914  FOX MVP ESSENTIALS 1,2,5,6 CONTRACT [294]
# 1258915  FOX MVP ESSENTIALS 1,2,5,6 CONTRACT [294]
# 1258916  FOX MVP ESSENTIALS 1,2,5,6 CONTRACT [294]
#
#                                                 plan_name local_code
# 0                    AETNA ALLIED BENEFIT SYSTEM [100101]    H128220  \
# 1                       AETNA MANAGED CARE PLANS [100102]    H128220
# 2         AETNA SIGNATURE ADMINISTRATORS GENERIC [100103]    H128220
# 3                         AETNATRADITIONAL PLANS [100104]    H128220
# 4                1199 NATIONAL BENEFIT FUND(BAR) [100105]    H128220
# ...                                                   ...        ...
# 1258912                                        6 [350901]    H847021
# 1258913                            MVP ESSENTIALS PLANS 1    H850140
# 1258914                                                 2    H850140
# 1258915                                                 5    H850140
# 1258916                                        6 [350901]    H850140
#
#         line_type        code  ndc rev_code                description
# 0             EAP         NaN  NaN     0270  HC Restraints Limb Holder  \
# 1             EAP         NaN  NaN     0270  HC Restraints Limb Holder
# 2             EAP         NaN  NaN     0270  HC Restraints Limb Holder
# 3             EAP         NaN  NaN     0270  HC Restraints Limb Holder
# 4             EAP         NaN  NaN     0270  HC Restraints Limb Holder
# ...           ...         ...  ...      ...                        ...
# 1258912       EAP  CPT« 84702  NaN     0301       HC Hcg, Tumor Marker
# 1258913       EAP  CPT« 85014  NaN     0305  HC Blood Count Hematocrit
# 1258914       EAP  CPT« 85014  NaN     0305  HC Blood Count Hematocrit
# 1258915       EAP  CPT« 85014  NaN     0305  HC Blood Count Hematocrit
# 1258916       EAP  CPT« 85014  NaN     0305  HC Blood Count Hematocrit
#
#         quantity IP Price IP Expected Reimbursement OP Price
# 0              1    10.44                       NaN    10.44  \
# 1              1    10.44                       NaN    10.44
# 2              1    10.44                       NaN    10.44
# 3              1    10.44                       NaN    10.44
# 4              1    10.44                       NaN    10.44
# ...          ...      ...                       ...      ...
# 1258912        1    38.31                       NaN    38.31
# 1258913        1    53.45                       NaN    53.45
# 1258914        1    53.45                       NaN    53.45
# 1258915        1    53.45                       NaN    53.45
# 1258916        1    53.45                       NaN    53.45
#
#         OP Expected Reimbursement Cash Price
# 0                            8.87      10.44
# 1                            8.87      10.44
# 2                            8.87      10.44
# 3                            8.87      10.44
# 4                            8.87      10.44
# ...                           ...        ...
# 1258912                     14.84      38.31
# 1258913                       2.4      53.45
# 1258914                       2.4      53.45
# 1258915                       2.4      53.45
# 1258916                       2.4      53.45
#
# [1258917 rows x 15 columns]

# %%
cols = df.columns.tolist()
val_vars = ['IP Price', 'OP Price', 'Cash Price']
if 'line_type' in cols:
    id_vars = cols[:10]
    # val_vars = cols[10:]
else:
    id_vars = cols[:9]
    # val_vars = cols[9:]

df_other = pd.melt(df, id_vars=id_vars, value_vars=val_vars, var_name='payer_name_temp', value_name='standard_charge')

# %%
df.drop(columns=val_vars, inplace=True)

# %%
df_other.drop(columns=['payer_name', 'additional_payer_notes', 'plan_name'], inplace=True)

# %%
df_other.rename(columns={'payer_name_temp': 'payer_name'}, inplace=True)
df_other.drop_duplicates(subset='payer_name')
# Out:
#         local_code line_type code  ndc rev_code                description
# 0          H128220       EAP  NaN  NaN     0270  HC Restraints Limb Holder  \
# 1258917    H128220       EAP  NaN  NaN     0270  HC Restraints Limb Holder
# 2517834    H128220       EAP  NaN  NaN     0270  HC Restraints Limb Holder
#
#         quantity  payer_name standard_charge
# 0              1    IP Price           10.44
# 1258917        1    OP Price           10.44
# 2517834        1  Cash Price           10.44

# %%
cols = df.columns.tolist()
if 'line_type' in cols:
    id_vars = cols[:10]
    val_vars = cols[10:]
else:
    id_vars = cols[:9]
    val_vars = cols[9:]

df = pd.melt(df, id_vars=id_vars, value_vars=val_vars, var_name='payer_type', value_name='standard_charge')

# %%
# This entire df is just the payers and their rates, none of the other types
df['payer_category'] = 'payer'

# %%
df = pd.concat([df, df_other])

# %%
# Set column `setting` to either `inpatient` if col `payer` starts with  'IP' or `outpatient` if col `payer` starts with  'OP'
df['setting'] = np.where(df['payer_type'].str.startswith('IP '), 'inpatient', np.where(df['payer_type'].str.startswith('OP '), 'outpatient', 1))
df['setting'] = np.where(df['payer_type'].isnull() & df['payer_name'].str.startswith('IP '), 'inpatient', np.where(df['payer_type'].isnull() & df['payer_name'].str.startswith('OP '), 'outpatient', df['setting']))

# %%
df.loc[df['payer_name'] == 'Cash Price', 'setting'] = pd.NA

# %%
df.drop_duplicates(subset='payer_name')
# Out:
#                                           payer_name
# 0                                       AETNA [1001]  \
# 141148                                  CDPHP [1003]
# 151230                                  CIGNA [1004]
# 191558                      EMBLEM COMMERCIAL [1005]
# 231886                      EMPIRE COMMERCIAL [1006]
# 272214                    EXCELLUS COMMERCIAL [1007]
# 277255                     GENERIC COMMERCIAL [1008]
# 347829            LIFETIME BENEFITS SOLUTIONS [1009]
# 352870                                    MVP [1010]
# 403280                        NEIC COMMERCIAL [1011]
# 483936                                   PHCS [1012]
# 549469                                  POMCO [1013]
# 559551               UNITED BEHAVIORAL HEALTH [1014]
# 584756                      UNITED HEALTHCARE [1015]
# 781355                                UNIVERA [1016]
# 786396              BEACON HEALTH OPTIONS ALT [1017]
# 796478                VETERANS ADMINISTRATION [1018]
# 811601                              MULTIPLAN [1023]
# 816642                  BEACON HEALTH OPTIONS [1024]
# 821683                                FIDELIS [1026]
# 826724                                TRICARE [1027]
# 831765                                CHAMPVA [2001]
# 836806                               MEDICARE [2002]
# 862011                                TRICARE [2003]
# 872093                          MARTINS POINT [2004]
# 877134               AETNA MEDICARE ADVANTAGE [2501]
# 887216              BSNENY MEDICARE ADVANTAGE [2502]
# 892257               CDPHP MEDICARE ADVANTAGE [2503]
# 902339              EMBLEM MEDICARE ADVANTAGE [2504]
# 907380              EMPIRE MEDICARE ADVANTAGE [2505]
# 912421            EXCELLUS MEDICARE ADVANTAGE [2506]
# 932585             FIDELIS MEDICARE ADVANTAGE [2507]
# 942667                 MVP MEDICARE ADVANTAGE [2508]
# 947708                     MEDICARE ADVANTAGE [2509]
# 967872                        TODAY'S OPTIONS [2510]
# 977954   UNITED HEALTHCARE MEDICARE ADVANTAGE [2512]
# 1063651             HUMANA MEDICARE ADVANTAGE [2513]
# 1068692                 WELLCARE HEALTH PLANS [2514]
# 1093897                              MEDICAID [3001]
# 1129184           CDPHP MEDICAID MANAGED CARE [3501]
# 1149348          EMBLEM MEDICAID MANAGED CARE [3503]
# 1154389          EMPIRE MEDICAID MANAGED CARE [3504]
# 1164471        EXCELLUS MEDICAID MANAGED CARE [3505]
# 1194717         FIDELIS MEDICAID MANAGED CARE [3506]
# 1219922         GENERIC MEDICAID MANAGED CARE [3507]
# 1250168                            HEALTHPLEX [3508]
# 1255209                  MVP MANAGED MEDICAID [3509]
# 2517834                                     IP Price
# 3776751                                     OP Price
# 5035668                                   Cash Price
#
#                             additional_payer_notes
# 0                         FOX AETNA CONTRACT [162]  \
# 141148                    FOX CDPHP CONTRACT [202]
# 151230                       FOX MVP CONTRACT [76]
# 191558                   FOX  EMBLEM CONTRACT [74]
# 231886                FOX BLUE CROSS CONTRACT [73]
# 272214               FOX BCBS UTICA CONTRACT [200]
# 277255                FOX CATCH ALL CONTRACT [165]
# 347829        FOX LIFETIME BENEFITS CONTRACT [208]
# 352870                       FOX MVP CONTRACT [76]
# 403280                FOX CATCH ALL CONTRACT [165]
# 483936                FOX CATCH ALL CONTRACT [165]
# 549469                    FOX POMCO CONTRACT [172]
# 559551                FOX CATCH ALL CONTRACT [165]
# 584756                FOX CATCH ALL CONTRACT [165]
# 781355                FOX CATCH ALL CONTRACT [165]
# 786396                FOX CATCH ALL CONTRACT [165]
# 796478                       FOX VA CONTRACT [171]
# 811601                FOX CATCH ALL CONTRACT [165]
# 816642                FOX CATCH ALL CONTRACT [165]
# 821683            FOX FIDELIS METAL CONTRACT [340]
# 826724               FOX MIXED APC  CONTRACT [203]
# 831765               FOX MIXED APC  CONTRACT [203]
# 836806                FOX CATCH ALL CONTRACT [165]
# 862011               FOX MIXED APC  CONTRACT [203]
# 872093            FOX MARTINS POINT CONTRACT [327]
# 877134                FOX AETNA MCR CONTRACT [424]
# 887216                FOX APC RATES CONTRACT [167]
# 892257               FOX MIXED APC  CONTRACT [203]
# 902339               FOX MIXED APC  CONTRACT [203]
# 907380          FOX EMPIRE MEDICARE CONTRACT [205]
# 912421          FOX EMPIRE MEDICARE CONTRACT [205]
# 932585              FOX FIDELIS MCR CONTRACT [213]
# 942667               FOX MIXED APC  CONTRACT [203]
# 947708                FOX CATCH ALL CONTRACT [165]
# 967872        FOX WELLCARE/TDO PFFS CONTRACT [278]
# 977954               FOX MIXED APC  CONTRACT [203]
# 1063651         FOX HUMANA MCR ADVT CONTRACT [432]
# 1068692              FOX MIXED APC  CONTRACT [203]
# 1093897                FOX MEDICAID CONTRACT [209]
# 1129184    FOX CDPHP ESSENTIALS 1,2 CONTRACT [299]
# 1149348                 FOX APG MIX CONTRACT [168]
# 1154389           FOX EMPIRE CHP/FHP CONTRACT [75]
# 1164471      FOX EXCELLUS/ HMO BLUE CONTRACT [207]
# 1194717                 FOX APG MIX CONTRACT [168]
# 1219922                FOX MEDICAID CONTRACT [209]
# 1250168               FOX CATCH ALL CONTRACT [165]
# 1255209  FOX MVP ESSENTIALS 1,2,5,6 CONTRACT [294]
# 2517834                                        NaN
# 3776751                                        NaN
# 5035668                                        NaN
#
#                                            plan_name local_code line_type
# 0               AETNA ALLIED BENEFIT SYSTEM [100101]    H128220       EAP  \
# 141148   CAPITAL DISTRICT PHYSICIANS HEALTH [100301]    H128220       EAP
# 151230                                CIGNA [100401]    H128220       EAP
# 191558              EMBLEM HEALTH CBP PLANS [100501]    H128220       EAP
# 231886                         BC EMPIRE HB [100601]    H128220       EAP
# 272214                      HEALTH NOW FLEX [100701]    H128220       EAP
# 277255                    EMBLEM HEALTH/GHI (DENTAL)    H128220       EAP
# 347829           LIFETIME BENEFIT SOLUTIONS [100901]    H128220       EAP
# 352870               MVP SMALL/LARGE GROUPS [101001]    H128220       EAP
# 403280            N E I C - HB ONLY GENERIC [101101]    H128220       EAP
# 483936                 PHCS NETWORK GENERIC [101201]    H128220       EAP
# 549469                                POMCO [101301]    H128220       EAP
# 559551     UNITED BEHAVIORAL HEALTH (AMPHE) [101401]    H128220       EAP
# 584756                                 AARP [101501]    H128220       EAP
# 781355                   UNIVERA HEALTHCARE [101601]    H128220       EAP
# 786396                BEACON HEALTH OPTIONS [101701]    H128220       EAP
# 796478     VETERANS ADMINISTRATION - ALBANY [101802]    H128220       EAP
# 811601                    MULTIPLAN GENERIC [102301]    H128220       EAP
# 816642                BEACON HEALTH OPTIONS [102401]    H128220       EAP
# 821683               FIDELIS METAL PRODUCTS [102601]    H128220       EAP
# 826724          TRICARE FOR LIFE (BAM ONLY) [102701]    H128220       EAP
# 831765                              CHAMPVA [200101]    H128220       EAP
# 836806         MEDIGAP SUPPLEMENTAL GENERIC [200208]    H128220       EAP
# 862011                 TRICARE NORTH REGION [200301]    H128220       EAP
# 872093             MARTINS POINT HEALTHCARE [200401]    H128220       EAP
# 877134     AETNA MEDICARE ADVANTAGE PPO/EPO [250101]    H128220       EAP
# 887216                 SENIOR BLUE MEDICARE [250201]    H128220       EAP
# 892257         CDPHP MEDICARE ADVANTAGE HMO [250301]    H128220       EAP
# 902339   EMBLEM HEALTH MEDICARE CHOICE PLUS [250401]    H128220       EAP
# 907380            EMPIRE MEDICARE ADVANTAGE [250501]    H128220       EAP
# 912421       BASSETT MEDICARE ADVANTAGE PPO [250601]    H128220       EAP
# 932585           FIDELIS MEDICARE ADVANTAGE [250701]    H128220       EAP
# 942667                    MVP GOLD/USA CARE [250801]    H128220       EAP
# 947708                         MSA PROCESSING CENTER    H128220       EAP
# 967872                  TODAYS OPTIONS PFFS [251002]    H128220       EAP
# 977954                  UHC MEDICARE COMPLETE CHOICE    H128220       EAP
# 1063651           HUMANA MEDICARE ADVANTAGE [251301]    H128220       EAP
# 1068692                    WELLCARE NON-PAR [251404]    H128220       EAP
# 1093897                         MEDICAID NY [300102]    H128220       EAP
# 1129184         CDPHP ESSENTIALS PLAN 1 & 2 [350103]    H128220       EAP
# 1149348  EMBLEM HEALTH CHP/MANAGED MEDICAID [350301]    H128220       EAP
# 1154389  EMPIRE CHILD HEALTHPLUS/HEALTHY NY [350401]    H128220       EAP
# 1164471          EXCELLUS CHILD HEALTH PLUS [350501]    H128220       EAP
# 1194717                    FIDELIS CARE CHP [350601]    H128220       EAP
# 1219922     MANAGED CARE-MNY ISSUED GENERIC [350701]    H128220       EAP
# 1250168                   HEALTHPLEX DENTAL [350801]    H128220       EAP
# 1255209                       MVP ESSENTIALS PLANS 1     H97760       EAP
# 2517834                                          NaN    H128220       EAP
# 3776751                                          NaN    H128220       EAP
# 5035668                                          NaN    H128220       EAP
#
#                code  ndc rev_code
# 0               NaN  NaN     0270  \
# 141148          NaN  NaN     0270
# 151230          NaN  NaN     0270
# 191558          NaN  NaN     0270
# 231886          NaN  NaN     0270
# 272214          NaN  NaN     0270
# 277255          NaN  NaN     0270
# 347829          NaN  NaN     0270
# 352870          NaN  NaN     0270
# 403280          NaN  NaN     0270
# 483936          NaN  NaN     0270
# 549469          NaN  NaN     0270
# 559551          NaN  NaN     0270
# 584756          NaN  NaN     0270
# 781355          NaN  NaN     0270
# 786396          NaN  NaN     0270
# 796478          NaN  NaN     0270
# 811601          NaN  NaN     0270
# 816642          NaN  NaN     0270
# 821683          NaN  NaN     0270
# 826724          NaN  NaN     0270
# 831765          NaN  NaN     0270
# 836806          NaN  NaN     0270
# 862011          NaN  NaN     0270
# 872093          NaN  NaN     0270
# 877134          NaN  NaN     0270
# 887216          NaN  NaN     0270
# 892257          NaN  NaN     0270
# 902339          NaN  NaN     0270
# 907380          NaN  NaN     0270
# 912421          NaN  NaN     0270
# 932585          NaN  NaN     0270
# 942667          NaN  NaN     0270
# 947708          NaN  NaN     0270
# 967872          NaN  NaN     0270
# 977954          NaN  NaN     0270
# 1063651         NaN  NaN     0270
# 1068692         NaN  NaN     0270
# 1093897         NaN  NaN     0270
# 1129184         NaN  NaN     0270
# 1149348         NaN  NaN     0270
# 1154389         NaN  NaN     0270
# 1164471         NaN  NaN     0270
# 1194717         NaN  NaN     0270
# 1219922         NaN  NaN     0270
# 1250168         NaN  NaN     0270
# 1255209  CPT« 97760  NaN     0420
# 2517834         NaN  NaN     0270
# 3776751         NaN  NaN     0270
# 5035668         NaN  NaN     0270
#
#                                              description quantity
# 0                              HC Restraints Limb Holder        1  \
# 141148                         HC Restraints Limb Holder        1
# 151230                         HC Restraints Limb Holder        1
# 191558                         HC Restraints Limb Holder        1
# 231886                         HC Restraints Limb Holder        1
# 272214                         HC Restraints Limb Holder        1
# 277255                         HC Restraints Limb Holder        1
# 347829                         HC Restraints Limb Holder        1
# 352870                         HC Restraints Limb Holder        1
# 403280                         HC Restraints Limb Holder        1
# 483936                         HC Restraints Limb Holder        1
# 549469                         HC Restraints Limb Holder        1
# 559551                         HC Restraints Limb Holder        1
# 584756                         HC Restraints Limb Holder        1
# 781355                         HC Restraints Limb Holder        1
# 786396                         HC Restraints Limb Holder        1
# 796478                         HC Restraints Limb Holder        1
# 811601                         HC Restraints Limb Holder        1
# 816642                         HC Restraints Limb Holder        1
# 821683                         HC Restraints Limb Holder        1
# 826724                         HC Restraints Limb Holder        1
# 831765                         HC Restraints Limb Holder        1
# 836806                         HC Restraints Limb Holder        1
# 862011                         HC Restraints Limb Holder        1
# 872093                         HC Restraints Limb Holder        1
# 877134                         HC Restraints Limb Holder        1
# 887216                         HC Restraints Limb Holder        1
# 892257                         HC Restraints Limb Holder        1
# 902339                         HC Restraints Limb Holder        1
# 907380                         HC Restraints Limb Holder        1
# 912421                         HC Restraints Limb Holder        1
# 932585                         HC Restraints Limb Holder        1
# 942667                         HC Restraints Limb Holder        1
# 947708                         HC Restraints Limb Holder        1
# 967872                         HC Restraints Limb Holder        1
# 977954                         HC Restraints Limb Holder        1
# 1063651                        HC Restraints Limb Holder        1
# 1068692                        HC Restraints Limb Holder        1
# 1093897                        HC Restraints Limb Holder        1
# 1129184                        HC Restraints Limb Holder        1
# 1149348                        HC Restraints Limb Holder        1
# 1154389                        HC Restraints Limb Holder        1
# 1164471                        HC Restraints Limb Holder        1
# 1194717                        HC Restraints Limb Holder        1
# 1219922                        HC Restraints Limb Holder        1
# 1250168                        HC Restraints Limb Holder        1
# 1255209  HC Orthotic Mgmt and Training, Initial Ea 15min        1
# 2517834                        HC Restraints Limb Holder        1
# 3776751                        HC Restraints Limb Holder        1
# 5035668                        HC Restraints Limb Holder        1
#
#                         payer_type standard_charge payer_category     setting
# 0        IP Expected Reimbursement             NaN          payer   inpatient
# 141148   IP Expected Reimbursement             NaN          payer   inpatient
# 151230   IP Expected Reimbursement             NaN          payer   inpatient
# 191558   IP Expected Reimbursement             NaN          payer   inpatient
# 231886   IP Expected Reimbursement             NaN          payer   inpatient
# 272214   IP Expected Reimbursement             NaN          payer   inpatient
# 277255   IP Expected Reimbursement             NaN          payer   inpatient
# 347829   IP Expected Reimbursement             NaN          payer   inpatient
# 352870   IP Expected Reimbursement             NaN          payer   inpatient
# 403280   IP Expected Reimbursement             NaN          payer   inpatient
# 483936   IP Expected Reimbursement             NaN          payer   inpatient
# 549469   IP Expected Reimbursement             NaN          payer   inpatient
# 559551   IP Expected Reimbursement             NaN          payer   inpatient
# 584756   IP Expected Reimbursement             NaN          payer   inpatient
# 781355   IP Expected Reimbursement             NaN          payer   inpatient
# 786396   IP Expected Reimbursement             NaN          payer   inpatient
# 796478   IP Expected Reimbursement             NaN          payer   inpatient
# 811601   IP Expected Reimbursement             NaN          payer   inpatient
# 816642   IP Expected Reimbursement             NaN          payer   inpatient
# 821683   IP Expected Reimbursement             NaN          payer   inpatient
# 826724   IP Expected Reimbursement             NaN          payer   inpatient
# 831765   IP Expected Reimbursement             NaN          payer   inpatient
# 836806   IP Expected Reimbursement             NaN          payer   inpatient
# 862011   IP Expected Reimbursement             NaN          payer   inpatient
# 872093   IP Expected Reimbursement             NaN          payer   inpatient
# 877134   IP Expected Reimbursement             NaN          payer   inpatient
# 887216   IP Expected Reimbursement             NaN          payer   inpatient
# 892257   IP Expected Reimbursement             NaN          payer   inpatient
# 902339   IP Expected Reimbursement             NaN          payer   inpatient
# 907380   IP Expected Reimbursement             NaN          payer   inpatient
# 912421   IP Expected Reimbursement             NaN          payer   inpatient
# 932585   IP Expected Reimbursement             NaN          payer   inpatient
# 942667   IP Expected Reimbursement             NaN          payer   inpatient
# 947708   IP Expected Reimbursement             NaN          payer   inpatient
# 967872   IP Expected Reimbursement             NaN          payer   inpatient
# 977954   IP Expected Reimbursement             NaN          payer   inpatient
# 1063651  IP Expected Reimbursement             NaN          payer   inpatient
# 1068692  IP Expected Reimbursement             NaN          payer   inpatient
# 1093897  IP Expected Reimbursement             NaN          payer   inpatient
# 1129184  IP Expected Reimbursement             NaN          payer   inpatient
# 1149348  IP Expected Reimbursement             NaN          payer   inpatient
# 1154389  IP Expected Reimbursement             NaN          payer   inpatient
# 1164471  IP Expected Reimbursement             NaN          payer   inpatient
# 1194717  IP Expected Reimbursement             NaN          payer   inpatient
# 1219922  IP Expected Reimbursement             NaN          payer   inpatient
# 1250168  IP Expected Reimbursement             NaN          payer   inpatient
# 1255209  IP Expected Reimbursement             NaN          payer   inpatient
# 2517834                        NaN           10.44          gross   inpatient
# 3776751                        NaN           10.44          gross  outpatient
# 5035668                        NaN           10.44           cash        <NA>

# %%
df.reset_index(drop=True, inplace=True)

# %%
payer_mapping = {
    'IP Price': 'gross',
    'OP Price': 'gross', 
    # These two are not needed as I set them to payer earlier
    # 'IP Expected Reimbursement': 'payer',
    # 'OP Expected Reimbursement': 'payer',
    'Cash Price': 'cash'
}

df.loc[df['payer_category'].isna(), 'payer_category'] = df['payer_name'].map(payer_mapping)
# df['payer_category'] = df['payer_name'].map(payer_mapping)

# %%
df
# Out:
#            payer_name    additional_payer_notes
# 0        AETNA [1001]  FOX AETNA CONTRACT [162]  \
# 1        AETNA [1001]  FOX AETNA CONTRACT [162]
# 2        AETNA [1001]  FOX AETNA CONTRACT [162]
# 3        AETNA [1001]  FOX AETNA CONTRACT [162]
# 4        AETNA [1001]  FOX AETNA CONTRACT [162]
# ...               ...                       ...
# 6294580    Cash Price                       NaN
# 6294581    Cash Price                       NaN
# 6294582    Cash Price                       NaN
# 6294583    Cash Price                       NaN
# 6294584    Cash Price                       NaN
#
#                                                 plan_name local_code
# 0                    AETNA ALLIED BENEFIT SYSTEM [100101]    H128220  \
# 1                       AETNA MANAGED CARE PLANS [100102]    H128220
# 2         AETNA SIGNATURE ADMINISTRATORS GENERIC [100103]    H128220
# 3                         AETNATRADITIONAL PLANS [100104]    H128220
# 4                1199 NATIONAL BENEFIT FUND(BAR) [100105]    H128220
# ...                                                   ...        ...
# 6294580                                               NaN    H847021
# 6294581                                               NaN    H850140
# 6294582                                               NaN    H850140
# 6294583                                               NaN    H850140
# 6294584                                               NaN    H850140
#
#         line_type        code  ndc rev_code                description
# 0             EAP         NaN  NaN     0270  HC Restraints Limb Holder  \
# 1             EAP         NaN  NaN     0270  HC Restraints Limb Holder
# 2             EAP         NaN  NaN     0270  HC Restraints Limb Holder
# 3             EAP         NaN  NaN     0270  HC Restraints Limb Holder
# 4             EAP         NaN  NaN     0270  HC Restraints Limb Holder
# ...           ...         ...  ...      ...                        ...
# 6294580       EAP  CPT« 84702  NaN     0301       HC Hcg, Tumor Marker
# 6294581       EAP  CPT« 85014  NaN     0305  HC Blood Count Hematocrit
# 6294582       EAP  CPT« 85014  NaN     0305  HC Blood Count Hematocrit
# 6294583       EAP  CPT« 85014  NaN     0305  HC Blood Count Hematocrit
# 6294584       EAP  CPT« 85014  NaN     0305  HC Blood Count Hematocrit
#
#         quantity                 payer_type standard_charge payer_category
# 0              1  IP Expected Reimbursement             NaN          payer  \
# 1              1  IP Expected Reimbursement             NaN          payer
# 2              1  IP Expected Reimbursement             NaN          payer
# 3              1  IP Expected Reimbursement             NaN          payer
# 4              1  IP Expected Reimbursement             NaN          payer
# ...          ...                        ...             ...            ...
# 6294580        1                        NaN           38.31           cash
# 6294581        1                        NaN           53.45           cash
# 6294582        1                        NaN           53.45           cash
# 6294583        1                        NaN           53.45           cash
# 6294584        1                        NaN           53.45           cash
#
#            setting
# 0        inpatient
# 1        inpatient
# 2        inpatient
# 3        inpatient
# 4        inpatient
# ...            ...
# 6294580        NaN
# 6294581        NaN
# 6294582        NaN
# 6294583        NaN
# 6294584        NaN
#
# [6294585 rows x 14 columns]

# %%
df.drop_duplicates(subset='payer_type')
# Out:
#            payer_name    additional_payer_notes
# 0        AETNA [1001]  FOX AETNA CONTRACT [162]  \
# 1258917  AETNA [1001]  FOX AETNA CONTRACT [162]
# 2517834      IP Price                       NaN
#
#                                     plan_name local_code line_type code  ndc
# 0        AETNA ALLIED BENEFIT SYSTEM [100101]    H128220       EAP  NaN  NaN  \
# 1258917  AETNA ALLIED BENEFIT SYSTEM [100101]    H128220       EAP  NaN  NaN
# 2517834                                   NaN    H128220       EAP  NaN  NaN
#
#         rev_code                description quantity
# 0           0270  HC Restraints Limb Holder        1  \
# 1258917     0270  HC Restraints Limb Holder        1
# 2517834     0270  HC Restraints Limb Holder        1
#
#                         payer_type standard_charge payer_category     setting
# 0        IP Expected Reimbursement             NaN          payer   inpatient
# 1258917  OP Expected Reimbursement            8.87          payer  outpatient
# 2517834                        NaN           10.44          gross   inpatient

# %%
df.loc[df['quantity'] == '1', 'quantity'] = pd.NA
df['standard_charge'] = df['standard_charge'].str.replace('$', '').str.replace(',', '').str.strip()
df.loc[df['standard_charge'] == '-', 'standard_charge'] = pd.NA

# %%
df.dropna(subset='standard_charge', inplace=True)

# %%
df.loc[(~df['code'].isna()) & (df['code'].str.match('HCPCS|CPT')), 'hcpcs_cpt'] = df['code'].str.replace('HCPCS |CPT« ', '', regex=True)
df['hcpcs_cpt'] = df['hcpcs_cpt'].str.strip()
df.loc[(df['hcpcs_cpt'].str.len() == 8) | (df['hcpcs_cpt'] == 'CUSTOM') | (df['hcpcs_cpt'].str.len() != 5), 'hcpcs_cpt'] = pd.NA

# %%
df.loc[~df['code'].isna() & df['code'].str.contains('DRG')]
# Out:
# Empty DataFrame
# Columns: [payer_name, additional_payer_notes, plan_name, local_code, line_type, code, ndc, rev_code, description, quantity, payer_type, standard_charge, payer_category, setting, hcpcs_cpt]
# Index: []

# %%
# df.drop(columns='payer_type', inplace=True)

# %%
hospital_map = {
    '150539039_AURELIA-OSBORN-FOX-MEMORIAL-HOSPITAL_STANDARDCHARGES_0.csv': '330408',
    '135596796_MARY-IMOGENE-BASSETT-HOSPITAL_STANDARDCHARGES.csv': '330136',
    '161540394_OCONNOR-HOSPITAL_STANDARDCHARGES_0.csv': '331305',
    '150533578_LITTLE-FALLS-HOSPITAL_STANDARDCHARGES_0.csv': '331311',
    '141772971_COBLESKILL-REGIONAL-HOSPITAL_STANDARDCHARGES_0.csv': '331320',
    '150539039_AURELIA-OSBORN-FOX-MEMORIAL-HOSPITAL_STANDARDCHARGES_1.csv': '330085'
}

hosp_id = hospital_map[file]

df['hospital_id'] = hosp_id

# df.to_csv('.\\output_files\\' + hosp_id + file.split('_')[1] + '.csv', index=False)
