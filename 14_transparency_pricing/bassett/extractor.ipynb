# %%
import pandas as pd
import numpy as np

# %%
folder = '.\\input_files\\'
file = '141772971_COBLESKILL-REGIONAL-HOSPITAL_STANDARDCHARGES_0.csv'

# %%
df = pd.read_csv(folder + file, skiprows=3, dtype=str)

# %%
df.rename(columns={
    'Payer': 'payer_name',
    'Internal Code': 'local_code',
    'Code': 'code',
    'NDC': 'ndc',
    'Rev Code': 'rev_code',
    'Procedure Description': 'description',
    'Quantity': 'quantity',
    'Plan(s)': 'plan_name',
    'Contract': 'additional_payer_notes',
    'Code Type': 'line_type'

}, inplace=True)

# %%
df = df.assign(plan_name=df['plan_name'].str.split(',')).explode('plan_name')

# %%
df
# Out:
#                               payer_name       additional_payer_notes
# 0                           AETNA [1001]     CRH AETNA CONTRACT [115]  \
# 0                           AETNA [1001]     CRH AETNA CONTRACT [115]
# 0                           AETNA [1001]     CRH AETNA CONTRACT [115]
# 0                           AETNA [1001]     CRH AETNA CONTRACT [115]
# 0                           AETNA [1001]     CRH AETNA CONTRACT [115]
# ...                                  ...                          ...
# 257890  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
# 257891  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
# 257891  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
# 257892  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
# 257892  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
#
#                                                plan_name local_code line_type
# 0                   AETNA ALLIED BENEFIT SYSTEM [100101]    H128224       EAP  \
# 0                      AETNA MANAGED CARE PLANS [100102]    H128224       EAP
# 0        AETNA SIGNATURE ADMINISTRATORS GENERIC [100103]    H128224       EAP
# 0                        AETNATRADITIONAL PLANS [100104]    H128224       EAP
# 0               1199 NATIONAL BENEFIT FUND(BAR) [100105]    H128224       EAP
# ...                                                  ...        ...       ...
# 257890                                      NY [3001901]    H128209       EAP
# 257891                                          MEDICAID    H128215       EAP
# 257891                                      NY [3001901]    H128215       EAP
# 257892                                          MEDICAID    H128216       EAP
# 257892                                      NY [3001901]    H128216       EAP
#
#               code  ndc                                           rev_code
# 0              NaN  NaN  0270 - MEDICAL/SURGICAL SUPPLIES AND DEVICES -...  \
# 0              NaN  NaN  0270 - MEDICAL/SURGICAL SUPPLIES AND DEVICES -...
# 0              NaN  NaN  0270 - MEDICAL/SURGICAL SUPPLIES AND DEVICES -...
# 0              NaN  NaN  0270 - MEDICAL/SURGICAL SUPPLIES AND DEVICES -...
# 0              NaN  NaN  0270 - MEDICAL/SURGICAL SUPPLIES AND DEVICES -...
# ...            ...  ...                                                ...
# 257890         NaN  NaN  0272 - MEDICAL/SURGICAL SUPPLIES AND DEVICES -...
# 257891  CPT« 94799  NaN  0410 - RESPIRATORY SERVICES - GENERAL CLASSIFI...
# 257891  CPT« 94799  NaN  0410 - RESPIRATORY SERVICES - GENERAL CLASSIFI...
# 257892         NaN  NaN  0270 - MEDICAL/SURGICAL SUPPLIES AND DEVICES -...
# 257892         NaN  NaN  0270 - MEDICAL/SURGICAL SUPPLIES AND DEVICES -...
#
#                                     description quantity IP Price
# 0                            HC Resusitator Bag        1    46.75  \
# 0                            HC Resusitator Bag        1    46.75
# 0                            HC Resusitator Bag        1    46.75
# 0                            HC Resusitator Bag        1    46.75
# 0                            HC Resusitator Bag        1    46.75
# ...                                         ...      ...      ...
# 257890                   HC Resolution Tips 846        1      225
# 257891            HC Respiratory Evaluation 742        1   169.46
# 257891            HC Respiratory Evaluation 742        1   169.46
# 257892  HC Respiratory Therapy Instructions 846        1     1.25
# 257892  HC Respiratory Therapy Instructions 846        1     1.25
#
#                      IP XR Detail OP Price OP Expected Reimbursement
# 0       Not reimbursed separately    46.75                     39.74  \
# 0       Not reimbursed separately    46.75                     39.74
# 0       Not reimbursed separately    46.75                     39.74
# 0       Not reimbursed separately    46.75                     39.74
# 0       Not reimbursed separately    46.75                     39.74
# ...                           ...      ...                       ...
# 257890  Not reimbursed separately      225                       225
# 257891  Not reimbursed separately   169.46                    169.46
# 257891  Not reimbursed separately   169.46                    169.46
# 257892  Not reimbursed separately     1.25                      1.25
# 257892  Not reimbursed separately     1.25                      1.25
#
#        Cash Price
# 0           46.75
# 0           46.75
# 0           46.75
# 0           46.75
# 0           46.75
# ...           ...
# 257890        225
# 257891     169.46
# 257891     169.46
# 257892       1.25
# 257892       1.25
#
# [959143 rows x 15 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.loc[(~df['rev_code'].isna()), 'rev_code'] = df['rev_code'].str.extract(r'(\d{4})', expand=False)

# %%
df.drop(columns=['IP XR Detail'], inplace=True)

# %%
df
# Out:
#                               payer_name       additional_payer_notes
# 0                           AETNA [1001]     CRH AETNA CONTRACT [115]  \
# 1                           AETNA [1001]     CRH AETNA CONTRACT [115]
# 2                           AETNA [1001]     CRH AETNA CONTRACT [115]
# 3                           AETNA [1001]     CRH AETNA CONTRACT [115]
# 4                           AETNA [1001]     CRH AETNA CONTRACT [115]
# ...                                  ...                          ...
# 959138  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
# 959139  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
# 959140  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
# 959141  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
# 959142  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
#
#                                                plan_name local_code line_type
# 0                   AETNA ALLIED BENEFIT SYSTEM [100101]    H128224       EAP  \
# 1                      AETNA MANAGED CARE PLANS [100102]    H128224       EAP
# 2        AETNA SIGNATURE ADMINISTRATORS GENERIC [100103]    H128224       EAP
# 3                        AETNATRADITIONAL PLANS [100104]    H128224       EAP
# 4               1199 NATIONAL BENEFIT FUND(BAR) [100105]    H128224       EAP
# ...                                                  ...        ...       ...
# 959138                                      NY [3001901]    H128209       EAP
# 959139                                          MEDICAID    H128215       EAP
# 959140                                      NY [3001901]    H128215       EAP
# 959141                                          MEDICAID    H128216       EAP
# 959142                                      NY [3001901]    H128216       EAP
#
#               code  ndc rev_code                              description
# 0              NaN  NaN     0270                       HC Resusitator Bag  \
# 1              NaN  NaN     0270                       HC Resusitator Bag
# 2              NaN  NaN     0270                       HC Resusitator Bag
# 3              NaN  NaN     0270                       HC Resusitator Bag
# 4              NaN  NaN     0270                       HC Resusitator Bag
# ...            ...  ...      ...                                      ...
# 959138         NaN  NaN     0272                   HC Resolution Tips 846
# 959139  CPT« 94799  NaN     0410            HC Respiratory Evaluation 742
# 959140  CPT« 94799  NaN     0410            HC Respiratory Evaluation 742
# 959141         NaN  NaN     0270  HC Respiratory Therapy Instructions 846
# 959142         NaN  NaN     0270  HC Respiratory Therapy Instructions 846
#
#        quantity IP Price OP Price OP Expected Reimbursement Cash Price
# 0             1    46.75    46.75                     39.74      46.75
# 1             1    46.75    46.75                     39.74      46.75
# 2             1    46.75    46.75                     39.74      46.75
# 3             1    46.75    46.75                     39.74      46.75
# 4             1    46.75    46.75                     39.74      46.75
# ...         ...      ...      ...                       ...        ...
# 959138        1      225      225                       225        225
# 959139        1   169.46   169.46                    169.46     169.46
# 959140        1   169.46   169.46                    169.46     169.46
# 959141        1     1.25     1.25                      1.25       1.25
# 959142        1     1.25     1.25                      1.25       1.25
#
# [959143 rows x 14 columns]

# %%
cols = df.columns.tolist()

if 'line_type' in cols:
    id_vars = cols[:10]
    val_vars = cols[10:]
else:
    id_vars = cols[:9]
    val_vars = cols[9:]

df = pd.melt(df, id_vars=id_vars, value_vars=val_vars, var_name='payer_type', value_name='standard_charge')

# %%
df
# Out:
#                                payer_name       additional_payer_notes
# 0                            AETNA [1001]     CRH AETNA CONTRACT [115]  \
# 1                            AETNA [1001]     CRH AETNA CONTRACT [115]
# 2                            AETNA [1001]     CRH AETNA CONTRACT [115]
# 3                            AETNA [1001]     CRH AETNA CONTRACT [115]
# 4                            AETNA [1001]     CRH AETNA CONTRACT [115]
# ...                                   ...                          ...
# 3836567  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
# 3836568  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
# 3836569  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
# 3836570  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
# 3836571  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
#
#                                                 plan_name local_code
# 0                    AETNA ALLIED BENEFIT SYSTEM [100101]    H128224  \
# 1                       AETNA MANAGED CARE PLANS [100102]    H128224
# 2         AETNA SIGNATURE ADMINISTRATORS GENERIC [100103]    H128224
# 3                         AETNATRADITIONAL PLANS [100104]    H128224
# 4                1199 NATIONAL BENEFIT FUND(BAR) [100105]    H128224
# ...                                                   ...        ...
# 3836567                                      NY [3001901]    H128209
# 3836568                                          MEDICAID    H128215
# 3836569                                      NY [3001901]    H128215
# 3836570                                          MEDICAID    H128216
# 3836571                                      NY [3001901]    H128216
#
#         line_type        code  ndc rev_code
# 0             EAP         NaN  NaN     0270  \
# 1             EAP         NaN  NaN     0270
# 2             EAP         NaN  NaN     0270
# 3             EAP         NaN  NaN     0270
# 4             EAP         NaN  NaN     0270
# ...           ...         ...  ...      ...
# 3836567       EAP         NaN  NaN     0272
# 3836568       EAP  CPT« 94799  NaN     0410
# 3836569       EAP  CPT« 94799  NaN     0410
# 3836570       EAP         NaN  NaN     0270
# 3836571       EAP         NaN  NaN     0270
#
#                                      description quantity  payer_type
# 0                             HC Resusitator Bag        1    IP Price  \
# 1                             HC Resusitator Bag        1    IP Price
# 2                             HC Resusitator Bag        1    IP Price
# 3                             HC Resusitator Bag        1    IP Price
# 4                             HC Resusitator Bag        1    IP Price
# ...                                          ...      ...         ...
# 3836567                   HC Resolution Tips 846        1  Cash Price
# 3836568            HC Respiratory Evaluation 742        1  Cash Price
# 3836569            HC Respiratory Evaluation 742        1  Cash Price
# 3836570  HC Respiratory Therapy Instructions 846        1  Cash Price
# 3836571  HC Respiratory Therapy Instructions 846        1  Cash Price
#
#         standard_charge
# 0                 46.75
# 1                 46.75
# 2                 46.75
# 3                 46.75
# 4                 46.75
# ...                 ...
# 3836567             225
# 3836568          169.46
# 3836569          169.46
# 3836570            1.25
# 3836571            1.25
#
# [3836572 rows x 12 columns]

# %%
df['payer_type'] = df['payer_type'].str.strip()

# %%
# Set column `setting` to either `inpatient` if col `payer` starts with  'IP' or `outpatient` if col `payer` starts with  'OP'
df['setting'] = np.where(df['payer_type'].str.startswith('IP '), 'inpatient', np.where(df['payer_type'].str.startswith('OP '), 'outpatient', 1))

# %%
payer_mapping = {
    'IP Price': 'gross',
    'OP Price': 'gross',
    'IP Expected Reimbursement': 'payer',
    'OP Expected Reimbursement': 'payer',
    'Cash Price': 'cash'
}

df['payer_category'] = df['payer_type'].map(payer_mapping)

# %%
df
# Out:
#                                payer_name       additional_payer_notes
# 0                            AETNA [1001]     CRH AETNA CONTRACT [115]  \
# 1                            AETNA [1001]     CRH AETNA CONTRACT [115]
# 2                            AETNA [1001]     CRH AETNA CONTRACT [115]
# 3                            AETNA [1001]     CRH AETNA CONTRACT [115]
# 4                            AETNA [1001]     CRH AETNA CONTRACT [115]
# ...                                   ...                          ...
# 3836567  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
# 3836568  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
# 3836569  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
# 3836570  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
# 3836571  MEDICAID ALTERNATE PAYOR [30019]  CRH MEDICAID CONTRACT [118]
#
#                                                 plan_name local_code
# 0                    AETNA ALLIED BENEFIT SYSTEM [100101]    H128224  \
# 1                       AETNA MANAGED CARE PLANS [100102]    H128224
# 2         AETNA SIGNATURE ADMINISTRATORS GENERIC [100103]    H128224
# 3                         AETNATRADITIONAL PLANS [100104]    H128224
# 4                1199 NATIONAL BENEFIT FUND(BAR) [100105]    H128224
# ...                                                   ...        ...
# 3836567                                      NY [3001901]    H128209
# 3836568                                          MEDICAID    H128215
# 3836569                                      NY [3001901]    H128215
# 3836570                                          MEDICAID    H128216
# 3836571                                      NY [3001901]    H128216
#
#         line_type        code  ndc rev_code
# 0             EAP         NaN  NaN     0270  \
# 1             EAP         NaN  NaN     0270
# 2             EAP         NaN  NaN     0270
# 3             EAP         NaN  NaN     0270
# 4             EAP         NaN  NaN     0270
# ...           ...         ...  ...      ...
# 3836567       EAP         NaN  NaN     0272
# 3836568       EAP  CPT« 94799  NaN     0410
# 3836569       EAP  CPT« 94799  NaN     0410
# 3836570       EAP         NaN  NaN     0270
# 3836571       EAP         NaN  NaN     0270
#
#                                      description quantity  payer_type
# 0                             HC Resusitator Bag        1    IP Price  \
# 1                             HC Resusitator Bag        1    IP Price
# 2                             HC Resusitator Bag        1    IP Price
# 3                             HC Resusitator Bag        1    IP Price
# 4                             HC Resusitator Bag        1    IP Price
# ...                                          ...      ...         ...
# 3836567                   HC Resolution Tips 846        1  Cash Price
# 3836568            HC Respiratory Evaluation 742        1  Cash Price
# 3836569            HC Respiratory Evaluation 742        1  Cash Price
# 3836570  HC Respiratory Therapy Instructions 846        1  Cash Price
# 3836571  HC Respiratory Therapy Instructions 846        1  Cash Price
#
#         standard_charge    setting payer_category
# 0                 46.75  inpatient          gross
# 1                 46.75  inpatient          gross
# 2                 46.75  inpatient          gross
# 3                 46.75  inpatient          gross
# 4                 46.75  inpatient          gross
# ...                 ...        ...            ...
# 3836567             225          1           cash
# 3836568          169.46          1           cash
# 3836569          169.46          1           cash
# 3836570            1.25          1           cash
# 3836571            1.25          1           cash
#
# [3836572 rows x 14 columns]

# %%
df.drop_duplicates(subset='payer_type')
# Out:
#            payer_name    additional_payer_notes
# 0        AETNA [1001]  CRH AETNA CONTRACT [115]  \
# 959143   AETNA [1001]  CRH AETNA CONTRACT [115]
# 1918286  AETNA [1001]  CRH AETNA CONTRACT [115]
# 2877429  AETNA [1001]  CRH AETNA CONTRACT [115]
#
#                                     plan_name local_code line_type code  ndc
# 0        AETNA ALLIED BENEFIT SYSTEM [100101]    H128224       EAP  NaN  NaN  \
# 959143   AETNA ALLIED BENEFIT SYSTEM [100101]    H128224       EAP  NaN  NaN
# 1918286  AETNA ALLIED BENEFIT SYSTEM [100101]    H128224       EAP  NaN  NaN
# 2877429  AETNA ALLIED BENEFIT SYSTEM [100101]    H128224       EAP  NaN  NaN
#
#         rev_code         description quantity                 payer_type
# 0           0270  HC Resusitator Bag        1                   IP Price  \
# 959143      0270  HC Resusitator Bag        1                   OP Price
# 1918286     0270  HC Resusitator Bag        1  OP Expected Reimbursement
# 2877429     0270  HC Resusitator Bag        1                 Cash Price
#
#         standard_charge     setting payer_category
# 0                 46.75   inpatient          gross
# 959143            46.75  outpatient          gross
# 1918286           39.74  outpatient          payer
# 2877429           46.75           1           cash

# %%
df.drop(df.loc[(df['payer_name'] == '<Self-pay>') & (df['payer_type'] != 'Cash Price')].index, inplace=True)

# %%
df.loc[df['quantity'] == '1', 'quantity'] = pd.NA
df['standard_charge'] = df['standard_charge'].str.replace('$', '').str.replace(',', '').str.strip()
df.loc[df['standard_charge'] == '-', 'standard_charge'] = pd.NA

# %%
df.dropna(subset='standard_charge', inplace=True)

# %%
df.loc[(~df['code'].isna()) & (df['code'].str.match('HCPCS|CPT')), 'hcpcs_cpt'] = df['code'].str.replace('HCPCS |CPT« ', '', regex=True)
df['hcpcs_cpt'] = df['hcpcs_cpt'].str.strip()
df.loc[(df['hcpcs_cpt'].str.len() == 8) | (df['hcpcs_cpt'] == 'CUSTOM') | (df['hcpcs_cpt'].str.len() != 5), 'hcpcs_cpt'] = pd.NA

# %%
df.loc[~df['code'].isna() & df['code'].str.contains('DRG')]
# Out:
# Empty DataFrame
# Columns: [payer_name, additional_payer_notes, plan_name, local_code, line_type, code, ndc, rev_code, description, quantity, payer_type, standard_charge, setting, payer_category, hcpcs_cpt]
# Index: []

# %%
df.drop(columns='payer_type', inplace=True)

# %%
hospital_map = {
    '150539039_AURELIA-OSBORN-FOX-MEMORIAL-HOSPITAL_STANDARDCHARGES_0.csv': '330408',
    '135596796_MARY-IMOGENE-BASSETT-HOSPITAL_STANDARDCHARGES.csv': '330136',
    '161540394_OCONNOR-HOSPITAL_STANDARDCHARGES_0.csv': '331305',
    '150533578_LITTLE-FALLS-HOSPITAL_STANDARDCHARGES_0.csv': '331311',
    '141772971_COBLESKILL-REGIONAL-HOSPITAL_STANDARDCHARGES_0.csv': '331320',
    '150539039_AURELIA-OSBORN-FOX-MEMORIAL-HOSPITAL_STANDARDCHARGES_1.csv': '330085'
}

hosp_id = hospital_map[file]

df['hospital_id'] = hosp_id

# df.to_csv('.\\output_files\\' + hosp_id + file.split('_')[1] + '.csv', index=False)
