# %%
import pandas as pd

# %%
pd.set_option('display.min_rows', 20)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv(".\\output_files\\411266009_241328.csv", dtype=str, low_memory=False)

pk_cols = ['hospital_id', 'rev_code', 'local_code', 'ms_drg', 'apr_drg', 'hcpcs_cpt', 'modifiers', 'ndc', 'billing_class', 'setting', 'payer_name', 'plan', 'description', 'standard_charge', 'code']
pk_cols = [x for x in pk_cols if x in df.columns]

# create a style object with background color yellow for pk columns
dp_rows = df[df.duplicated(subset=pk_cols, keep=False)]

dp_rows.sort_values(pk_cols, inplace=True)
# dp_rows.sort_values('code', inplace=True)
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_6455304\2659666701.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp_rows.sort_values(pk_cols, inplace=True)

# %%
dp_rows[dp_rows.duplicated]
# Out:
#                      payer_name
# 3719           Avg_Gross_Charge  \
# 4747           Avg_Gross_Charge
# 5775           Avg_Gross_Charge
# 6803           Avg_Gross_Charge
# 7831           Avg_Gross_Charge
# 8859           Avg_Gross_Charge
# 9887           Avg_Gross_Charge
# 10915          Avg_Gross_Charge
# 11943          Avg_Gross_Charge
# 12971          Avg_Gross_Charge
# ...                         ...
# 71718  Deidentified_Min_Allowed
# 72685  Deidentified_Min_Allowed
# 73652  Deidentified_Min_Allowed
# 74619  Deidentified_Min_Allowed
# 75586  Deidentified_Min_Allowed
# 76553  Deidentified_Min_Allowed
# 77520  Deidentified_Min_Allowed
# 78487  Deidentified_Min_Allowed
# 79454  Deidentified_Min_Allowed
# 80421  Deidentified_Min_Allowed
#
#                                                                                                                                           description
# ...

# %%
df.loc[df['code'] == '72220']
# Out:
#                                payer_name        description   code
# 334             BCBS Minnesota Commercial  X-Ray of Tailbone  72220  \
# 565     BCBS Minnesota Medicare Advantage  X-Ray of Tailbone  72220
# 1812       Sanford Health Plan Commercial  X-Ray of Tailbone  72220
# 1866               UCare Managed Medicaid  X-Ray of Tailbone  72220
# 3375                     Avg_Gross_Charge  X-Ray of Tailbone  72220
# 4403                     Avg_Gross_Charge  X-Ray of Tailbone  72220
# 5431                     Avg_Gross_Charge  X-Ray of Tailbone  72220
# 6459                     Avg_Gross_Charge  X-Ray of Tailbone  72220
# 7487                     Avg_Gross_Charge  X-Ray of Tailbone  72220
# 8515                     Avg_Gross_Charge  X-Ray of Tailbone  72220
# ...                                   ...                ...    ...
# 97384            DeIdentified_Max_Allowed  X-Ray of Tailbone  72220
# 98351            DeIdentified_Max_Allowed  X-Ray of Tailbone  72220
# ...
