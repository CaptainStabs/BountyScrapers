# %%
import pandas as pd

# %%
pd.set_option('display.min_rows', 50)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv(".\\output_files\\Hawaii.csv", dtype=str, low_memory=False)

pk_cols = ['hospital_id', 'rev_code', 'local_code', 'ms_drg', 'apr_drg', 'hcpcs_cpt', 'modifiers', 'ndc', 'billing_class', 'setting', 'payer', 'plan']
pk_cols = [x for x in pk_cols if x in df.columns]

# create a style object with background color yellow for pk columns
dp_rows = df[df.duplicated(subset=pk_cols, keep=False)]

dp_rows.sort_values(pk_cols, inplace=True)
# Out:
# \Local\Temp\ipykernel_34628\2064733943.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp_rows.sort_values(pk_cols, inplace=True)

# %%
dp_rows
# Out:
#       code
# 0    20610  \
# 1    20610
# 433  20670
# 434  20670
# 288  20670
# 289  20670
# 2    20670
# 3    20670
# 672  20670
# 673  20670
# 4    20680
# 5    20680
# 6    22899
# 7    22899
# 435  24530
# 436  24530
# 290  24530
# 291  24530
# 8    24530
# 9    24530
# 674  24530
# 675  24530
# 10   24538
# 11   24538
# 12   24575
# ..     ...
# 259  J2765
# 260  J3010
# 261  J3010
# 262  J3370
# 263  J3370
# 264  J3480
# 265  J3480
# 573  J3490
# 574  J3490
# 428  J3490
# 429  J3490
# 266  J3490
# 267  J3490
# 796  J3490
# 797  J3490
# 670  J3490
# 671  J3490
# 268  J7050
# 269  J7050
# 270  J7120
# 271  J7120
# 272  L8699
# 273  L8699
# 274  Q9967
# 275  Q9967
#
#                                                                    description
# 0                        ASPIRATION AND/OR INJECTION OF FLUID FROM LARGE JOINT  \
# 1                        ASPIRATION AND/OR INJECTION OF FLUID FROM LARGE JOINT
# 433                                       REMOVAL OF SURFACE IMPLANT FROM BONE
# 434                                       REMOVAL OF SURFACE IMPLANT FROM BONE
# 288                                       REMOVAL OF SURFACE IMPLANT FROM BONE
# 289                                       REMOVAL OF SURFACE IMPLANT FROM BONE
# 2                                         REMOVAL OF SURFACE IMPLANT FROM BONE
# 3                                         REMOVAL OF SURFACE IMPLANT FROM BONE
# 672                                       REMOVAL OF SURFACE IMPLANT FROM BONE
# 673                                       REMOVAL OF SURFACE IMPLANT FROM BONE
# 4                                            REMOVAL OF DEEP IMPLANT FROM BONE
# 5                                            REMOVAL OF DEEP IMPLANT FROM BONE
# 6                                                     OTHER PROCEDURE ON SPINE
# 7                                                     OTHER PROCEDURE ON SPINE
# 435                         CLOSED TREATMENT OF UPPER ARM BONE BROKEN AT ELBOW
# 436                         CLOSED TREATMENT OF UPPER ARM BONE BROKEN AT ELBOW
# 290                         CLOSED TREATMENT OF UPPER ARM BONE BROKEN AT ELBOW
# 291                         CLOSED TREATMENT OF UPPER ARM BONE BROKEN AT ELBOW
# 8                           CLOSED TREATMENT OF UPPER ARM BONE BROKEN AT ELBOW
# 9                           CLOSED TREATMENT OF UPPER ARM BONE BROKEN AT ELBOW
# 674                         CLOSED TREATMENT OF UPPER ARM BONE BROKEN AT ELBOW
# 675                         CLOSED TREATMENT OF UPPER ARM BONE BROKEN AT ELBOW
# 10                PLACEMENT OF STABILIZING DEVICE TO UPPER ARM BROKEN AT ELBOW
# 11                PLACEMENT OF STABILIZING DEVICE TO UPPER ARM BROKEN AT ELBOW
# 12                   TREATMENT OF BROKEN OUTER PART OF UPPER ARM BONE AT ELBOW
# ..                                                                         ...
# 259                                 INJECTION, METOCLOPRAMIDE HCL, UP TO 10 MG
# 260                                        INJECTION, FENTANYL CITRATE, 0.1 MG
# 261                                        INJECTION, FENTANYL CITRATE, 0.1 MG
# 262                                          INJECTION, VANCOMYCIN HCL, 500 MG
# 263                                          INJECTION, VANCOMYCIN HCL, 500 MG
# 264                                   INJECTION, POTASSIUM CHLORIDE, PER 2 MEQ
# 265                                   INJECTION, POTASSIUM CHLORIDE, PER 2 MEQ
# 573                                                         UNCLASSIFIED DRUGS
# 574                                                         UNCLASSIFIED DRUGS
# 428                                                         UNCLASSIFIED DRUGS
# 429                                                         UNCLASSIFIED DRUGS
# 266                                                         UNCLASSIFIED DRUGS
# 267                                                         UNCLASSIFIED DRUGS
# 796                                                         UNCLASSIFIED DRUGS
# 797                                                         UNCLASSIFIED DRUGS
# 670                                                         UNCLASSIFIED DRUGS
# 671                                                         UNCLASSIFIED DRUGS
# 268                                   INFUSION, NORMAL SALINE SOLUTION, 250 CC
# 269                                   INFUSION, NORMAL SALINE SOLUTION, 250 CC
# 270                                    RINGERS LACTATE INFUSION, UP TO 1000 CC
# 271                                    RINGERS LACTATE INFUSION, UP TO 1000 CC
# 272                                PROSTHETIC IMPLANT, NOT OTHERWISE SPECIFIED
# 273                                PROSTHETIC IMPLANT, NOT OTHERWISE SPECIFIED
# 274  LOW OSMOLAR CONTRAST MATERIAL, 300-399 MG/ML IODINE CONCENTRATION, PER ML
# 275  LOW OSMOLAR CONTRAST MATERIAL, 300-399 MG/ML IODINE CONCENTRATION, PER ML
#
#         setting                                    payer standard_charge
# 0    outpatient                             Gross Charge           718.5  \
# 1    outpatient                             Gross Charge         1565.88
# 433  outpatient        De-identified max contracted rate          183.45
# 434  outpatient        De-identified max contracted rate          183.45
# 288  outpatient        De-identified min contracted rate          183.45
# 289  outpatient        De-identified min contracted rate          183.45
# 2    outpatient                             Gross Charge         5680.95
# 3    outpatient                             Gross Charge          8023.4
# 672  outpatient                HMSA-Commercial other_Avg          183.45
# 673  outpatient                HMSA-Commercial other_Avg          183.45
# 4    outpatient                             Gross Charge         10008.7
# 5    outpatient                             Gross Charge        14341.07
# 6    outpatient                             Gross Charge          7393.4
# 7    outpatient                             Gross Charge          7393.4
# 435  outpatient        De-identified max contracted rate          539.37
# 436  outpatient        De-identified max contracted rate          539.37
# 290  outpatient        De-identified min contracted rate          539.37
# 291  outpatient        De-identified min contracted rate          539.37
# 8    outpatient                             Gross Charge           718.5
# 9    outpatient                             Gross Charge           718.5
# 674  outpatient                HMSA-Commercial other_Avg          539.37
# 675  outpatient                HMSA-Commercial other_Avg          539.37
# 10   outpatient                             Gross Charge          8012.1
# 11   outpatient                             Gross Charge        13919.54
# 12   outpatient                             Gross Charge         13424.9
# ..          ...                                      ...             ...
# 259  outpatient                             Gross Charge           131.3
# 260  outpatient                             Gross Charge          243.04
# 261  outpatient                             Gross Charge          243.04
# 262  outpatient                             Gross Charge           69.75
# 263  outpatient                             Gross Charge           69.75
# 264  outpatient                             Gross Charge            14.9
# 265  outpatient                             Gross Charge            14.9
# 573  outpatient        De-identified max contracted rate            3.43
# 574  outpatient        De-identified max contracted rate            3.43
# 428  outpatient        De-identified min contracted rate            2.04
# 429  outpatient        De-identified min contracted rate            2.04
# 266  outpatient                             Gross Charge           92.21
# 267  outpatient                             Gross Charge           92.21
# 796  outpatient                HMSA-Commercial other_Avg            2.04
# 797  outpatient                HMSA-Commercial other_Avg            2.04
# 670  outpatient  United Healthcare -Commercial other_Avg            3.43
# 671  outpatient  United Healthcare -Commercial other_Avg            3.43
# 268  outpatient                             Gross Charge          461.22
# 269  outpatient                             Gross Charge          461.22
# 270  outpatient                             Gross Charge          135.24
# 271  outpatient                             Gross Charge          135.24
# 272  outpatient                             Gross Charge         1746.18
# 273  outpatient                             Gross Charge         1746.18
# 274  outpatient                             Gross Charge           29.32
# 275  outpatient                             Gross Charge           29.32
#
#     ms_drg hcpcs_cpt payer_category hospital_id
# 0      NaN     20610          gross      123301
# 1      NaN     20610          gross      123301
# 433    NaN     20670            max      123301
# 434    NaN     20670            max      123301
# 288    NaN     20670            min      123301
# 289    NaN     20670            min      123301
# 2      NaN     20670          gross      123301
# 3      NaN     20670          gross      123301
# 672    NaN     20670          payer      123301
# 673    NaN     20670          payer      123301
# 4      NaN     20680          gross      123301
# 5      NaN     20680          gross      123301
# 6      NaN     22899          gross      123301
# 7      NaN     22899          gross      123301
# 435    NaN     24530            max      123301
# 436    NaN     24530            max      123301
# 290    NaN     24530            min      123301
# 291    NaN     24530            min      123301
# 8      NaN     24530          gross      123301
# 9      NaN     24530          gross      123301
# 674    NaN     24530          payer      123301
# 675    NaN     24530          payer      123301
# 10     NaN     24538          gross      123301
# 11     NaN     24538          gross      123301
# 12     NaN     24575          gross      123301
# ..     ...       ...            ...         ...
# 259    NaN     J2765          gross      123301
# 260    NaN     J3010          gross      123301
# 261    NaN     J3010          gross      123301
# 262    NaN     J3370          gross      123301
# 263    NaN     J3370          gross      123301
# 264    NaN     J3480          gross      123301
# 265    NaN     J3480          gross      123301
# 573    NaN     J3490            max      123301
# 574    NaN     J3490            max      123301
# 428    NaN     J3490            min      123301
# 429    NaN     J3490            min      123301
# 266    NaN     J3490          gross      123301
# 267    NaN     J3490          gross      123301
# 796    NaN     J3490          payer      123301
# 797    NaN     J3490          payer      123301
# 670    NaN     J3490          payer      123301
# 671    NaN     J3490          payer      123301
# 268    NaN     J7050          gross      123301
# 269    NaN     J7050          gross      123301
# 270    NaN     J7120          gross      123301
# 271    NaN     J7120          gross      123301
# 272    NaN     L8699          gross      123301
# 273    NaN     L8699          gross      123301
# 274    NaN     Q9967          gross      123301
# 275    NaN     Q9967          gross      123301
#
# [854 rows x 9 columns]
