# %%
import pandas as pd

# %%
pd.set_option('display.min_rows', 10)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv(".\\output_files\\20-2850920.csv", dtype=str, low_memory=False)

pk_cols = ['hospital_id', 'rev_code', 'local_code', 'ms_drg', 'apr_drg', 'hcpcs_cpt', 'modifiers', 'ndc', 'billing_class', 'setting', 'payer_name', 'plan', 'description', 'standard_charge']
pk_cols = [x for x in pk_cols if x in df.columns]

# create a style object with background color yellow for pk columns
dp_rows = df[df.duplicated(subset=pk_cols, keep=False)]

dp_rows.sort_values(pk_cols, inplace=True)
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_9194188\2748562539.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp_rows.sort_values(pk_cols, inplace=True)

# %%
df[df.duplicated]
# Out:
#            setting ms_drg apr_drg local_code
# 8897     inpatient    NaN     NaN   25000001  \
# 9099     inpatient    NaN     NaN   25000030
# 9101     inpatient    NaN     NaN   25000030
# 9102     inpatient    NaN     NaN   25000030
# 9246     inpatient    NaN     NaN   25800001
# ...            ...    ...     ...        ...
# 111754   inpatient    NaN     NaN   63600036
# 115572   inpatient    NaN     NaN   63600036
# 116941   inpatient    NaN     NaN   27801253
# 117072  outpatient    NaN     NaN   27800165
# 117116  outpatient    NaN     NaN   27801253
#
#                                                                       description
# 8897                                  electrolyte-R (pH 7.4) intravenous solution  \
# 9099              tranexamic acid 1,000 mg/10 mL (100 mg/mL) intravenous solution
# 9101              tranexamic acid 1,000 mg/10 mL (100 mg/mL) intravenous solution
# 9102              tranexamic acid 1,000 mg/10 mL (100 mg/mL) intravenous solution
# 9246                                   sodium chloride 0.9 % intravenous solution
# ...                                                                           ...
# 111754                                                     voriconazole 200 mg IV
# 115572                                                     voriconazole 200 mg IV
# 116941  Hc Shell C1713, Anchor/screw, Bone-to-bone Or Soft Tissue-to-bone (implt)
# 117072                                     Hc Shell Crosslink,#10 Crosovr Rod Spn
# 117116  Hc Shell C1713, Anchor/screw, Bone-to-bone Or Soft Tissue-to-bone (implt)
#
#                 ndc rev_code hcpcs_cpt contracting_method        payer_name
# 8897      409767009     0250       NaN                NaN      Gross Charge  \
# 9099    39822100001     0250       NaN                NaN      Gross Charge
# 9101    67850004100     0250       NaN                NaN      Gross Charge
# 9102    67850004110     0250       NaN                NaN      Gross Charge
# 9246      264780010     0258       NaN                NaN      Gross Charge
# ...             ...      ...       ...                ...               ...
# 111754     49319028     0259       NaN                NaN  Wellmed Medicare
# 115572     49319028     0636       NaN                NaN  Wellmed Medicare
# 116941          NaN     0276       NaN                NaN  Wellmed Medicare
# 117072          NaN     0636       NaN                NaN  Wellmed Medicare
# 117116          NaN     0276       NaN                NaN  Wellmed Medicare
#
#        standard_charge payer_category hospital_id row_id
# 8897               0.0          gross      452105    NaN
# 9099              64.0          gross      452105    NaN
# 9101              82.0          gross      452105    NaN
# 9102              82.0          gross      452105    NaN
# 9246               0.0          gross      452105    NaN
# ...                ...            ...         ...    ...
# 111754           2.235          payer      452105    NaN
# 115572           2.235          payer      452105    NaN
# 116941           0.007          payer      452105    NaN
# 117072         2889.12          payer      452105    NaN
# 117116          0.0075          payer      452105    NaN
#
# [4173 rows x 14 columns]
