# %%
import pandas as pd
import polars as pl

# %%
folder = '.\\input_files\\'

file = '26-0194016_baylor-scott-and-white-medical-center-lake-pointe_standardcharges.csv'

df = pd.read_csv(folder + file, dtype=str, skiprows=4)

# %%
df.rename(columns={
    'Patient Type': 'setting',
    'DRG': 'ms_drg',
    'APR-DRG': 'apr_drg',
    'Procedure Code': 'local_code',
    'Procedure Name': 'description',
    'NDC': 'ndc',
    'Default Rev Code': 'rev_code',
    'CPT / HCPCS Code': 'hcpcs_cpt',
    'Service Package Type': 'contracting_method',
}, inplace=True)

# %%
df['setting'] = df['setting'].str.lower()
df['contracting_method'] = df['contracting_method'].str.lower()

# %%
df.drop(columns='Gross Charge Min/Max', inplace=True)

# %%
cols = df.columns.tolist()
id_vars = cols[:9]
value_vars = cols[9:]

df = pd.melt(df, id_vars=id_vars, value_vars=value_vars, var_name='payer', value_name='standard_charge')

# %%
df['standard_charge'] = pd.to_numeric(df['standard_charge'], errors='coerce')
df.dropna(subset=['standard_charge'], inplace=True)

# %%
empty_cols = ['ms_drg', 'apr_drg', 'local_code', 'ndc', 'rev_code', 'hcpcs_cpt']
df.loc[:, empty_cols] = df[empty_cols].fillna('')

# %%
mapping = {
    'Gross Charge': 'gross',
    'Discounted Cash Price': 'cash',
    'De-Identified Minimum Reimbursement*': 'min',
    'De-Identified Maximum Reimbursement*': 'max',
}

df['payer_category'] = df['payer'].map(mapping).fillna('payer')

# %%
ccn = {
        '74-1166904': '450054',
    '75-2586857': '450079',
    '74-1161944': '450101',
    '75-1008430': '450137',
    '75-1844139': '450372',
    '75-1777119': '450563',
    '75-2834135': '450851',
    '82-0551704': '450890',
    '74-1595711': '451374',
    '20-2850920': '452105',
    '41-2101361': '670025',
    '20-3749695': '670043',
    '27-4434451': '670088',
    '46-4007700': '670108',
    '81-3040663': '670136',
    '74-2519752': '450187',
    '82-4052186': '450885',
    '26-0194016': '450742',
    '75-1037591': '670082',
    '26-3603862': '450893',
    '75-1837454': '450021'
}

ein = file.split('_')[0]

df['hospital_id'] = ccn[ein]


# df = pl.from_pandas(df)
# df.write_csv('.\\output_files\\' + ein + '.csv')

# %%
df.loc[(df['hcpcs_cpt'].str.len() > 5)]
# Out:
#           setting ms_drg apr_drg local_code                   description ndc
# 4567    inpatient                  99800182  HC SURFACTANT ADMINISTRATION      \
# 4568    inpatient                  99800351            HC INCENTIVE SPIRO
# 9150   outpatient                  99800182  HC SURFACTANT ADMINISTRATION
# 9151   outpatient                  99800351            HC INCENTIVE SPIRO
# 35248   inpatient                  99800182  HC SURFACTANT ADMINISTRATION
# 35249   inpatient                  99800351            HC INCENTIVE SPIRO
# 39831  outpatient                  99800182  HC SURFACTANT ADMINISTRATION
# 39832  outpatient                  99800351            HC INCENTIVE SPIRO
#
#       rev_code hcpcs_cpt contracting_method                  payer
# 4567       998  99800182                NaN           Gross Charge  \
# 4568       998  99800351                NaN           Gross Charge
# 9150       998  99800182                NaN           Gross Charge
# 9151       998  99800351                NaN           Gross Charge
# 35248      998  99800182                NaN  Discounted Cash Price
# 35249      998  99800351                NaN  Discounted Cash Price
# 39831      998  99800182                NaN  Discounted Cash Price
# 39832      998  99800351                NaN  Discounted Cash Price
#
#        standard_charge payer_category hospital_id
# 4567            205.60          gross      450742
# 4568            167.20          gross      450742
# 9150            205.60          gross      450742
# 9151            167.20          gross      450742
# 35248           123.36           cash      450742
# 35249           100.32           cash      450742
# 39831           123.36           cash      450742
# 39832           100.32           cash      450742

# %%
df
# Out:
#           setting ms_drg apr_drg local_code
# 0       inpatient                  11000001  \
# 1       inpatient                  11100001
# 2       inpatient                  11200001
# 3       inpatient                  11264451
# 4       inpatient                  11264452
# ...           ...    ...     ...        ...
# 642169  inpatient    982
# 642170  inpatient    983
# 642171  inpatient    987
# 642172  inpatient    988
# 642173  inpatient    989
#
#                                               description ndc rev_code
# 0                                    HC PRIVATE - GENERAL          110  \
# 1                               HC PRIVATE - MED/SURG/GYN          111
# 2                                         HC PRIVATE - OB          112
# 3                                  HC PRIVATE- ANTEPARTUM          112
# 4                                  HC PRIVATE- POSTPARTUM          112
# ...                                                   ...  ..      ...
# 642169  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...
# 642170  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...
# 642171  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...
# 642172  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...
# 642173  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...
#
#        hcpcs_cpt contracting_method             payer  standard_charge
# 0                               NaN      Gross Charge          1132.60  \
# 1                               NaN      Gross Charge          1063.66
# 2                               NaN      Gross Charge          1134.86
# 3                               NaN      Gross Charge          1134.62
# 4                               NaN      Gross Charge          1123.38
# ...          ...                ...               ...              ...
# 642169                    case rate  Wellmed Medicare         31290.00
# 642170                    case rate  Wellmed Medicare         20374.00
# 642171                    case rate  Wellmed Medicare         40163.00
# 642172                    case rate  Wellmed Medicare         20693.00
# 642173                    case rate  Wellmed Medicare         13739.00
#
#        payer_category hospital_id
# 0               gross      450742
# 1               gross      450742
# 2               gross      450742
# 3               gross      450742
# 4               gross      450742
# ...               ...         ...
# 642169          payer      450742
# 642170          payer      450742
# 642171          payer      450742
# 642172          payer      450742
# 642173          payer      450742
#
# [170777 rows x 13 columns]
