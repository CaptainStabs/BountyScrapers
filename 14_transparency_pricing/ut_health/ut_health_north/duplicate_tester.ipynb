# %%
import pandas as pd

# %%
df = pd.read_csv('tyler.csv', dtype={'rate': float})

pk_cols = ['hospital_ccn','rev_code','internal_code','code_prefix','code','modifier','ndc','billing_class','patient_class','payer_orig','plan_orig', ]
pk_cols = [x for x in pk_cols if x in df.columns]

dp_rows = df[df.duplicated(subset=pk_cols, keep=False)]
# dp_rows = dp_rows[pk_cols]
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_27164\1585433269.py:1: DtypeWarning: Columns (0,3,4,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('tyler.csv', dtype={'rate': float})

# %%
dp_rows
# Out:
#        code_orig code_prefix  code rev_code internal_code code_type  \
# 2357         NaN        none  none     0250         10014       ERX
# 2358         NaN        none  none     0250         10014       ERX
# 2359         NaN        none  none     0250         10014       ERX
# 2360         NaN        none  none     0250         10014       ERX
# 2361         NaN        none  none     0250         10014       ERX
# ...          ...         ...   ...      ...           ...       ...
# 867150       NaN        none  none      637           999       ERX
# 867151       NaN        none  none      637           999       ERX
# 867152       NaN        none  none      637           999       ERX
# 867153       NaN        none  none      637           999       ERX
# 867154       NaN        none  none      637           999       ERX
#
#                                                  rev_desc  \
# 2357                              0250 - PHARMACY-GENERAL
# ...

# %%
dp_rows
# Out:
#        code_orig code_prefix  code rev_code internal_code code_type  \
# 2357         NaN        none  none     0250         10014       ERX
# 2358         NaN        none  none     0250         10014       ERX
# 2359         NaN        none  none     0250         10014       ERX
# 2360         NaN        none  none     0250         10014       ERX
# 2361         NaN        none  none     0250         10014       ERX
# ...          ...         ...   ...      ...           ...       ...
# 867150       NaN        none  none      637           999       ERX
# 867151       NaN        none  none      637           999       ERX
# 867152       NaN        none  none      637           999       ERX
# 867153       NaN        none  none      637           999       ERX
# 867154       NaN        none  none      637           999       ERX
#
#                                                  rev_desc  \
# 2357                              0250 - PHARMACY-GENERAL
# ...
