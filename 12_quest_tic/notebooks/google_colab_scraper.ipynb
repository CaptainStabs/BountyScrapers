# %%
# !git clone https://github.com/CaptainStabs/data-analysis.git
# Out:
# Cloning into 'data-analysis'...
# remote: Enumerating objects: 2566, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 2566 (delta 0), reused 4 (delta 0), pack-reused 2560
# Receiving objects: 100% (2566/2566), 52.41 MiB | 18.87 MiB/s, done.
# Resolving deltas: 100% (1193/1193), done.

# %%
cd /content/data-analysis
# Out:
# /content/data-analysis

# %%
# !git checkout mp
# Out:
# Branch 'mp' set up to track remote branch 'mp' from 'origin'.
# Switched to a new branch 'mp'

# %%
cd ./transparency-in-coverage/python/processors/
# Out:
# [Errno 2] No such file or directory: './transparency-in-coverage/python/processors/'
# /content/data-analysis/transparency-in-coverage/python

# %%
# !pip install -r /content/data-analysis/transparency-in-coverage/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 133 kB 4.7 MB/s
# ...
#      |████████████████████████████████| 61 kB 7.1 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
# !python cli_multi.py -i payer_index.csv -o output/payer_index/
# Out:
# Streaming output truncated to the last 5000 lines.
#     content.start()
#   File "/content/data-analysis/transparency-in-coverage/python/processors/mrfutils.py", line 712, in start
#     self.plan = next(self.extractor)
#   File "/content/data-analysis/transparency-in-coverage/python/processors/mrfutils.py", line 731, in _extractor
#     yield _plan(parser)
#   File "/content/data-analysis/transparency-in-coverage/python/processors/mrfutils.py", line 634, in _plan
#     for prefix, event, value in parser:
#   File "/usr/lib/python3.8/gzip.py", line 292, in read
#     return self._buffer.read(size)
#   File "/usr/lib/python3.8/_compression.py", line 68, in readinto
#     data = self.read(len(byte_view))
#   File "/usr/lib/python3.8/gzip.py", line 479, in read
#     if not self._read_gzip_header():
#   File "/usr/lib/python3.8/gzip.py", line 427, in _read_gzip_header
#     raise BadGzipFile('Not a gzipped file (%r)' % magic)
# gzip.BadGzipFile: Not a gzipped file (b'<!')
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 6 (delta 3), reused 6 (delta 3), pack-reused 0
# Unpacking objects: 100% (6/6), done.
# From https://github.com/CaptainStabs/data-analysis
#    69a3c35..0bad15c  mp         -> origin/mp
# Updating 69a3c35..0bad15c
# Fast-forward
#  transparency-in-coverage/python/processors/mrfutils.py | 10 ++++------
#  1 file changed, 4 insertions(+), 6 deletions(-)
